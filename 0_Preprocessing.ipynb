# %% [markdown]
# # DATA
#
# Study of a dataset cotaining various information about 32135 games published on Steam gaming plataform.
#
# | Columna | Descripción | Ejemplo |
# | -- | - | - |
# | publisher | Empresa publicadora del contenido | [Ubisoft,Dovetail Games - Trains,Degica] |
# | genres | Genero del contenido | [Action, Adventure, Racing, Simulation, Strategy] |
# | app_name | Nombre del contenido | [Warzone, Soundtrack, Puzzle Blocks] |
# | title | Titulo del contenido | [The Dream Machine: Chapter 4 , Fate/EXTELLA - Sweet Room Dream, Fate/EXTELLA - Charming Bunny] |
# | url | URL de publicación del contenido | http://store.steampowered.com/app/761140/Lost_Summoner_Kitty/ |
# | release_date | Fecha de lanzamiento | [2018-01-04] |
# | tags | etiquetas de contenido | [Simulation, Indie, Action, Adventure, Funny, Open World, First-Person, Sandbox, Free to Play] |
# | discount_price | precio de descuento | [22.66, 0.49, 0.69] |
# | reviews_url | Reviews de contenido | http://steamcommunity.com/app/681550/reviews/?browsefilter=mostrecent&p=1 |
# | specs | Especificaciones | [Multi-player, Co-op, Cross-Platform Multiplayer, Downloadable Content] |
# | price | Precio del contenido | [4.99, 9.99, Free to Use, Free to Play] |
# | early_access | acceso temprano | [False, True] |
# | id | identificador unico de contenido | [761140, 643980, 670290] |
# | developer | Desarrollador | [Kotoshiro, Secret Level SRL, Poolians.com] |
# | sentiment | Análisis de sentimiento | [Mixed, Very Positive, Positive, 3 user reviews] |
# | metascore | Score por metacritic | [80, 74, 77, 75] |

# %% [markdown]
# # PREPROCESSING
#
# Prepare datasets to process 6 endpoint efficiently.
#
#     def genero( Año: str ): Se ingresa un año y devuelve una lista con los 5 géneros más ofrecidos en el orden correspondiente.
#
#     def juegos( Año: str ): Se ingresa un año y devuelve una lista con los juegos lanzados en el año.
#
#     def specs( Año: str ): Se ingresa un año y devuelve una lista con los 5 specs que más se repiten en el mismo en el orden correspondiente.
#
#     def earlyacces( Año: str ): Cantidad de juegos lanzados en un año con early access.
#
#     def sentiment( Año: str ): Según el año de lanzamiento, se devuelve una lista con la cantidad de registros que se encuentren categorizados con un análisis de sentimiento.
#
#                         Ejemplo de retorno: {Mixed = 182, Very Positive = 120, Positive = 278}
#
#     def metascore( Año: str ): Top 5 juegos según año con mayor metascore.

# %% [markdown]
# Import relevant libraries.

# %%
import pandas as pd
import numpy as np
import ast
import json

# %% [markdown]
# ## Read Data

# %% [markdown]
# I tried to open the json file with pd.read_json but i could not do it because of it's format.

# %%
# pd.read_json()

# %% [markdown]
# That's why I decided to use "open" and then transform each row into a dictionary. With the list of all the rows I can create a DataFrame.

# %%
# Open file.
file = open('datasets/steam_games.json')

allNewLines = []

# Go through each line 
for line in file:
    # Create a dictionary of each line.
    myNewdict = ast.literal_eval(line)
    # Append to a list of all the lines in the file.
    allNewLines.append(myNewdict)

rawGamesDf = pd.DataFrame(allNewLines)

# %%
rawGamesDf.head(2)
# Out:
#           publisher                                         genres
# 0         Kotoshiro  [Action, Casual, Indie, Simulation, Strategy]  \
# 1  Making Fun, Inc.           [Free to Play, Indie, RPG, Strategy]
#
#               app_name                title
# 0  Lost Summoner Kitty  Lost Summoner Kitty  \
# 1            Ironbound            Ironbound
#
#                                                  url release_date
# 0  http://store.steampowered.com/app/761140/Lost_...   2018-01-04  \
# 1  http://store.steampowered.com/app/643980/Ironb...   2018-01-04
#
#                                                 tags  discount_price
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49  \
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
#
#                                          reviews_url
# 0  http://steamcommunity.com/app/761140/reviews/?...  \
# 1  http://steamcommunity.com/app/643980/reviews/?...
#
#                                                specs         price
# 0                                    [Single-player]          4.99  \
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
#
#    early_access      id         developer        sentiment metascore
# 0         False  761140         Kotoshiro              NaN       NaN
# 1         False  643980  Secret Level SRL  Mostly Positive       NaN

# %% [markdown]
# ## Columns: url & reviews_url
# We do not need any url for the analysis so we will drop them.

# %%
rawGamesDf.drop(columns=['url', 'reviews_url'], inplace=True)

# %%
rawGamesDf.head(2)
# Out:
#           publisher                                         genres
# 0         Kotoshiro  [Action, Casual, Indie, Simulation, Strategy]  \
# 1  Making Fun, Inc.           [Free to Play, Indie, RPG, Strategy]
#
#               app_name                title release_date
# 0  Lost Summoner Kitty  Lost Summoner Kitty   2018-01-04  \
# 1            Ironbound            Ironbound   2018-01-04
#
#                                                 tags  discount_price
# 0      [Strategy, Action, Indie, Casual, Simulation]            4.49  \
# 1  [Free to Play, Strategy, Indie, RPG, Card Game...             NaN
#
#                                                specs         price
# 0                                    [Single-player]          4.99  \
# 1  [Single-player, Multi-player, Online Multi-Pla...  Free To Play
#
#    early_access      id         developer        sentiment metascore
# 0         False  761140         Kotoshiro              NaN       NaN
# 1         False  643980  Secret Level SRL  Mostly Positive       NaN

# %% [markdown]
# ---

# %% [markdown]
# ## Duplicates
#
# Analysis if there are duplicates

# %%
# Games with duplicate ids, dropna to avoid games with ids = NaN.
rawGamesDf[rawGamesDf.duplicated(keep=False, subset='id')].dropna(subset='id')
# Out:
#                 publisher    genres                          app_name
# 13894  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus  \
# 14573  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
#
#                                   title release_date
# 13894  Wolfenstein II: The New Colossus   2017-10-26  \
# 14573  Wolfenstein II: The New Colossus   2017-10-26
#
#                                                     tags  discount_price
# 13894  [Action, FPS, Gore, Violent, Alternate History...             NaN  \
# 14573  [Action, FPS, Gore, Violent, Alternate History...             NaN
#
#                                                    specs  price  early_access
# 13894  [Single-player, Steam Achievements, Full contr...  59.99         False  \
# 14573  [Single-player, Steam Achievements, Full contr...  59.99         False
#
#            id      developer        sentiment metascore
# 13894  612880  Machine Games  Mostly Positive        86
# 14573  612880  Machine Games  Mostly Positive        86

# %%
index_last_dup_to_remove = rawGamesDf[rawGamesDf.duplicated(keep='last', subset='id')].dropna(subset='id').index
index_last_dup_to_remove
# Out:
# Index([13894], dtype='int64')

# %%
rawGamesDf.iloc[index_last_dup_to_remove]
# Out:
#                 publisher    genres                          app_name
# 13894  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus  \
#
#                                   title release_date
# 13894  Wolfenstein II: The New Colossus   2017-10-26  \
#
#                                                     tags  discount_price
# 13894  [Action, FPS, Gore, Violent, Alternate History...             NaN  \
#
#                                                    specs  price  early_access
# 13894  [Single-player, Steam Achievements, Full contr...  59.99         False  \
#
#            id      developer        sentiment metascore
# 13894  612880  Machine Games  Mostly Positive        86

# %%
rawGamesDf.drop(index=index_last_dup_to_remove, inplace=True)

# %%
# Can't use this one yet because of the list in some columns.
# rawGamesDf.drop_duplicates(inplace=True)

# %% [markdown]
# ---
#
# ### Aux Functions

# %%
def sort_dic(dic: dict):
    """
    Function made to sort dictionary values for the top 5 rankings.
    """
    dic_sorted = {}
    for y in dic.keys():
        d = dic[y]
        d_sorted = {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=True)}
        dic_sorted[y] = d_sorted
    return dic_sorted

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoints, general
#
# Since the data is static and won't change, the most optimal solution could be to prepare a data with every year already processed so the API endpoint can consume it with the least processing in real time.
#
# And since every endpoint to be consumed by the API it needs to know the year, let's process that first.

# %% [markdown]
# ### Year
#
# We only need year for this study so we will create a new column called year with that information. Extracting year with a pattern of four numbers toghether.

# %%
gamesWithYearDf = rawGamesDf

# %%
gamesWithYearDf['release_date'].unique()
# Out:
# array(['2018-01-04', '2017-07-24', '2017-12-07', ..., '2016-11-19',
#        'January 2018', '2018-10-01'], dtype=object)

# %%
# Pattern of regex to extract, 1XXX or 2XXX (valid years).
pattern = '([1-2][0-9][0-9][0-9])'
gamesWithYearDf['year'] = gamesWithYearDf['release_date'].str.extract(pattern, expand = True)

# %%
gamesWithYearDf['year'].head()
# Out:
# 0    2018
# 1    2018
# 2    2017
# 3    2017
# 4     NaN
# Name: year, dtype: object

# %%
gamesWithYearDf['year'].describe()
# Out:
# count     29966
# unique       44
# top        2017
# freq       9594
# Name: year, dtype: object

# %%
gamesWithYearDf['year'].isna().sum()
# Out:
# 2168

# %% [markdown]
# Drop "release_date" and drop NaNs from year since they will not give us relevant information on the APIs queries.

# %%
gamesWithYearDf = gamesWithYearDf.drop(columns='release_date')

# %%
gamesWithYearDf.shape
# Out:
# (32134, 14)

# %%
gamesWithYearDf = gamesWithYearDf.dropna(subset=['year'])

# %%
gamesWithYearDf.shape
# Out:
# (29966, 14)

# %% [markdown]
# Lastly we convert years into int and we can check the years so they are valid years and drop the invalids.

# %%
gamesWithYearDf['year'] = pd.to_numeric(gamesWithYearDf['year'])
gamesWithYearDf['year'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 29966 entries, 0 to 32133
# Series name: year
# Non-Null Count  Dtype
# --------------  -----
# 29966 non-null  int64
# dtypes: int64(1)
# memory usage: 468.2 KB

# %%
gamesWithYearDf[gamesWithYearDf['year'] > 2023]
# Out:
#       publisher                         genres             app_name
# 13428    一次元创作组  [Casual, Indie, Early Access]  Puzzle Sisters Foer  \
#
#                      title                           tags  discount_price
# 13428  Puzzle Sisters Foer  [Early Access, Casual, Indie]             NaN  \
#
#                                                    specs price  early_access
# 13428  [Single-player, Steam Achievements, Steam Trad...   NaN          True  \
#
#            id developer sentiment metascore  year
# 13428  710190    一次元创作组       NaN       NaN  2756

# %%
gamesWithYearDf[gamesWithYearDf['year'] < 1970].head()
# Out:
# Empty DataFrame
# Columns: [publisher, genres, app_name, title, tags, discount_price, specs, price, early_access, id, developer, sentiment, metascore, year]
# Index: []

# %% [markdown]
# Let's remove invalide, more than 2023. And older games

# %%
gamesWithYearDf = gamesWithYearDf[gamesWithYearDf['year'] <= 2023]

# %%
gamesWithYearDf = gamesWithYearDf[gamesWithYearDf['year'] > 1970]

# %% [markdown]
# ### App_name, Title
#
# Also, study both columns which contane the names of the game, "app_name" and "title".

# %%
gamesWithYearDf[['app_name', 'title']].head()
# Out:
#                   app_name                    title
# 0      Lost Summoner Kitty      Lost Summoner Kitty
# 1                Ironbound                Ironbound
# 2  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 3                  弹炸人2222                  弹炸人2222
# 5    Battle Royale Trainer    Battle Royale Trainer

# %% [markdown]
# First let's study and unify app_name and title into one. It only has one NaN each and it is in the same row, so we drop it.

# %%
print("Unique:",gamesWithYearDf['app_name'].unique())
print("NaNs:", gamesWithYearDf['app_name'].isna().sum())
# Out:
# Unique: ['Lost Summoner Kitty' 'Ironbound' 'Real Pool 3D - Poolians' ...
#  'LOGistICAL: South Africa' 'Russian Roads' 'EXIT 2 - Directions']
# NaNs: 1

# %%
print("Unique:",gamesWithYearDf['title'].unique())
print("NaNs:", gamesWithYearDf['title'].isna().sum())
# Out:
# Unique: ['Lost Summoner Kitty' 'Ironbound' 'Real Pool 3D - Poolians' ...
#  'LOGistICAL: South Africa' 'Russian Roads' 'EXIT 2 - Directions']
# NaNs: 1

# %%
gamesWithYearDf[gamesWithYearDf['title'].isna()]
# Out:
#      publisher           genres app_name title             tags
# 2580       NaN  [Action, Indie]      NaN   NaN  [Action, Indie]  \
#
#       discount_price                       specs price  early_access      id
# 2580             NaN  [Single-player, Game demo]   NaN         False  317160  \
#
#      developer sentiment metascore  year
# 2580       NaN  Positive       NaN  2014

# %%
gamesWithYearDf.shape
# Out:
# (29966, 14)

# %%
gamesWithYearDf = gamesWithYearDf.dropna(subset=['app_name', 'title'])

# %%
gamesWithYearDf.shape
# Out:
# (29965, 14)

# %% [markdown]
# Comparing the difference of game names it looks better the characters in "app_name", so we drop "title".

# %%
gamesWithYearDf[gamesWithYearDf['app_name'] != gamesWithYearDf['title']].tail()
# Out:
#             publisher               genres
# 31871  Telltale Games  [Action, Adventure]  \
# 31872  Telltale Games  [Action, Adventure]
# 31873  Telltale Games  [Action, Adventure]
# 31898  Strategy First   [Action, Strategy]
# 32052         Ubisoft        [Action, RPG]
#
#                                      app_name
# 31871              Sam & Max 105: Reality 2.0  \
# 31872    Sam & Max 104: Abe Lincoln Must Die!
# 31873  Sam & Max 106: Bright Side of the Moon
# 31898    Making History: The Calm & the Storm
# 32052           Dark Messiah of Might & Magic
#
#                                             title
# 31871              Sam &amp; Max 105: Reality 2.0  \
# 31872    Sam &amp; Max 104: Abe Lincoln Must Die!
# 31873  Sam &amp; Max 106: Bright Side of the Moon
# 31898    Making History: The Calm &amp; the Storm
# 32052           Dark Messiah of Might &amp; Magic
#
#                                                     tags  discount_price
# 31871                                [Adventure, Action]             NaN  \
# 31872  [Adventure, Action, Point & Click, Free to Pla...             NaN
# 31873                                [Adventure, Action]             NaN
# 31898  [Strategy, Action, Turn-Based Strategy, Grand ...             NaN
# 32052  [RPG, Action, First-Person, Fantasy, Adventure...             NaN
#
#                                                    specs  price  early_access
# 31871                                    [Single-player]  19.99         False  \
# 31872                                    [Single-player]  19.99         False
# 31873                                    [Single-player]  19.99         False
# 31898                      [Single-player, Multi-player]   4.99         False
# 32052  [Single-player, Multi-player, Valve Anti-Cheat...   9.99         False
#
#          id       developer       sentiment metascore  year
# 31871  8240  Telltale Games        Positive       NaN  2007
# 31872  8230  Telltale Games  8 user reviews       NaN  2007
# 31873  8250  Telltale Games        Positive       NaN  2007
# 31898  6250      Muzzy Lane   Very Positive        70  2007
# 32052  2100  Arkane Studios   Very Positive        72  2006

# %%
gamesWithYearDf = gamesWithYearDf.drop(columns='title')

# %% [markdown]
# ---
# ### Export JSON for future EDA
# Now that we can read the dataset, let's export to a new json file so we can use it in the EDA later.

# %%
gamesWithYearDf.to_json("datasets/steam_games_format_ok.json")

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 1: genero
#
# def genero( Año: str ): Se ingresa un año y devuelve una lista con los 5 géneros más vendidos en el orden correspondiente.
#
# Example:
# | Year | Genres |
# | -- | - |
# | 2018 | {'Indie': 125, 'Action': 75, 'Adventure': 74, 'Casual': 45, 'Simulation': 43} |
# | 2016 | {'Indie': 4106, 'Action': 2544, 'Casual': 2141, 'Adventure': 2042, 'Simulation': 1666} |
#
# For this case the only thing that matters to us is "genres" and "year" columns, so we can drop the other ones.

# %%
generoEndpointDf = gamesWithYearDf[['genres', 'year']]
generoEndpointDf.head()
# Out:
#                                               genres  year
# 0      [Action, Casual, Indie, Simulation, Strategy]  2018
# 1               [Free to Play, Indie, RPG, Strategy]  2018
# 2  [Casual, Free to Play, Indie, Simulation, Sports]  2017
# 3                        [Action, Adventure, Casual]  2017
# 5                    [Action, Adventure, Simulation]  2018

# %% [markdown]
# Now we can drop all the columns that have a NaN in any of the two columns because they will bring no information to the scope of the genero function.

# %%
generoEndpointDf.describe()
# Out:
#                year
# count  29965.000000
# mean    2014.794727
# std        5.532999
# min     1970.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2756.000000

# %%
generoEndpointDf.isna().sum()
# Out:
# genres    1234
# year         0
# dtype: int64

# %%
generoEndpointDf = generoEndpointDf.dropna()

# %%
generoEndpointDf.isna().sum()
# Out:
# genres    0
# year      0
# dtype: int64

# %% [markdown]
# ### Genre
#
# Each game can have various genres, we can see this in the "genres" column because it is filled with lists.
#
# For this reason we need to explode it so we can count all the genres separately.

# %%
genresCompleteList = generoEndpointDf.explode(column=['genres'])['genres'].unique()
print(genresCompleteList)
print(genresCompleteList.shape)
# Out:
# ['Action' 'Casual' 'Indie' 'Simulation' 'Strategy' 'Free to Play' 'RPG'
#  'Sports' 'Adventure' 'Racing' 'Massively Multiplayer' 'Early Access'
#  'Animation &amp; Modeling' 'Video Production' 'Web Publishing'
#  'Education' 'Software Training' 'Utilities' 'Design &amp; Illustration'
#  'Audio Production' 'Photo Editing' 'Accounting']
# (22,)

# %%
generoEndpointDf.shape
# Out:
# (28731, 2)

# %%
generoEndpointDf = generoEndpointDf.explode('genres')
generoEndpointDf.head()
# Out:
#        genres  year
# 0      Action  2018
# 0      Casual  2018
# 0       Indie  2018
# 0  Simulation  2018
# 0    Strategy  2018

# %%
generoEndpointDf.shape
# Out:
# (71213, 2)

# %% [markdown]
# Now we can make a Groupby to get all the genres of each year. Then unstack it and have a new Data Frame with the data we desire.

# %%
generoEndpointDf2 = generoEndpointDf.groupby(by=['year', 'genres'])['genres'].count()
generoEndpointDf2.tail()
# Out:
# year  genres
# 2021  Indie           1
#       RPG             1
# 2756  Casual          1
#       Early Access    1
#       Indie           1
# Name: genres, dtype: int64

# %%
generoEndpointDf3 = generoEndpointDf2.unstack(level=1, fill_value=0)
generoEndpointDf3.head()
# Out:
# genres  Accounting  Action  Adventure  Animation &amp; Modeling
# year
# 1983             0       1          1                         0  \
# 1984             0       1          1                         0
# 1985             0       0          0                         0
# 1986             0       0          1                         0
# 1987             0       0          3                         0
#
# genres  Audio Production  Casual  Design &amp; Illustration  Early Access
# year
# 1983                   0       1                          0             0  \
# 1984                   0       2                          0             0
# 1985                   0       0                          0             0
# 1986                   0       1                          0             0
# 1987                   0       0                          0             0
#
# genres  Education  Free to Play  ...  Photo Editing  RPG  Racing  Simulation
# year                             ...
# 1983            0             0  ...              0    0       0           0  \
# 1984            0             0  ...              0    0       0           0
# 1985            0             0  ...              0    0       0           1
# 1986            0             0  ...              0    1       0           1
# 1987            0             0  ...              0    0       0           2
#
# genres  Software Training  Sports  Strategy  Utilities  Video Production
# year
# 1983                    0       0         0          0                 0  \
# 1984                    0       0         0          0                 0
# 1985                    0       0         0          0                 0
# 1986                    0       0         0          0                 0
# 1987                    0       0         0          0                 0
#
# genres  Web Publishing
# year
# 1983                 0
# 1984                 0
# 1985                 0
# 1986                 0
# 1987                 0
#
# [5 rows x 22 columns]

# %%
# Now we have exactly what we need.
generoEndpointDict = generoEndpointDf3.to_dict(orient='index')
generoEndpointDict
# Out:
# {1983: {'Accounting': 0,
#   'Action': 1,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1984: {'Accounting': 0,
#   'Action': 1,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 2,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1985: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 1,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1986: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 1,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1987: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 3,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1988: {'Accounting': 0,
#   'Action': 1,
#   'Adventure': 2,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 2,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1989: {'Accounting': 0,
#   'Action': 2,
#   'Adventure': 5,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 3,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1990: {'Accounting': 0,
#   'Action': 3,
#   'Adventure': 5,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 4,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 1,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1991: {'Accounting': 0,
#   'Action': 6,
#   'Adventure': 8,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 0,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 3,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1992: {'Accounting': 0,
#   'Action': 5,
#   'Adventure': 10,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 4,
#   'Racing': 0,
#   'Simulation': 1,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 2,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1993: {'Accounting': 0,
#   'Action': 13,
#   'Adventure': 15,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 3,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 0,
#   'Simulation': 4,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 3,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1994: {'Accounting': 0,
#   'Action': 20,
#   'Adventure': 13,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 3,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 2,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 4,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1995: {'Accounting': 0,
#   'Action': 15,
#   'Adventure': 11,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 4,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 2,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 3,
#   'Racing': 2,
#   'Simulation': 3,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 7,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1996: {'Accounting': 0,
#   'Action': 13,
#   'Adventure': 16,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 8,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 3,
#   'Simulation': 3,
#   'Software Training': 0,
#   'Sports': 1,
#   'Strategy': 6,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1997: {'Accounting': 0,
#   'Action': 16,
#   'Adventure': 16,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 8,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 6,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 4,
#   'Racing': 2,
#   'Simulation': 2,
#   'Software Training': 0,
#   'Sports': 1,
#   'Strategy': 9,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1998: {'Accounting': 0,
#   'Action': 22,
#   'Adventure': 15,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 8,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 5,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 4,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 12,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1999: {'Accounting': 0,
#   'Action': 26,
#   'Adventure': 6,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 5,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 4,
#   'Massively Multiplayer': 1,
#   'Photo Editing': 0,
#   'RPG': 9,
#   'Racing': 3,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 16,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2000: {'Accounting': 0,
#   'Action': 18,
#   'Adventure': 8,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 6,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 4,
#   'Racing': 1,
#   'Simulation': 7,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 8,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2001: {'Accounting': 0,
#   'Action': 25,
#   'Adventure': 14,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 7,
#   'Design &amp; Illustration': 0,
#   'Early Access': 1,
#   'Education': 0,
#   'Free to Play': 3,
#   'Indie': 9,
#   'Massively Multiplayer': 4,
#   'Photo Editing': 0,
#   'RPG': 7,
#   'Racing': 0,
#   'Simulation': 13,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 26,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2002: {'Accounting': 0,
#   'Action': 21,
#   'Adventure': 7,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 4,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 5,
#   'Racing': 0,
#   'Simulation': 5,
#   'Software Training': 0,
#   'Sports': 1,
#   'Strategy': 16,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2003: {'Accounting': 0,
#   'Action': 34,
#   'Adventure': 20,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 7,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 2,
#   'Indie': 10,
#   'Massively Multiplayer': 2,
#   'Photo Editing': 0,
#   'RPG': 11,
#   'Racing': 2,
#   'Simulation': 4,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 26,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2004: {'Accounting': 0,
#   'Action': 28,
#   'Adventure': 11,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 6,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 5,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 6,
#   'Racing': 1,
#   'Simulation': 10,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 24,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2005: {'Accounting': 0,
#   'Action': 38,
#   'Adventure': 15,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 10,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 3,
#   'Indie': 10,
#   'Massively Multiplayer': 1,
#   'Photo Editing': 0,
#   'RPG': 16,
#   'Racing': 8,
#   'Simulation': 9,
#   'Software Training': 0,
#   'Sports': 3,
#   'Strategy': 25,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 1},
#  2006: {'Accounting': 0,
#   'Action': 43,
#   'Adventure': 21,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 27,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 3,
#   'Indie': 22,
#   'Massively Multiplayer': 4,
#   'Photo Editing': 1,
#   'RPG': 12,
#   'Racing': 11,
#   'Simulation': 22,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 46,
#   'Utilities': 2,
#   'Video Production': 1,
#   'Web Publishing': 0},
#  2007: {'Accounting': 0,
#   'Action': 58,
#   'Adventure': 27,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 2,
#   'Casual': 35,
#   'Design &amp; Illustration': 1,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 7,
#   'Indie': 30,
#   'Massively Multiplayer': 4,
#   'Photo Editing': 1,
#   'RPG': 21,
#   'Racing': 8,
#   'Simulation': 27,
#   'Software Training': 0,
#   'Sports': 2,
#   'Strategy': 33,
#   'Utilities': 1,
#   'Video Production': 1,
#   'Web Publishing': 1},
#  2008: {'Accounting': 0,
#   'Action': 46,
#   'Adventure': 51,
#   'Animation &amp; Modeling': 1,
#   'Audio Production': 0,
#   'Casual': 58,
#   'Design &amp; Illustration': 1,
#   'Early Access': 0,
#   'Education': 1,
#   'Free to Play': 6,
#   'Indie': 55,
#   'Massively Multiplayer': 5,
#   'Photo Editing': 0,
#   'RPG': 27,
#   'Racing': 14,
#   'Simulation': 24,
#   'Software Training': 1,
#   'Sports': 5,
#   'Strategy': 35,
#   'Utilities': 1,
#   'Video Production': 0,
#   'Web Publishing': 1},
#  2009: {'Accounting': 0,
#   'Action': 86,
#   'Adventure': 54,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 67,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 4,
#   'Indie': 70,
#   'Massively Multiplayer': 2,
#   'Photo Editing': 0,
#   'RPG': 33,
#   'Racing': 10,
#   'Simulation': 83,
#   'Software Training': 0,
#   'Sports': 9,
#   'Strategy': 73,
#   'Utilities': 1,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2010: {'Accounting': 0,
#   'Action': 150,
#   'Adventure': 85,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 70,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 4,
#   'Free to Play': 7,
#   'Indie': 110,
#   'Massively Multiplayer': 2,
#   'Photo Editing': 0,
#   'RPG': 56,
#   'Racing': 11,
#   'Simulation': 57,
#   'Software Training': 1,
#   'Sports': 4,
#   'Strategy': 106,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2011: {'Accounting': 0,
#   'Action': 223,
#   'Adventure': 87,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 97,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 12,
#   'Indie': 179,
#   'Massively Multiplayer': 9,
#   'Photo Editing': 0,
#   'RPG': 89,
#   'Racing': 21,
#   'Simulation': 86,
#   'Software Training': 0,
#   'Sports': 11,
#   'Strategy': 173,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2012: {'Accounting': 0,
#   'Action': 505,
#   'Adventure': 191,
#   'Animation &amp; Modeling': 3,
#   'Audio Production': 0,
#   'Casual': 240,
#   'Design &amp; Illustration': 1,
#   'Early Access': 2,
#   'Education': 0,
#   'Free to Play': 41,
#   'Indie': 347,
#   'Massively Multiplayer': 21,
#   'Photo Editing': 1,
#   'RPG': 136,
#   'Racing': 30,
#   'Simulation': 281,
#   'Software Training': 0,
#   'Sports': 6,
#   'Strategy': 299,
#   'Utilities': 2,
#   'Video Production': 2,
#   'Web Publishing': 1},
#  2013: {'Accounting': 0,
#   'Action': 604,
#   'Adventure': 331,
#   'Animation &amp; Modeling': 10,
#   'Audio Production': 6,
#   'Casual': 286,
#   'Design &amp; Illustration': 28,
#   'Early Access': 10,
#   'Education': 9,
#   'Free to Play': 78,
#   'Indie': 469,
#   'Massively Multiplayer': 35,
#   'Photo Editing': 0,
#   'RPG': 214,
#   'Racing': 47,
#   'Simulation': 375,
#   'Software Training': 7,
#   'Sports': 46,
#   'Strategy': 411,
#   'Utilities': 17,
#   'Video Production': 4,
#   'Web Publishing': 30},
#  2014: {'Accounting': 0,
#   'Action': 1022,
#   'Adventure': 684,
#   'Animation &amp; Modeling': 26,
#   'Audio Production': 17,
#   'Casual': 715,
#   'Design &amp; Illustration': 60,
#   'Early Access': 78,
#   'Education': 13,
#   'Free to Play': 169,
#   'Indie': 1358,
#   'Massively Multiplayer': 98,
#   'Photo Editing': 4,
#   'RPG': 566,
#   'Racing': 79,
#   'Simulation': 707,
#   'Software Training': 12,
#   'Sports': 101,
#   'Strategy': 570,
#   'Utilities': 33,
#   'Video Production': 9,
#   'Web Publishing': 44},
#  2015: {'Accounting': 2,
#   'Action': 2033,
#   'Adventure': 1502,
#   'Animation &amp; Modeling': 38,
#   'Audio Production': 17,
#   'Casual': 1217,
#   'Design &amp; Illustration': 88,
#   'Early Access': 224,
#   'Education': 25,
#   'Free to Play': 333,
#   'Indie': 2828,
#   'Massively Multiplayer': 182,
#   'Photo Editing': 29,
#   'RPG': 972,
#   'Racing': 162,
#   'Simulation': 1173,
#   'Software Training': 35,
#   'Sports': 179,
#   'Strategy': 1087,
#   'Utilities': 87,
#   'Video Production': 24,
#   'Web Publishing': 35},
#  2016: {'Accounting': 1,
#   'Action': 2544,
#   'Adventure': 2042,
#   'Animation &amp; Modeling': 52,
#   'Audio Production': 24,
#   'Casual': 2141,
#   'Design &amp; Illustration': 123,
#   'Early Access': 363,
#   'Education': 29,
#   'Free to Play': 555,
#   'Indie': 4106,
#   'Massively Multiplayer': 310,
#   'Photo Editing': 15,
#   'RPG': 1272,
#   'Racing': 283,
#   'Simulation': 1666,
#   'Software Training': 21,
#   'Sports': 355,
#   'Strategy': 1607,
#   'Utilities': 92,
#   'Video Production': 31,
#   'Web Publishing': 61},
#  2017: {'Accounting': 4,
#   'Action': 3556,
#   'Adventure': 2839,
#   'Animation &amp; Modeling': 53,
#   'Audio Production': 27,
#   'Casual': 3172,
#   'Design &amp; Illustration': 157,
#   'Early Access': 733,
#   'Education': 43,
#   'Free to Play': 786,
#   'Indie': 5994,
#   'Massively Multiplayer': 422,
#   'Photo Editing': 26,
#   'RPG': 1927,
#   'Racing': 371,
#   'Simulation': 2039,
#   'Software Training': 28,
#   'Sports': 512,
#   'Strategy': 2271,
#   'Utilities': 101,
#   'Video Production': 44,
#   'Web Publishing': 94},
#  2018: {'Accounting': 0,
#   'Action': 75,
#   'Adventure': 74,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 45,
#   'Design &amp; Illustration': 1,
#   'Early Access': 33,
#   'Education': 1,
#   'Free to Play': 13,
#   'Indie': 125,
#   'Massively Multiplayer': 3,
#   'Photo Editing': 0,
#   'RPG': 40,
#   'Racing': 5,
#   'Simulation': 43,
#   'Software Training': 0,
#   'Sports': 12,
#   'Strategy': 28,
#   'Utilities': 1,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2019: {'Accounting': 0,
#   'Action': 2,
#   'Adventure': 3,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 1,
#   'Education': 0,
#   'Free to Play': 1,
#   'Indie': 3,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 2,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 1,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2021: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 1,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 1,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2756: {'Accounting': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 1,
#   'Design &amp; Illustration': 0,
#   'Early Access': 1,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 1,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0}}

# %% [markdown]
# Sort by values.

# %%
generoEndpointDict_sorted = sort_dic(generoEndpointDict)
generoEndpointDict_sorted
# Out:
# {1983: {'Action': 1,
#   'Adventure': 1,
#   'Casual': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1984: {'Casual': 2,
#   'Action': 1,
#   'Adventure': 1,
#   'Indie': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1985: {'Simulation': 1,
#   'Accounting': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1986: {'Adventure': 1,
#   'Casual': 1,
#   'Indie': 1,
#   'RPG': 1,
#   'Simulation': 1,
#   'Accounting': 0,
#   'Action': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1987: {'Adventure': 3,
#   'Simulation': 2,
#   'Accounting': 0,
#   'Action': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1988: {'Adventure': 2,
#   'Simulation': 2,
#   'Strategy': 2,
#   'Action': 1,
#   'Indie': 1,
#   'RPG': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1989: {'Adventure': 5,
#   'Simulation': 3,
#   'Action': 2,
#   'RPG': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1990: {'Adventure': 5,
#   'Simulation': 4,
#   'Action': 3,
#   'RPG': 1,
#   'Strategy': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1991: {'Adventure': 8,
#   'Action': 6,
#   'Strategy': 3,
#   'RPG': 2,
#   'Simulation': 2,
#   'Casual': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1992: {'Adventure': 10,
#   'Action': 5,
#   'RPG': 4,
#   'Strategy': 2,
#   'Casual': 1,
#   'Indie': 1,
#   'Simulation': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1993: {'Adventure': 15,
#   'Action': 13,
#   'Simulation': 4,
#   'Casual': 3,
#   'Strategy': 3,
#   'RPG': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Indie': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1994: {'Action': 20,
#   'Adventure': 13,
#   'Simulation': 7,
#   'Strategy': 4,
#   'Casual': 3,
#   'RPG': 2,
#   'Racing': 2,
#   'Indie': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1995: {'Action': 15,
#   'Adventure': 11,
#   'Strategy': 7,
#   'Casual': 4,
#   'RPG': 3,
#   'Simulation': 3,
#   'Indie': 2,
#   'Racing': 2,
#   'Sports': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1996: {'Adventure': 16,
#   'Action': 13,
#   'Casual': 8,
#   'Strategy': 6,
#   'Indie': 3,
#   'Racing': 3,
#   'Simulation': 3,
#   'RPG': 2,
#   'Free to Play': 1,
#   'Sports': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1997: {'Action': 16,
#   'Adventure': 16,
#   'Strategy': 9,
#   'Casual': 8,
#   'Indie': 6,
#   'RPG': 4,
#   'Racing': 2,
#   'Simulation': 2,
#   'Sports': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1998: {'Action': 22,
#   'Adventure': 15,
#   'Strategy': 12,
#   'Casual': 8,
#   'Simulation': 7,
#   'Indie': 5,
#   'Racing': 4,
#   'RPG': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  1999: {'Action': 26,
#   'Strategy': 16,
#   'RPG': 9,
#   'Simulation': 7,
#   'Adventure': 6,
#   'Casual': 5,
#   'Indie': 4,
#   'Racing': 3,
#   'Sports': 2,
#   'Free to Play': 1,
#   'Massively Multiplayer': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2000: {'Action': 18,
#   'Adventure': 8,
#   'Strategy': 8,
#   'Simulation': 7,
#   'Casual': 6,
#   'RPG': 4,
#   'Indie': 3,
#   'Racing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2001: {'Strategy': 26,
#   'Action': 25,
#   'Adventure': 14,
#   'Simulation': 13,
#   'Indie': 9,
#   'Casual': 7,
#   'RPG': 7,
#   'Massively Multiplayer': 4,
#   'Free to Play': 3,
#   'Early Access': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2002: {'Action': 21,
#   'Strategy': 16,
#   'Adventure': 7,
#   'RPG': 5,
#   'Simulation': 5,
#   'Casual': 4,
#   'Indie': 3,
#   'Sports': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2003: {'Action': 34,
#   'Strategy': 26,
#   'Adventure': 20,
#   'RPG': 11,
#   'Indie': 10,
#   'Casual': 7,
#   'Simulation': 4,
#   'Free to Play': 2,
#   'Massively Multiplayer': 2,
#   'Racing': 2,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2004: {'Action': 28,
#   'Strategy': 24,
#   'Adventure': 11,
#   'Simulation': 10,
#   'Casual': 6,
#   'RPG': 6,
#   'Indie': 5,
#   'Free to Play': 1,
#   'Racing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2005: {'Action': 38,
#   'Strategy': 25,
#   'RPG': 16,
#   'Adventure': 15,
#   'Casual': 10,
#   'Indie': 10,
#   'Simulation': 9,
#   'Racing': 8,
#   'Free to Play': 3,
#   'Sports': 3,
#   'Massively Multiplayer': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0},
#  2006: {'Strategy': 46,
#   'Action': 43,
#   'Casual': 27,
#   'Indie': 22,
#   'Simulation': 22,
#   'Adventure': 21,
#   'RPG': 12,
#   'Racing': 11,
#   'Massively Multiplayer': 4,
#   'Free to Play': 3,
#   'Sports': 2,
#   'Utilities': 2,
#   'Photo Editing': 1,
#   'Video Production': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Software Training': 0,
#   'Web Publishing': 0},
#  2007: {'Action': 58,
#   'Casual': 35,
#   'Strategy': 33,
#   'Indie': 30,
#   'Adventure': 27,
#   'Simulation': 27,
#   'RPG': 21,
#   'Racing': 8,
#   'Free to Play': 7,
#   'Massively Multiplayer': 4,
#   'Audio Production': 2,
#   'Sports': 2,
#   'Design &amp; Illustration': 1,
#   'Photo Editing': 1,
#   'Utilities': 1,
#   'Video Production': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Software Training': 0},
#  2008: {'Casual': 58,
#   'Indie': 55,
#   'Adventure': 51,
#   'Action': 46,
#   'Strategy': 35,
#   'RPG': 27,
#   'Simulation': 24,
#   'Racing': 14,
#   'Free to Play': 6,
#   'Massively Multiplayer': 5,
#   'Sports': 5,
#   'Animation &amp; Modeling': 1,
#   'Design &amp; Illustration': 1,
#   'Education': 1,
#   'Software Training': 1,
#   'Utilities': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Audio Production': 0,
#   'Early Access': 0,
#   'Photo Editing': 0,
#   'Video Production': 0},
#  2009: {'Action': 86,
#   'Simulation': 83,
#   'Strategy': 73,
#   'Indie': 70,
#   'Casual': 67,
#   'Adventure': 54,
#   'RPG': 33,
#   'Racing': 10,
#   'Sports': 9,
#   'Free to Play': 4,
#   'Massively Multiplayer': 2,
#   'Utilities': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2010: {'Action': 150,
#   'Indie': 110,
#   'Strategy': 106,
#   'Adventure': 85,
#   'Casual': 70,
#   'Simulation': 57,
#   'RPG': 56,
#   'Racing': 11,
#   'Free to Play': 7,
#   'Education': 4,
#   'Sports': 4,
#   'Massively Multiplayer': 2,
#   'Software Training': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Photo Editing': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2011: {'Action': 223,
#   'Indie': 179,
#   'Strategy': 173,
#   'Casual': 97,
#   'RPG': 89,
#   'Adventure': 87,
#   'Simulation': 86,
#   'Racing': 21,
#   'Free to Play': 12,
#   'Sports': 11,
#   'Massively Multiplayer': 9,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2012: {'Action': 505,
#   'Indie': 347,
#   'Strategy': 299,
#   'Simulation': 281,
#   'Casual': 240,
#   'Adventure': 191,
#   'RPG': 136,
#   'Free to Play': 41,
#   'Racing': 30,
#   'Massively Multiplayer': 21,
#   'Sports': 6,
#   'Animation &amp; Modeling': 3,
#   'Early Access': 2,
#   'Utilities': 2,
#   'Video Production': 2,
#   'Design &amp; Illustration': 1,
#   'Photo Editing': 1,
#   'Web Publishing': 1,
#   'Accounting': 0,
#   'Audio Production': 0,
#   'Education': 0,
#   'Software Training': 0},
#  2013: {'Action': 604,
#   'Indie': 469,
#   'Strategy': 411,
#   'Simulation': 375,
#   'Adventure': 331,
#   'Casual': 286,
#   'RPG': 214,
#   'Free to Play': 78,
#   'Racing': 47,
#   'Sports': 46,
#   'Massively Multiplayer': 35,
#   'Web Publishing': 30,
#   'Design &amp; Illustration': 28,
#   'Utilities': 17,
#   'Animation &amp; Modeling': 10,
#   'Early Access': 10,
#   'Education': 9,
#   'Software Training': 7,
#   'Audio Production': 6,
#   'Video Production': 4,
#   'Accounting': 0,
#   'Photo Editing': 0},
#  2014: {'Indie': 1358,
#   'Action': 1022,
#   'Casual': 715,
#   'Simulation': 707,
#   'Adventure': 684,
#   'Strategy': 570,
#   'RPG': 566,
#   'Free to Play': 169,
#   'Sports': 101,
#   'Massively Multiplayer': 98,
#   'Racing': 79,
#   'Early Access': 78,
#   'Design &amp; Illustration': 60,
#   'Web Publishing': 44,
#   'Utilities': 33,
#   'Animation &amp; Modeling': 26,
#   'Audio Production': 17,
#   'Education': 13,
#   'Software Training': 12,
#   'Video Production': 9,
#   'Photo Editing': 4,
#   'Accounting': 0},
#  2015: {'Indie': 2828,
#   'Action': 2033,
#   'Adventure': 1502,
#   'Casual': 1217,
#   'Simulation': 1173,
#   'Strategy': 1087,
#   'RPG': 972,
#   'Free to Play': 333,
#   'Early Access': 224,
#   'Massively Multiplayer': 182,
#   'Sports': 179,
#   'Racing': 162,
#   'Design &amp; Illustration': 88,
#   'Utilities': 87,
#   'Animation &amp; Modeling': 38,
#   'Software Training': 35,
#   'Web Publishing': 35,
#   'Photo Editing': 29,
#   'Education': 25,
#   'Video Production': 24,
#   'Audio Production': 17,
#   'Accounting': 2},
#  2016: {'Indie': 4106,
#   'Action': 2544,
#   'Casual': 2141,
#   'Adventure': 2042,
#   'Simulation': 1666,
#   'Strategy': 1607,
#   'RPG': 1272,
#   'Free to Play': 555,
#   'Early Access': 363,
#   'Sports': 355,
#   'Massively Multiplayer': 310,
#   'Racing': 283,
#   'Design &amp; Illustration': 123,
#   'Utilities': 92,
#   'Web Publishing': 61,
#   'Animation &amp; Modeling': 52,
#   'Video Production': 31,
#   'Education': 29,
#   'Audio Production': 24,
#   'Software Training': 21,
#   'Photo Editing': 15,
#   'Accounting': 1},
#  2017: {'Indie': 5994,
#   'Action': 3556,
#   'Casual': 3172,
#   'Adventure': 2839,
#   'Strategy': 2271,
#   'Simulation': 2039,
#   'RPG': 1927,
#   'Free to Play': 786,
#   'Early Access': 733,
#   'Sports': 512,
#   'Massively Multiplayer': 422,
#   'Racing': 371,
#   'Design &amp; Illustration': 157,
#   'Utilities': 101,
#   'Web Publishing': 94,
#   'Animation &amp; Modeling': 53,
#   'Video Production': 44,
#   'Education': 43,
#   'Software Training': 28,
#   'Audio Production': 27,
#   'Photo Editing': 26,
#   'Accounting': 4},
#  2018: {'Indie': 125,
#   'Action': 75,
#   'Adventure': 74,
#   'Casual': 45,
#   'Simulation': 43,
#   'RPG': 40,
#   'Early Access': 33,
#   'Strategy': 28,
#   'Free to Play': 13,
#   'Sports': 12,
#   'Racing': 5,
#   'Massively Multiplayer': 3,
#   'Design &amp; Illustration': 1,
#   'Education': 1,
#   'Utilities': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Photo Editing': 0,
#   'Software Training': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2019: {'Adventure': 3,
#   'Indie': 3,
#   'Action': 2,
#   'RPG': 2,
#   'Early Access': 1,
#   'Free to Play': 1,
#   'Strategy': 1,
#   'Accounting': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Education': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2021: {'Adventure': 1,
#   'Indie': 1,
#   'RPG': 1,
#   'Accounting': 0,
#   'Action': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Casual': 0,
#   'Design &amp; Illustration': 0,
#   'Early Access': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0},
#  2756: {'Casual': 1,
#   'Early Access': 1,
#   'Indie': 1,
#   'Accounting': 0,
#   'Action': 0,
#   'Adventure': 0,
#   'Animation &amp; Modeling': 0,
#   'Audio Production': 0,
#   'Design &amp; Illustration': 0,
#   'Education': 0,
#   'Free to Play': 0,
#   'Massively Multiplayer': 0,
#   'Photo Editing': 0,
#   'RPG': 0,
#   'Racing': 0,
#   'Simulation': 0,
#   'Software Training': 0,
#   'Sports': 0,
#   'Strategy': 0,
#   'Utilities': 0,
#   'Video Production': 0,
#   'Web Publishing': 0}}

# %%
with open("datasets/steam_games_endpoint_1_genero.json", "w") as outfile:
    json.dump(generoEndpointDict_sorted, outfile)

# %% [markdown]
# **TEST**

# %%
def genero(Year: str): 
    """
    Se ingresa un año y devuelve un diccionario con los 5 géneros más vendidos en el orden correspondiente.
    """

    # Read data
    with open("datasets/steam_games_endpoint_1_genero.json") as json_file:
        genres_dict = json.load(json_file)
    # Since data is already sorted, get the first 5 as top 5.
    top5 = dict(list(genres_dict[Year].items())[0:5])
    return top5

genero('2016')
# Out:
# {'Indie': 4106,
#  'Action': 2544,
#  'Casual': 2141,
#  'Adventure': 2042,
#  'Simulation': 1666}

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 2: juegos
#
# def juegos( Año: str ): Se ingresa un año y devuelve una lista con los juegos lanzados en el año.
#
# Example:
# | Year | Games |
# | -- | - |
# | 2018 | ['juego1', 'juego2', ... ] |
# | 2016 | ['juegoX', 'juegoY', ... ] |
#
# For this case the only thing that matters to us is "app_name" and "year" columns, so we can drop the other ones.

# %% [markdown]
# ### Games
#
# Each game has the name on column "app_name". Let's prepare the json.

# %%
juegosEndpointDf = gamesWithYearDf[['app_name', 'year']]
juegosEndpointDf.head()
# Out:
#                   app_name  year
# 0      Lost Summoner Kitty  2018
# 1                Ironbound  2018
# 2  Real Pool 3D - Poolians  2017
# 3                  弹炸人2222  2017
# 5    Battle Royale Trainer  2018

# %%
juegosEndpointDf.shape
# Out:
# (29965, 2)

# %% [markdown]
# Now we can make a Groupby to get all the genres of each year. Then unstack it and have a new Data Frame with the data we desire.

# %%
juegosEndpointDf2 = juegosEndpointDf.groupby(by=['year']).apply(lambda df: list(df['app_name']))

juegosEndpointDf2.tail(20)
# Out:
# year
# 2002    [Arx Fatalis, The Sum of All Fears, Freedom Fo...
# 2003    [Ghost Master®, Railroad Tycoon 3, BloodRayne,...
# 2004    [Rome: Total War™ - Collection, Manhunt, Far C...
# 2005    [Advent Rising, FlatOut, Act of War: Direct Ac...
# 2006    [Disciples II: Gallean's Return, Disciples II:...
# 2007    [Lost Planet™: Extreme Condition, RIP - Trilog...
# 2008    [Command & Conquer: Red Alert 3, Conflict: Den...
# 2009    [PRR Wagon Pack 01, Class 421 London South Eas...
# 2010    [Avencast: Rise of the Mage, Pirates, Vikings,...
# 2011    [Mafia II, Lara Croft GoL: Raziel and Kain Cha...
# 2012    [Hard Reset Extended Edition, Blackwell Unboun...
# 2013    [RIFT, Trine 2: Complete Story, Angelica Weave...
# 2014    [Imagine Earth, BeatBlasters III, Blood of the...
# 2015    [Assault Android Cactus, America's Army: Provi...
# 2016    [Fallen Mage, Of Guards And Thieves, The Inter...
# 2017    [Real Pool 3D - Poolians, 弹炸人2222, RC Plane 3 ...
# 2018    [Lost Summoner Kitty, Ironbound, Battle Royale...
# 2019    [Raji: An Ancient Epic, K'NOSSOS, The Legendar...
# 2021                        [Finding Paradise Soundtrack]
# 2756                                [Puzzle Sisters Foer]
# dtype: object

# %%
juegosEndpointDict = dict(juegosEndpointDf2)

# %%
with open("datasets/steam_games_endpoint_2_juegos.json", "w") as outfile:
    json.dump(juegosEndpointDict, outfile)

# %% [markdown]
# **TEST**

# %%
def juegos( Year: str ):
    """
    Se ingresa un año y devuelve un diccionario con los juegos lanzados en el año.
    """
    # Read data
    with open("datasets/steam_games_endpoint_2_juegos.json") as json_file:
        juegos_dict = json.load(json_file)
    return juegos_dict[Year]

juegos('2015')
# Out:
# ['Assault Android Cactus',
#  "America's Army: Proving Grounds",
#  'The Tower',
#  'Dimmdrive :: Gaming Ramdrive @ 10,000+ MB/s',
#  'Fake Colours',
#  'WolfWars',
#  'Dr.Green',
#  'Vintage Year',
#  'The Race for the White House',
#  'X-Plane 10 AddOn - Carenado - C185F Skywagon',
#  'Rocksmith® 2014 – Linkin Park - “What I’ve Done”',
#  'Rocksmith® 2014 – Linkin Park Song Pack',
#  'Dreaming Sarah OST',
#  'Antisquad: Tasks near the coast of Somalia. Tactics DLC',
#  'Castle',
#  'Antisquad: Tasks in North Korea. Tactics DLC',
#  'ATLAS レジェンドパック',
#  'Ostrich Island',
#  'Adventures of Robinson Crusoe',
#  'Mechs & Mercs: Black Talons',
#  'Urja',
#  'Teddy Floppy Ear - Mountain Adventure',
#  'Su-27: The Ultimate Argument Campaign',
#  'Squirreltopia',
#  'Lara Croft and the Temple of Osiris - Icy Death Pack',
#  'Lara Croft and the Temple of Osiris - Legend Pack',
#  'Lara Croft and the Temple of Osiris - Deus Ex Pack',
#  'Disorder',
#  'Lara Croft and the Temple of Osiris - Hitman Pack',
#  'Avernum 2: Crystal Souls',
#  'Gunslugs 2',
#  "Train Simulator: CrossCountry Class 220 'Voyager' DEMU Add-On",
#  'Tengami',
#  'But to Paint a Universe',
#  'TRISTOY',
#  'Crystal Catacombs',
#  'Aveyond 3-3: The Lost Orb',
#  'Call of Duty®: Advanced Warfare - Netherlands Exoskeleton Pack',
#  'Call of Duty®: Advanced Warfare - Australia Exoskeleton Pack',
#  'Call of Duty®: Advanced Warfare - France Exoskeleton Pack',
#  'Call of Duty®: Advanced Warfare - Hot Rod Exoskeleton Pack',
#  'Call of Duty®: Advanced Warfare - Canada Exoskeleton Pack',
#  'Call of Duty®: Advanced Warfare - Barong Exoskeleton Pack',
#  'Chronicles of a Dark Lord: Episode II War of The Abyss',
#  'Train Simulator: The Story of Forest Rail Route Add-On',
#  'HuniePop',
#  'Cat Goes Fishing',
#  'Middle-earth: Shadow of Mordor - Captain of the Watch Character Skin',
#  'Resident Evil / biohazard HD REMASTER',
#  'Deity Quest Demo',
#  'Deity Quest',
#  'Deity Quest Soundtrack',
#  'Deity Quest Extended',
#  'PAYDAY 2: The Bomb Heists',
#  'PAYDAY 2: Dragan Character Pack',
#  'PARTICLE MACE',
#  'Among Ripples',
#  'Without Within - Extra Edition',
#  'TorqueL',
#  'PARTICLE MACE - Soundtrack',
#  'Stranded Deep',
#  'Guild Commander',
#  'Grey Goo',
#  'Without Within',
#  'Gravity Ghost - Soundtrack',
#  'Bridge Creator 2015',
#  'Rocksmith® 2014 – Three Days Grace - “Never Too Late”',
#  'Rocksmith® 2014 – Three Days Grace - “Just Like You”',
#  'Rocksmith® 2014 – Three Days Grace - “Break”',
#  'Rocksmith® 2014 – Three Days Grace Song Pack',
#  'Trials Fusion - Fire in the Deep',
#  'Lady Hammerlock the Baroness Pack',
#  'Middle-earth: Shadow of Mordor - The Dark Ranger Character Skin',
#  'Middle-earth: Shadow of Mordor - Blood Hunters Warband',
#  'Ghost Pirates of Vooju Island',
#  'My Family Creative Studio',
#  'X-Plane 10 AddOn - Carenado - C337H Skymaster',
#  'The Quivering',
#  'Wildlife Creative Studio',
#  'Hypnosis',
#  'Dead State Demo',
#  'Tulpa',
#  'Firefly Online Cortex',
#  'The Lady',
#  'Pix the Cat',
#  'Fantasy Grounds - Top-down Tokens - Heroic 1',
#  'Fantasy Grounds - Top-down Tokens - Heroic 2',
#  'Fantasy Grounds - Fiery Dragon Counter Collection: Heroic 2',
#  'Fantasy Grounds - Top-down Tokens - Heroic 5',
#  'Fantasy Grounds - Top-down Tokens - Heroic 3',
#  'Fantasy Grounds - Top-down Tokens - Heroic 4',
#  'Forward to the Sky Demo',
#  '10 Years After',
#  'Fantasy Grounds - Fiery Dragon Counter Collection: Epic 1',
#  'Lara Croft and the Temple of Osiris - Twisted Gears Pack',
#  'Overture',
#  'Overture OST',
#  'Ancient Planet Tower Defense',
#  'Apotheon',
#  'Super Pixalo',
#  'Terra Incognita ~ Chapter One: The Descendant',
#  'Apotheon: Original Soundtrack',
#  'Middle-earth: Shadow of Mordor - Test of Power',
#  'Astray',
#  'TOTM',
#  'Rocksmith® 2014 – Cinderella - “Don’t Know What You Got (Till It’s Gone)”',
#  'Rocksmith® 2014 – Tesla - “Love Song”',
#  'Rocksmith® 2014 – Extreme - “More Than Words”',
#  'Rocksmith® 2014 – Boston - “Amanda”',
#  'Sentinels of the Multiverse - Mini-Pack 1',
#  'Sentinels of the Multiverse - Soundtrack (Volume 1)',
#  'Moorhuhn (Crazy Chicken)',
#  'Train Simulator: Union Pacific GP30 Loco Add-On',
#  'Destination Sol',
#  'Fractured Soul',
#  'Forsaken Isle',
#  'Barter Empire',
#  'Bloop Reloaded',
#  'SUNLESS SEA',
#  'Crystal Story II',
#  'Tropico 5 - Gone Green',
#  'The Asskickers-Steam Edition',
#  'Rocksmith® 2014 – Seether Song Pack',
#  'Universal Combat CE',
#  'Pixel Heroes: Byte & Magic',
#  'HuniePop Original Soundtrack',
#  'Plazma Being',
#  'Check vs. Mate - Floating Island DLC',
#  'Time Rifters Demo',
#  'Samudai',
#  'HIT',
#  'Lex Mortis',
#  'Steam and Metal',
#  'Dark Forester',
#  'Steam and Metal Demo',
#  'MyRPG Master',
#  'Train Simulator: Midland Main Line London-Bedford Route Add-On',
#  'Spirit Run - Fire vs. Ice',
#  'Damned Nation Reborn',
#  'The Crew™ Speed Car Pack',
#  'Barbarian Brawl',
#  'Far Cry® 4 – Overrun',
#  'Cults and Daggers',
#  'The Legend of Candlewind: Nights & Candles',
#  'The Lady - Soundtrack',
#  'Crashed Lander Demo',
#  'Hyphen',
#  'Hyphen Original Soundtrack',
#  'Evolution II: Fighting for Survival',
#  'Janky Tanks',
#  'On A Roll 3D',
#  'Total War: ATTILA - Viking Forefathers Culture Pack',
#  'Morningstar: Descent to Deadrock Demo',
#  'Morningstar: Descent to Deadrock',
#  'Hand of Fate',
#  'LEGO Batman 3: Beyond Gotham DLC: Bizarro',
#  'Stay Dead Evolution Demo',
#  'Rocksmith® 2014 – Jane’s Addiction - “Been Caught Stealing”',
#  'Rocksmith® 2014 – Jane’s Addiction - “Just Because”',
#  'Rocksmith® 2014 – Jane’s Addiction - “Superhero”',
#  'Rocksmith® 2014 – Jane’s Addiction - “Mountain Song”',
#  'Rocksmith® 2014 – Jane’s Addiction - “Jane Says”',
#  'Rocksmith® 2014 – Jane’s Addiction Song Pack',
#  'Paparazzi',
#  'Hotline Miami 2: Wrong Number Digital Comic',
#  'Chainsaw Warrior: Lords of the Night',
#  'Cell HD: emergence',
#  'Pixel Puzzles 2: Birds',
#  'Warhammer 40,000 : Armageddon - Untold Battles',
#  'Hot Tin Roof: The Cat That Wore A Fedora',
#  'Boring Man: Premium!',
#  'Tormentum - Dark Sorrow Demo',
#  'Influent DLC - Português do Brasil [Learn Brazilian Portuguese]',
#  'Hero of the Kingdom II',
#  'Catacomb Kids',
#  'Moorhuhn Invasion (Crazy Chicken Invasion)',
#  'Fasaria World: Browser MO',
#  'Odysseus: Long Way Home',
#  'Night Shift',
#  'Trash TV',
#  'There Came an Echo: Original Soundtrack',
#  'Trials Fusion - Fault One Zero',
#  'Fuse - Free Brute Character Pack',
#  'Raid Mode: Weapon Storage B',
#  'Raid Mode: Parts Storage A',
#  'Raid Mode: Weapon Storage C',
#  'Raid Mode: Weapon Storage A',
#  'Oscura: Lost Light',
#  'Raid Mode: Parts Storage C',
#  'Costume Pack',
#  'Raid Mode: Parts Storage B',
#  'Raid Mode: Album Storage B',
#  'Raid Mode: Album Storage A',
#  "Natalia's Lottie Suit Costume",
#  "Barry's Commandant Costume",
#  "Claire's Rodeo Costume",
#  'Raid Mode: Album Storage C',
#  'Raid Mode Character: Albert Wesker',
#  'Raid Mode Character: HUNK',
#  "Moira's Urban Ninja Costume",
#  'Resident Evil Revelations 2 / Biohazard Revelations 2',
#  'Raid Mode: Throwback Map Pack',
#  'TownCraft',
#  'Starlaxis Supernova Edition Demo',
#  'Airships: Conquer the Skies',
#  'Over 9000 Zombies!',
#  "Oddworld: New 'n' Tasty - Scrub Abe Costume",
#  'The Great Fusion',
#  'Isbarah',
#  "Oddworld: New 'n' Tasty",
#  "Oddworld: New 'n' Tasty - Alf's Escape DLC",
#  'A Good Snowman Is Hard To Build',
#  'Homeworld Remastered Collection',
#  'TableTop Cricket',
#  'Expansion - Europa Universalis IV: El Dorado',
#  'Europa Universalis IV: Guns, Drums and Steel Volume 2 Music Pack',
#  'Night Mysteries: The Amphora Prisoner',
#  'NeXus: One Core',
#  'Never Alone: Original Soundtrack',
#  "PAYDAY 2: The Butcher's AK/CAR Mod Pack",
#  'Agarest 2 - Bundle #1',
#  'DRAGON BALL XENOVERSE',
#  'DYNASTY WARRIORS® 8 Empires',
#  'DW8E: Edit Parts - Face, Hair & Accessary Pack',
#  'DW8E: Special Costume Pack 1',
#  'DW8E: Special Costume Pack 2',
#  'DW8E: Old Costume Pack 1',
#  'DW8E: Old Costume Pack 2',
#  'Rocksmith® 2014 – The Cars - “Good Times Roll”',
#  'Rocksmith® 2014 – The Cars - “Just What I Needed”',
#  'Rocksmith® 2014 – The Cars - “You’re All I’ve Got Tonight”',
#  'Rocksmith® 2014 – The Cars - “Let’s Go”',
#  'Rocksmith® 2014 – The Cars - “Bye Bye Love”',
#  'Rocksmith® 2014 – The Cars Song Pack',
#  'Shiftlings',
#  'Call of Duty®: Advanced Warfare - Havoc',
#  'White Night',
#  'Tallowmere',
#  'Damnation City of Death',
#  'Mighty Dungeons',
#  'HIS (Heroes In the Sky)',
#  'HIS - Blueprint Pack',
#  'HIS - Rare Flight Pack',
#  'HIS - Extend  Pack',
#  'RER2 Episode Two: Contemplation',
#  'Marble Age',
#  'HIS - Battle Pack',
#  'Talisman: Digital Edition - Season Pass',
#  'Talisman - Character Pack #9 - Shape Shifter',
#  'Pixel: ru²',
#  'Pixel: ru² Demo',
#  'Pixel: ru² | Soundtrack',
#  'ARMED SEVEN',
#  'PAYDAY 2: The OVERKILL Pack',
#  'This War of Mine - War Child Charity DLC',
#  'Shelter 2',
#  'Frankenstein: Master of Death',
#  'The Fool',
#  'Pneuma: Breath of Life - Soundtrack',
#  'After Reset RPG Demo',
#  'Night Mysteries: The Amphora Prisoner - Official Soundtrack',
#  'Assassin’s Creed® Rogue - Time Saver: Activities Pack',
#  'Assetto Corsa - Dream Pack 1',
#  'The Albino Hunter',
#  'Assassin’s Creed® Rogue - Time Saver: Resource Pack',
#  'HIS - [P-38J] Lightning R.Bong Pack',
#  'Starship Traveller',
#  'Drizzlepath',
#  'Train Simulator: MRCE BR 185.5 Loco Add-On',
#  'Supreme League of Patriots Issue 1: A Patriot Is Born Demo',
#  'Automation - The Car Company Tycoon Game',
#  "Sid Meier's Starships",
#  'Spirit of War',
#  'Call of Duty®: Advanced Warfare - Championship Premium Personalization Pack',
#  'FSX: Steam Edition - Piper PA-28RT-201 Arrow IV Add-On',
#  'Agarest 2 - Bundle #3',
#  'Bermuda',
#  'Oceanhorn: Monster of Uncharted Seas',
#  'Bermuda Demo',
#  'Battletank LOBA',
#  'StarCrawlers Soundtrack',
#  'Woolfe - The Red Hood Diaries',
#  'Enemy',
#  'Rocksmith® 2014 – Stiff Little Fingers - “Alternative Ulster”',
#  'Rocksmith® 2014 – The Cranberries - “Zombie”',
#  'Rocksmith® 2014 – Dropkick Murphys - “I’m Shipping Up to Boston”',
#  'Spellbind',
#  'Rocksmith® 2014 – Villagers - “Becoming a Jackal”',
#  'Eron',
#  'Rocksmith® 2014 – Flogging Molly - “Drunken Lullabies”',
#  'Three Fourths Home: Extended Edition - Art Book & Soundtrack',
#  'Dead Rising 2 - Psychopath Skills Pack',
#  'Glorkian Warrior: The Trials Of Glork',
#  'Trapped Dead: Lockdown',
#  'Factions: Origins of Malu',
#  'Official Guide - Millennium',
#  'World of Subways 4 – New York Line 7',
#  'Euro Truck Simulator 2 - Russian Paint Jobs Pack',
#  '12 Labours of Hercules',
#  "Time Tracer's DLC Package",
#  'Exowar',
#  'Dungeon Highway',
#  "Axis Game Factory's AGFPRO - Voxel Sculpt DLC",
#  'Blade Kitten: Soundtrack + Remixes',
#  '3d Bridges',
#  'Blade Kitten: Comic Pack - Dirty Angels',
#  'Total War: ATTILA - Celts Culture Pack',
#  'Etherium',
#  'Aquadelic GT',
#  'Red Lake',
#  'Band of Drones',
#  'Influent DLC - Suomi [Learn Finnish]',
#  'FLAMBERGE',
#  'HIS - [Avatar] XF5U Pack',
#  '1931: Scheherazade at the Library of Pergamum',
#  "Train Simulator: Grand Central Class 180 'Adelante' DMU Add-On",
#  'Ironcast',
#  'Spirits of Xanadu',
#  'Resident Evil 5 - UNTOLD STORIES BUNDLE',
#  'ArcheAge',
#  'Tropico 5 - Supervillain',
#  "PAYDAY 2: The Butcher's BBQ Pack",
#  'Agarest 2 - Bundle #5',
#  'Arms Dealer',
#  'An Octave Higher',
#  'Pixel Puzzles 2: Anime',
#  'TyranoBuilder Visual Novel Studio',
#  'RIDE',
#  '//SNOWFLAKE TATTOO//',
#  'Age of Fear 2: The Chaos Lord GOLD',
#  'Star Ruler 2',
#  'Keebles',
#  'Why We Ride',
#  'Deadly Sin',
#  'Unium',
#  'RIDE: Yamaha Historical Bikes',
#  'Half-Life 2: Update',
#  'Artizens Official Soundtrack Vol. 1',
#  'Princess Evangile All Ages Version',
#  'A Pixel Story Original Soundtrack',
#  'A Pixel Story',
#  'Attack of the Labyrinth +',
#  'MAGIX Music Maker Hip Hop Edition 6',
#  'Pre-purchase Reward Set',
#  'DEAD OR ALIVE 5 Last Round: Core Fighters',
#  'Fun Theme Set',
#  'Halloween + Debut Costume Set',
#  'AdVenture Capitalist',
#  'The Spatials',
#  'Bloodsports.TV',
#  'Locust - Expansion Pack',
#  'KeeperRL',
#  'Rocksmith® 2014 – Spinal Tap - “Tonight I’m Gonna Rock You Tonight”',
#  'Rocksmith® 2014 – Spinal Tap - “Stonehenge”',
#  'Rocksmith® 2014 – Spinal Tap - “Gimme Some Money”',
#  'Rocksmith® 2014 – Spinal Tap - “Big Bottom”',
#  'Rocksmith® 2014 – Spinal Tap - “Sex Farm”',
#  'Rocksmith® 2014 – Spinal Tap Song Pack',
#  'Paperbound',
#  'From Bedrooms to Billions',
#  'Trials Fusion - After the Incident',
#  'Hare In The Hat',
#  'The Defenders: The Second Wave',
#  'Make it indie!',
#  'LA Cops Soundtrack',
#  'gravilon',
#  'Jaques Roque',
#  'Grass Simulator',
#  'Grass Simulator - Soundtrack',
#  'Hawk for DCS World',
#  'LEGO Batman 3: Beyond Gotham DLC: Heroines and Villainesses Character Pack',
#  'The Talos Principle - Serious DLC',
#  'Freestyle 2: Street Basketball',
#  'R.O.O.T.S',
#  'Wildlife Park - Wild Creatures',
#  'DARK SOULS™ II: Scholar of the First Sin',
#  'Gare Sapphire Mechs',
#  'War for the Overworld - Underlord Edition Upgrade',
#  'HIS - [Avatar] Ho229 Pack',
#  "Train Simulator: Network SouthEast Class 415 '4EPB' EMU Add-On",
#  'Astronaut Simulator',
#  'Battle Academy 2 - Battle of Kursk',
#  'Shutter',
#  'Farming Simulator 15 - JCB',
#  'Depth - Corsair APS Skin',
#  'Depth - Corsair P-11 Skin',
#  'Depth - Corsair Knife Skin',
#  'War for the Overworld',
#  'Depth - Legendary Hammerhead Skin',
#  'Return NULL - Episode 1',
#  'World of Cinema - Movie Tycoon',
#  'Survarium',
#  'DC Universe Online™ - Episode Pack II',
#  'DC Universe Online™ - Episode Pack I',
#  'Survarium - Ultimate Steam Starter Pack',
#  'Survarium - Steam Shotgun Pack',
#  'Adventures of Bertram Fiddle: Episode 1: A Dreadly Business',
#  'Crazy Steam Bros 2',
#  'Sun Blast: Star Fighter',
#  'Dragon Fantasy: The Volumes of Westeria',
#  'Fantasy Grounds - D&D Paladin Class Pack',
#  'Fantasy Grounds - D&D Monk Class Pack',
#  'Fantasy Grounds - D&D Ranger Class Pack',
#  'Fantasy Grounds - D&D Sorcerer Class Pack',
#  'Fantasy Grounds - D&D Warlock Class Pack',
#  'Fantasy Grounds - D&D Wizard Class Pack',
#  'Fantasy Grounds - D&D Rogue Class Pack',
#  'Fantasy Grounds - D&D Complete Core Monster Pack',
#  'Fantasy Grounds - D&D Lost Mine of Phandelver',
#  'Fantasy Grounds - D&D Monster Pack - Aberrations',
#  'Fantasy Grounds - D&D Monster Pack - Beasts',
#  'Fantasy Grounds - D&D Monster Pack - Celestials & Fiends',
#  'Fantasy Grounds - D&D Monster Pack - Dragons',
#  'Fantasy Grounds - D&D Monster Pack - Fey & Giants',
#  'Fantasy Grounds - D&D Monster Pack - Humanoids',
#  'Fantasy Grounds - D&D Monster Pack - Monstrosities',
#  'Fantasy Grounds - D&D Monster Pack - Oozes, Plants & Swarms',
#  'Rocksmith® 2014 – Bush - “Glycerine”',
#  'Fantasy Grounds - D&D Monster Pack - Undead',
#  'Fantasy Grounds - D&D Monster Pack - Constructs & Elementals',
#  'Rocksmith® 2014 – Bush - “Swallowed”',
#  'Rocksmith® 2014 – Bush - “Everything Zen”',
#  'Rocksmith® 2014 – Bush Song Pack',
#  'Rocksmith® 2014 – Bush - “Comedown”',
#  'Starlight Tactics™',
#  'Primal Carnage: Extinction Soundtrack',
#  'Into The Gloom',
#  'Official Guide - Millennium 2',
#  'Tropical Paradise Costume & Movie Set',
#  'Variety Costume Set',
#  'Blue Estate The Game',
#  'Arma 3 Marksmen',
#  'TS Marketplace: Connex South Central Class 319 Livery Add-On',
#  'Luminosity',
#  'Train Simulator: Network SouthEast Class 159 DMU Add-On',
#  'fault milestone two Demo',
#  'Lakeview Cabin Collection',
#  '99 Waves to Die',
#  'Defend Your Life: TD',
#  'Dead Synchronicity: Tomorrow Comes Today',
#  'Dead Synchronicity - Soundtrack',
#  'Relativity Wars - A Science Space RTS',
#  'Choice of the Petal Throne',
#  'Choice of the Petal Throne Demo',
#  'Hero Generations',
#  "Hero Generations - Collector's Edition Content",
#  'The Undying Plague',
#  'Albedo: Eyes from Outer Space',
#  'Muvee Reveal 11',
#  'Red Stone Online',
#  "Traps N' Gemstones",
#  'Far Cry® 4 Valley of the Yetis',
#  'Train Simulator: CSX AC6000CW Loco Add-On',
#  'I, Gladiator - Soundtracks',
#  'Agarest 2 - Bundle #8',
#  'Blue Steel Sub-Zero',
#  'The Charnel House Trilogy',
#  'The Charnel House Trilogy - OST',
#  'The Charnel House Trilogy Demo',
#  'Tropico 5 - Inquisition',
#  'Westerado: Double Barreled',
#  'Telepath Tactics',
#  'House of Caravan',
#  'StarFence: Heroic Edition',
#  'Door Kickers Soundtrack',
#  'Lovely Planet Demo',
#  'Slow Down, Bull',
#  'The Lost Valley',
#  'Escape',
#  'Shadow Hunter',
#  'Dynasty Warriors 8 - Empires: Castle Pack',
#  'DW8E: Castle and Scenario Pack',
#  'The Evil Within - The Consequence',
#  'Bloodbath Kavkaz',
#  'Highlands',
#  'Convoy',
#  'FSX: Steam Edition - Piper PA-32R-301 Saratoga SP Add-On',
#  'Warhammer 40,000: Armageddon - Angels of Death',
#  'Rocksmith® 2014 – Fuel - “Hemorrhage (In My Hands)”',
#  'Nimble Writer',
#  'JumpJet Rex',
#  'Rocksmith® 2014 – Alt-Rock Song Pack',
#  'The Clans - Saga of the Twins',
#  'The Clans - Saga of the Twins - Deluxe Edition',
#  'JumpJet Rex - Soundtrack',
#  'Airport Simulator 2015',
#  'Train Simulator: BR Class 07 Loco Add-On',
#  'Unlimited Escape 2',
#  'Lord of the Dark Castle Demo',
#  'BR Blue Class 07 Add-On Livery',
#  'Kalimba',
#  'Kalimba - The Dark Void - Coop',
#  'Kalimba - The Dark Void - Solo',
#  'Parcel',
#  'Ghost in the Machine',
#  "Kitty Powers' Matchmaker",
#  'Deepworld',
#  'Will Fight for Food: Super Actual Sellout: Game of the Hour',
#  'Unlock all Krypt Items',
#  'Samurai Pack',
#  'Environmental Station Alpha',
#  'Environmental Station Alpha Demo',
#  'Quarries of Scred',
#  'House of Nightmares B-Movie Edition',
#  'HIS - [Ju87G] Berta Hildebrand Pack',
#  'Everything is Black and White',
#  'Crest - an indirect god sim',
#  "Mind Snares: Alice's Journey",
#  'Crypt of the NecroDancer',
#  'Crypt of the NecroDancer Extended Soundtrack',
#  'The Indie Mixtape',
#  'The Way of the Pixelated Fist',
#  'The Curse of Nordic Cove',
#  'Hypt',
#  'World of Cinema - Directors Cut',
#  'The Lost Battalion: All Out Warfare',
#  'Blender',
#  'Dungeons 2',
#  'Siralim',
#  "Infested Planet - Trickster's Arsenal",
#  'Breakout Invaders',
#  'RPG Maker 2003',
#  'DRAGON: A Game About a Dragon',
#  'The Weaponographist - Soundtrack',
#  'VRC PRO Deluxe Nitro on-road tracks',
#  'VRC PRO Deluxe Off-road tracks',
#  'VRC PRO Deluxe Cars pack',
#  'Ys VI: The Ark of Napishtim',
#  'Influent DLC - Norsk [Learn Norwegian]',
#  'VRC PRO Deluxe Electric on-road tracks',
#  'Rocksmith® 2014 – Dethklok - “Thunderhorse”',
#  'Rocksmith® 2014 – Dethklok - “Awaken”',
#  'Ultimate Tic-Tac-Toe',
#  'Rocksmith® 2014 – Dethklok Song Pack',
#  'Rocksmith® 2014 – Dethklok - “Go Into the Water”',
#  'Boston Lockdown Campaign Book pdf',
#  'Earthtongue Soundtrack',
#  'Carp Fishing Simulator',
#  'Bloodbath Kavkaz - Soundtrack',
#  'Battle Brothers - Fangshire Helm',
#  'Lilly and Sasha: Curse of the Immortals',
#  'FSX: Steam Edition - Piper PA-34-200T Seneca II Add-On',
#  'Metamorphabet',
#  'Remnants Of Isolation',
#  'Helena The 3rd',
#  'Hollywood Visionary Demo',
#  'Gremlin Invasion: Survivor',
#  'REVERSE SIDE: Official Soundtrack',
#  'Hollywood Visionary',
#  'Screencheat - Deluxe Edition Upgrade',
#  'Robot Roller-Derby Disco Dodgeball Soundtrack',
#  'RPG Maker VX Ace - Samurai Classics Music Resource Pack',
#  'RPG Maker VX Ace - Tyler Warren RTP Redesign 1',
#  "RPG Maker VX Ace - Valentine's Tile Pack",
#  'RPG Maker VX Ace - Wild Steam Resource Pack',
#  'RPG Maker VX Ace - Wild West Music Variety Pack',
#  'Rocksmith® 2014 – Blues Song Pack',
#  'TERA',
#  'UfoPilot : Astro-Creeps Elite',
#  'TERA: Starter Pack',
#  'TERA: Accessorize Pack',
#  "TERA: Explorer's Pack",
#  'TERA: Steam-Powered Pack',
#  'Apollo4x',
#  'Grim Fandango Remastered - Soundtrack',
#  'Karmaflow: The Rock Opera Videogame - Act I & Act II',
#  'Karmaflow: The Rock Opera Videogame - Upgrade to Deluxe Edition',
#  'The Music Machine',
#  'Alter World Demo',
#  'This Starry Midnight We Make',
#  'Euro Truck Simulator 2 - Viking Legends',
#  'Invisible Apartment Zero',
#  'Star Trek™: Judgment Rites',
#  'Star Trek™: Starfleet Academy',
#  'Word Wonders: The Tower of Babel',
#  'The Reject Demon: Toko Chapter 0 — Prelude',
#  'Terraform',
#  'The Reject Soundtrack - Prelude',
#  'Tiny Bridge: Ratventure',
#  'Virtual Pool 4',
#  'Inside My Radio',
#  'Action Henk',
#  'Action Henk Soundtrack',
#  'Prison Tycoon Alcatraz',
#  'Football Manager Ruined My Life',
#  'Rktcr',
#  'Horror Pack',
#  'Jason Voorhees',
#  'FSX: Steam Edition - F-16 Fighting Falcon Add-On',
#  'In Exilium - OST',
#  'Windward',
#  'Interplanetary',
#  'Jigoku Kisetsukan: Sense of the Seasons',
#  'TowerFall Dark World Expansion',
#  'Official Guide - Moonchild',
#  'Pavel Quest',
#  'The Magic Circle Original Soundtrack',
#  'Axiom Verge Original Soundtrack',
#  'Clicker Heroes',
#  'Pavel Quest Demo',
#  'Treeker: The Lost Glasses',
#  'Galactic Civilizations III',
#  'Discouraged Workers',
#  'Trainz: A New Era',
#  'Flem - Soundtrack',
#  'Green Moon',
#  "Luna's Wandering Stars",
#  'Downpour',
#  'Alum',
#  'Advent',
#  'Age of Castles: Warlords',
#  'BLACKHOLE: Testing Laboratory',
#  'BLACKHOLE: Complete Edition Upgrade',
#  'Chicken Invaders 4 - Easter Edition',
#  'Dustbowl',
#  'Life Of Pixel - Soundtrack',
#  "H-Hour: World's Elite",
#  'Rocksmith® 2014 – Slayer - “Angel of Death”',
#  'Rocksmith® 2014 – Slayer - “South of Heaven”',
#  'Rocksmith® 2014 – Slayer - “Seasons in the Abyss”',
#  'Rocksmith® 2014 – Slayer Song Pack',
#  'GameGuru - Buildings Pack',
#  'Rocksmith® 2014 – Slayer - “Dead Skin Mask”',
#  'Rocksmith® 2014 – Slayer - “Raining Blood”',
#  'NEON STRUCT Demo',
#  'NEON STRUCT',
#  'NEON STRUCT Soundtrack & Artbook',
#  'Gran Vitreous',
#  'Spaceman Sparkles 2',
#  'Always The Same Blue Sky...',
#  'Porcunipine',
#  'Space Robot Samurai Zombie Slayer',
#  'Courier of the Crypts',
#  'Teddy Terror',
#  'Train Simulator: Soldier Summit Route Add-On',
#  'Blockstorm',
#  'OBEY',
#  'True Bliss',
#  'Janky Tanks Demo',
#  'Strife®',
#  'The Incredible Adventures of Van Helsing III',
#  'Wyrmsun',
#  '60 Seconds!',
#  'CHARIOT WARS',
#  'The Evil Within: The Executioner',
#  'Teddy Floppy Ear - The Race',
#  'Lilly and Sasha: Nexus of Souls',
#  'Heroes of Loot',
#  "A Bastard's Tale",
#  'Man Alive',
#  'Rocksmith® 2014 – Bill Withers - “Lovely Day”',
#  'Rocksmith® 2014 – Love Singles Song Pack',
#  'BADLAND: Game of the Year Edition',
#  "AKIBA'S TRIP: Undead ＆ Undressed",
#  'BADLAND: Game of the Year Edition - Digital Art Booklet & Ambient Soundtrack',
#  'Crimzon Clover WORLD IGNITION - Superplay Strategy Guide',
#  'Crimzon Clover WORLD IGNITION - Arcade Poster Pack',
#  'Crimzon Clover WORLD IGNITION - Arranged Sound Track',
#  'Orbital Gear Soundtrack',
#  'Vortex Attack: ボルテックスアタック',
#  'Rooms: The Unsolvable Puzzle - Original Soundtrack',
#  'Carnivores: Dinosaur Hunter Reborn',
#  'Rituals',
#  'Hills Of Glory 3D',
#  '0RBITALIS',
#  'Homesick',
#  'Flame Over',
#  'Servo',
#  'Sleep Attack',
#  'The Detail Episode 2 - From The Ashes',
#  'Tropico 5 - Espionage',
#  'Lunch Truck Tycoon',
#  'Blender Game Asset Creation',
#  'Kung Fury: Street Rage',
#  'Toy Wars Invasion',
#  'Koi-Koi Japan : Koi-Koi Enjoy Pack',
#  'BLADESTORM: Nightmare',
#  'HIS - [J7W1] Berta Hildebrand Pack',
#  'HIS - [Me262] Berta Hildebrand Pack',
#  'Stargazer',
#  'Alter World',
#  'Waste Walkers',
#  'Official Guide - Millennium 4',
#  'BeamNG.drive',
#  'The Silent Age',
#  'Tiamat X',
#  'FSX: Steam Edition - Diamond DA40 Add-On',
#  "Waste Walkers Prepper's Edition DLC",
#  'Waste Walkers Resource Toolkit DLC',
#  'stratO',
#  'Scribble Space',
#  'MASSIVE CHALICE',
#  'Hatred',
#  'Football Tactics',
#  'Sirius Online',
#  "DNO Rasa's Journey",
#  'The Four Kings Casino and Slots',
#  'Artifact Adventure',
#  'Rise of Flight: ILYA Muromets',
#  'Digger Online',
#  'FSX: Steam Edition - Oban Airport (EGEO) Add-On',
#  'Soccer Rage',
#  'I, Gladiator - Kolhid Sword',
#  'RESCUE 2: Everyday Heroes',
#  'ZombieRun',
#  'Rolling Sun',
#  'The Enchanted Cave 2',
#  'FSX: Steam Edition - Piper Pacer 180 Add-On',
#  'Stonehearth',
#  'Football Tactics Demo',
#  'Spheritis',
#  'Vektor Wars',
#  'Spooky Cats',
#  'Parcel Demo',
#  'You Must Build A Boat',
#  'Duck Game',
#  'Call of Duty®: Advanced Warfare - Lagoon Personalization Pack',
#  'Call of Duty®: Advanced Warfare - Tiki Personalization Pack',
#  'The Masterplan',
#  'Call of Duty®: Advanced Warfare - Backdraft Personalization Pack',
#  'Call of Duty®: Advanced Warfare - Psychedelic Personalization Pack',
#  'Spriter: Game Effects Pack',
#  'Fury Of The Gods',
#  'D4: Dark Dreams Don’t Die -Season One-',
#  'D4: Special Costume Set -12 Beers-',
#  'D4: Mini Soundtrack',
#  'D4: Special Art Book',
#  'D4: Season One Voice Over Script',
#  'Tiki Man',
#  "Shoot 'Em Up Kit",
#  'Legend of Dungeon Original Soundtrack',
#  'Way to Go!',
#  'Way to Go! Demo',
#  'Rolling Shapes',
#  "Aero's Quest",
#  'Chicken Invaders 3',
#  'Titanis',
#  'Content Pack - Europa Universalis IV: Common Sense',
#  'Expansion - Europa Universalis IV: Common Sense',
#  'Hero Siege - Amazon (Class)',
#  'Europa Universalis IV: Common Sense E-Book',
#  'Klassic Pack 1',
#  'Tanya',
#  'Fox & Flock',
#  'Rocksmith® 2014 – Brian Setzer - “Rock This Town”',
#  'Galactic Inheritors',
#  'Rocksmith® 2014 – Queen - “Crazy Little Thing Called Love”',
#  'Rocksmith® 2014 – Carl Perkins - “Blue Suede Shoes”',
#  'Rocksmith® 2014 – Gene Vincent and His Blue Caps - “Be-Bop-A-Lula”',
#  'GTA Online: Shark Cash Cards',
#  'Rocksmith® 2014 – Rockabilly Song Pack',
#  'FREE China Theme Pack',
#  'Rocksmith® 2014 – Ricky Nelson - “Hello Mary Lou (Goodbye Heart)”',
#  'Alone in the Dark: Illumination™',
#  'US Diesel Lokomotiven - Set 1',
#  'US Diesel Lokomotiven - Set 2',
#  'Modellset 1 - Bahnhof, Häuser, Scheunen',
#  'TERA: Totes the Portable Pet Bank',
#  'Avalanche 2: Super Avalanche',
#  'Grey Goo - Emergence Campaign',
#  "Son of Nor Item: Moon's Touch Bracer",
#  'Son of Nor Item: Diadem of Nor',
#  'LEGO® Jurassic World',
#  'Son of Nor: Warriors of Nor',
#  'Journey Of The Light - Soundtrack',
#  '100% Orange Juice - Krila & Kae Character Pack',
#  '5 Blue Orbs',
#  'Ice Cream Surfer',
#  'Super Star Path Soundtrack',
#  'Second Warfare',
#  'Echo of Soul',
#  'Atlantic Quest Solitaire',
#  'Super Star Path',
#  'Koala Kids',
#  'Tcheco in the Castle of Lucio',
#  'Shadowrun 5th Edition Rules pdf',
#  'Mahjong Pretty Girls Battle : School Girls Edition',
#  'Electric Circuit',
#  'FSX: Steam Edition - Stornoway Airport (EGPO) Add-On',
#  'FSX: Steam Edition - Piper PA-38 Tomahawk II Add-On',
#  'FSX: Steam Edition - R66 Turbine Add-On',
#  'Train Simulator: DB BR 120 Loco Add-On',
#  'Eaos Wagon Pack',
#  'Spandex Force: Champion Rising Demo',
#  'Spandex Force: Champion Rising',
#  'Glass Wing Demo',
#  'Glass Wing',
#  'Icarus-X: Tides of Fire',
#  'Fort Meow',
#  'HIS - [Kalinin K-7] Julia Mackin Pack',
#  'HIS - [BV P188] Julia Mackin Pack',
#  'Train Simulator: Weardale & Teesdale Network Route Add-On',
#  'Streets of Fury EX',
#  'Epic Arena - Uniform Colors Pack',
#  'Train Simulator: BR Class 105 DMU Add-On',
#  'Epic Arena - Spyglass',
#  'Blockwick 2',
#  'DinoSystem',
#  'Hot Pinball Thrills',
#  'Soccer Pinball Thrills',
#  'Nomad',
#  'CDF Ghostship',
#  'Lost Lands: Dark Overlord',
#  'Combat Cats',
#  'Action Alien',
#  'Color Guardians Demo',
#  'Spy Bugs',
#  'Gaokao.Love.100Days - Original Soundtrack',
#  'Ashes of Immortality',
#  'Fort Defense - Atlantic Ocean',
#  'Puzzle Expedition',
#  'Yargis - Soundtrack / Artwork',
#  'SHOFER Race Driver',
#  'Playing History: Vikings',
#  'Scarab Tales',
#  'The Adventures of Mr. Bobley',
#  'Cosmonautica - Soundtrack',
#  "Luciel's DLC Package",
#  'D&RGW F7 Add-On Livery',
#  'Battle of Empires : 1914-1918 - Blazing guns',
#  'Prismatica',
#  'The Battle of Sol',
#  'DungeonRift',
#  'Devouring Stars - Soundtrack',
#  'D4: In Game Document Full Unlock Key',
#  'Vindicator: Uprising',
#  'Car Mechanic Simulator 2015 - Trader Pack',
#  'Farm Frenzy: Hurricane Season',
#  'Deadlands Noir - That Old Time Religion',
#  'Parcel - Soundtrack',
#  'CPUCores :: Maximize Your FPS',
#  'Grand Designer Pro',
#  'The Amber Throne',
#  'Creature Factory 2',
#  'Knee Deep - Digital Playbill and Soundtrack',
#  'WAKFU - Steel Beak Pack',
#  'Prompt',
#  'JamG',
#  "Fantasy Grounds - D&D Elemental Evil Player's Companion",
#  'Deluxe Upgrade for Shadowrun Chronicles',
#  'Hook',
#  'oO',
#  'Rocket League®',
#  'SanctuaryRPG: Black Edition - Piano Collection',
#  'TAKEN',
#  'Star Chronicles: Delta Quadrant',
#  'Lilly and Sasha: Guardian Angels',
#  'FaceRig',
#  'Once Bitten, Twice Dead!',
#  'Yatagarasu Attack on Cataclysm',
#  'TIMEframe',
#  'TIMEframe Soundtrack',
#  'Two Digits - Soundtrack',
#  'Rocksmith® 2014 – Volbeat - “Heaven Nor Hell”',
#  'Skullgirls: Robo-Fortune',
#  'Hello Kitty and Sanrio Friends Racing',
#  'The Language Game',
#  'Moonchild - Deluxe Contents',
#  'Pulut Adventure',
#  'F1 2015',
#  'NotGTAV: The Kickstarter Avoidance Album',
#  'Epic Cards Battle(TCG)',
#  'ATV GP',
#  'City of Fools',
#  'Railroad Lines',
#  'Spectra - Soundtrack',
#  'Spectra',
#  'VRC PRO Deluxe Off-road tracks 2',
#  'FSX: Steam Edition - WWI Fighters Add-On',
#  'Trap Them',
#  'Girlfriend Rescue',
#  'Depth Hunter 2: Treasure Hunter',
#  'Hack Run ZERO',
#  'In Verbis Virtus - Soundtrack',
#  'Secrets of Grindea',
#  'Secrets of Grindea Demo',
#  'Holy Potatoes! A Weapon Shop?!',
#  'Sol Divide',
#  'Survivor Squad: Gauntlets Demo',
#  "Doomed'n Damned",
#  'Valkyrie Hat (or "Buy Us Coffee") DLC for Secrets of Grindea',
#  'Card Hunter',
#  'Choice Chamber',
#  'Worms World Party Remastered',
#  'Soccer Manager 2015',
#  'RC Mini Racers',
#  'Ame no Marginal -Rain Marginal- - Original Soundtrack',
#  'Biodrone Battle',
#  'MOAI 2: Path to Another World',
#  'Squarelands',
#  'Temporal Shift',
#  'No Time To Explain Remastered',
#  'CroNix',
#  'SLIDE: platformer',
#  'Super Dungeon Run',
#  'Tap Tap Infinity',
#  'Cosmic Rocket Defender',
#  'Lethal RPG: War',
#  'Interstellaria',
#  'Badland Bandits - Early Access Base Pack',
#  'In Space We Brawl',
#  "D4: David's Costume Full Unlock Key",
#  "D4: Forrest's Costume Full Unlock Key",
#  "D4: Amanda's Costume Full Unlock Key",
#  "D4: Olivia's Costume Full Unlock Key",
#  "D4: David's Beard Full Unlock Key",
#  'Vampire of the Sands',
#  'Brighter Day',
#  'Interstellaria OST',
#  'Aberoth',
#  'Monstrum - Original Soundtrack',
#  'Luckslinger Demo',
#  'Official Guide - Undefeated',
#  'Mobile Light Force (aka Gunbird)',
#  'Cast of the Seven Godsends - Redux - Soundtrack',
#  'Cast of the Seven Godsends - Redux',
#  'Botology - Map "Targul" for Survival Mode',
#  'TIS-100',
#  'Heroes of SoulCraft - Arcade MOBA',
#  'Big Fish Legend',
#  'Pixel Fodder',
#  'Super Hipster Lumberjack',
#  'Oblivious Garden ~White Day',
#  'Hypt - Original Soundtrack',
#  'Breach & Clear: Deadline Rebirth (2016)',
#  'Counter-Strike Nexon: Zombies - Journey to the West + Permanent Character',
#  'Counter-Strike Nexon: Zombies - Dragon Set + Permanent Character',
#  'Battle of Empires : 1914-1918',
#  'Project CARS - Modified Car Pack',
#  'Klassic Pack 2',
#  'TEMBO THE BADASS ELEPHANT',
#  'Tremor',
#  'Super Galaxy Squadron Soundtrack',
#  'WORLD END ECONOMiCA episode.02',
#  'Rocksmith® 2014 – The Toadies - “Possum Kingdom”',
#  'Rocksmith® 2014 – The Subways - “Rock and Roll Queen”',
#  'Rocksmith® 2014 – Queensrÿche - “Silent Lucidity”',
#  'Rocksmith® 2014 – Stevie Wonder - “Sir Duke”',
#  'Rocksmith® 2014 – Queen - “Another One Bites the Dust”',
#  'Rocksmith® 2014 – Regal Singles Song Pack',
#  "Nobunaga's Ambition: Souzou WPK - 10 New Face CG Set",
#  "Nobunaga's Ambition: Souzou WPK - Scenario Shokutokudoumei",
#  "Nobunaga's Ambition: Souzou WPK - Scenario Gunshinkourinsu",
#  'Rare Weapons Set C (The Tournament Tyrants)',
#  'Rare Weapons Set A (The Amihama Elite)',
#  'Ryoma Sakamoto',
#  'Shinsengumi Set',
#  'Where Are They Now? Set',
#  "Five Nights at Freddy's 4",
#  'Russian Front',
#  'Dungeon League',
#  'Microcosmum: survival of cells',
#  'OVERGRAVITY',
#  'Cradle',
#  'Victor Vran ARPG',
#  'Cradle - Soundtrack & Artbook',
#  'Naninights',
#  'Heroes of Legionwood',
#  'Heroes of Legionwood Demo',
#  'Spectrum: First Light',
#  'Arevan',
#  'Starchaser: Priestess of the Night Sky',
#  'Pixel Space',
#  'Coffin Dodgers Demo',
#  'Pulsen',
#  "NASCAR '15 Chevrolet Pack 1",
#  "NASCAR '15 FREE Thank You Pack",
#  "NASCAR '15 Ford and Toyota Pack 1",
#  'Rise of the Triad Soundtrack',
#  'Race The Sun Original Soundtrack',
#  'Idol Magical Girl Chiru Chiru Michiru Part 2',
#  'Project Druid - 2D Labyrinth Explorer-',
#  'Diving Normal',
#  'Pluck',
#  'Siege Wars',
#  'Hydraulic Empire',
#  "The Princess' Heart",
#  'MANOS',
#  'Fated Souls',
#  'Deserter Simulator',
#  'Damn virgins',
#  'REVERSE SIDE',
#  'Super Space Meltdown',
#  'Deficis',
#  'Mystical',
#  'Gunjitsu',
#  '3D Paraglider',
#  'ENKI',
#  'FREE Villager Stevie',
#  'Caverns of the Snow Witch',
#  'Radial Impact',
#  'The Bloc',
#  'Duet',
#  'Yomi - Expansion Characters',
#  'Submerged',
#  'Submerged OST',
#  'Dandy: Or a Brief Glimpse Into the Life of the Candy Alchemist',
#  'Dandy Original Soundtrack',
#  'The Logomancer',
#  "Unfinished - An Artist's Lament",
#  ...]

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 3: specs
#
# def specs( Año: str ): Se ingresa un año y devuelve una lista con los 5 specs que más se repiten en el mismo en el orden correspondiente.
#
# Example:
# | Year | Specs |
# | -- | - |
# | 2018 | {'Indie': 125, 'Action': 75, 'Adventure': 74, 'Casual': 45, 'Simulation': 43} |
# | 2016 | {'Indie': 4106, 'Action': 2544, 'Casual': 2141, 'Adventure': 2042, 'Simulation': 1666} |
#
# For this case the only thing that matters to us is "specs" and "year" columns, so we can drop the other ones.

# %%
specsEndpointDf = gamesWithYearDf[['specs', 'year']]
specsEndpointDf.head()
# Out:
#                                                specs  year
# 0                                    [Single-player]  2018
# 1  [Single-player, Multi-player, Online Multi-Pla...  2018
# 2  [Single-player, Multi-player, Online Multi-Pla...  2017
# 3                                    [Single-player]  2017
# 5                [Single-player, Steam Achievements]  2018

# %% [markdown]
# Now we can drop all the columns that have a NaN in any of the two columns because they will bring no information to the scope of the genero function.

# %%
specsEndpointDf.describe()
# Out:
#                year
# count  29965.000000
# mean    2014.794727
# std        5.532999
# min     1970.000000
# 25%     2014.000000
# 50%     2016.000000
# 75%     2017.000000
# max     2756.000000

# %%
specsEndpointDf.isna().sum()
# Out:
# specs    669
# year       0
# dtype: int64

# %%
specsEndpointDf = specsEndpointDf.dropna()

# %%
specsEndpointDf.isna().sum()
# Out:
# specs    0
# year     0
# dtype: int64

# %% [markdown]
# ### Specs
#
# Similarly to genres, each game can have various specs, we can see this in the "specs" column because it is filled with lists.
#
# For this reason we need to explode it so we can count all the specs separately.

# %%
specsCompleteList = specsEndpointDf.explode(column=['specs'])['specs'].unique()
print(specsCompleteList)
print(specsCompleteList.shape)
# Out:
# ['Single-player' 'Multi-player' 'Online Multi-Player'
#  'Cross-Platform Multiplayer' 'Steam Achievements' 'Steam Trading Cards'
#  'In-App Purchases' 'Stats' 'Downloadable Content'
#  'Full controller support' 'Steam Cloud' 'Steam Leaderboards'
#  'Partial Controller Support' 'Local Co-op' 'Shared/Split Screen'
#  'Valve Anti-Cheat enabled' 'Local Multi-Player'
#  'Steam Turn Notifications' 'MMO' 'Co-op' 'Captions available'
#  'Steam Workshop' 'Includes level editor' 'Mods' 'Mods (require HL2)'
#  'Online Co-op' 'Game demo' 'Includes Source SDK' 'Commentary available'
#  'SteamVR Collectibles' 'Mods (require HL1)']
# (31,)

# %%
specsEndpointDf.shape
# Out:
# (29296, 2)

# %%
specsEndpointDf = specsEndpointDf.explode('specs')
specsEndpointDf.head()
# Out:
#                         specs  year
# 0               Single-player  2018
# 1               Single-player  2018
# 1                Multi-player  2018
# 1         Online Multi-Player  2018
# 1  Cross-Platform Multiplayer  2018

# %%
specsEndpointDf.shape
# Out:
# (128231, 2)

# %% [markdown]
# Now we can make a Groupby to get all the specs of each year. Then unstack it and have a new Data Frame with the data we desire.

# %%
specsEndpointDf2 = specsEndpointDf.groupby(by=['year', 'specs'])['specs'].count()
specsEndpointDf2.tail()
# Out:
# year  specs
# 2756  Single-player          1
#       Steam Achievements     1
#       Steam Cloud            1
#       Steam Trading Cards    1
#       Steam Workshop         1
# Name: specs, dtype: int64

# %%
specsEndpointDf3 = specsEndpointDf2.unstack(level=1, fill_value=0)
specsEndpointDf3.head()
# Out:
# specs  Captions available  Co-op  Commentary available
# year
# 1970                    2      0                     0  \
# 1975                    1      0                     0
# 1980                    1      0                     0
# 1981                    2      0                     0
# 1982                    3      0                     0
#
# specs  Cross-Platform Multiplayer  Downloadable Content
# year
# 1970                            0                     0  \
# 1975                            0                     0
# 1980                            0                     0
# 1981                            0                     0
# 1982                            0                     0
#
# specs  Full controller support  Game demo  In-App Purchases
# year
# 1970                         0          0                 0  \
# 1975                         0          0                 0
# 1980                         0          0                 0
# 1981                         0          0                 0
# 1982                         0          0                 0
#
# specs  Includes Source SDK  Includes level editor  ...  Single-player  Stats
# year                                               ...
# 1970                     0                      0  ...              0      0  \
# 1975                     0                      0  ...              0      0
# 1980                     0                      0  ...              0      0
# 1981                     0                      0  ...              0      0
# 1982                     0                      0  ...              0      0
#
# specs  Steam Achievements  Steam Cloud  Steam Leaderboards
# year
# 1970                    0            0                   0  \
# 1975                    0            0                   0
# 1980                    0            0                   0
# 1981                    0            0                   0
# 1982                    0            0                   0
#
# specs  Steam Trading Cards  Steam Turn Notifications  Steam Workshop
# year
# 1970                     0                         0               0  \
# 1975                     0                         0               0
# 1980                     0                         0               0
# 1981                     0                         0               0
# 1982                     0                         0               0
#
# specs  SteamVR Collectibles  Valve Anti-Cheat enabled
# year
# 1970                      0                         0
# 1975                      0                         0
# 1980                      0                         0
# 1981                      0                         0
# 1982                      0                         0
#
# [5 rows x 31 columns]

# %%
# Now we have exactly what we need.
specsEndpointDict = specsEndpointDf3.to_dict(orient='index')
specsEndpointDict
# Out:
# {1970: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1975: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1980: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1981: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1982: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1983: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 1,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1984: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 1,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 2,
#   'Shared/Split Screen': 0,
#   'Single-player': 2,
#   'Stats': 0,
#   'Steam Achievements': 2,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1985: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1986: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1987: {'Captions available': 5,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 4,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1988: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 5,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 1,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1989: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 7,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1990: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 0,
#   'Single-player': 10,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 2,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1991: {'Captions available': 4,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 5,
#   'Shared/Split Screen': 1,
#   'Single-player': 12,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1992: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 1,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 1,
#   'Single-player': 13,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 2,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1993: {'Captions available': 8,
#   'Co-op': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 8,
#   'Shared/Split Screen': 0,
#   'Single-player': 25,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 2,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 2,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1994: {'Captions available': 3,
#   'Co-op': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 2,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 15,
#   'Shared/Split Screen': 0,
#   'Single-player': 31,
#   'Stats': 0,
#   'Steam Achievements': 3,
#   'Steam Cloud': 6,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 4,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1995: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 4,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 0,
#   'Single-player': 30,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 6,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 3,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1996: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 1,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 9,
#   'Online Co-op': 0,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 2,
#   'Single-player': 36,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 4,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 6,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1997: {'Captions available': 3,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 2,
#   'Full controller support': 4,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 1,
#   'Local Co-op': 1,
#   'Local Multi-Player': 2,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 13,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 1,
#   'Single-player': 39,
#   'Stats': 0,
#   'Steam Achievements': 5,
#   'Steam Cloud': 9,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 10,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1998: {'Captions available': 11,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 3,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 17,
#   'Online Co-op': 0,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 4,
#   'Shared/Split Screen': 1,
#   'Single-player': 50,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 9,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 4,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  1999: {'Captions available': 7,
#   'Co-op': 6,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 3,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 1,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 2,
#   'MMO': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 13,
#   'Online Co-op': 0,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 3,
#   'Single-player': 45,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 10,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 7,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 1,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 2},
#  2000: {'Captions available': 5,
#   'Co-op': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 1,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 13,
#   'Online Co-op': 0,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 1,
#   'Single-player': 34,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 4,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 2,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 2},
#  2001: {'Captions available': 13,
#   'Co-op': 6,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 2,
#   'Full controller support': 1,
#   'Game demo': 0,
#   'In-App Purchases': 1,
#   'Includes Source SDK': 0,
#   'Includes level editor': 7,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 4,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 25,
#   'Online Co-op': 1,
#   'Online Multi-Player': 5,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 1,
#   'Single-player': 55,
#   'Stats': 1,
#   'Steam Achievements': 4,
#   'Steam Cloud': 12,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 6,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2002: {'Captions available': 7,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 3,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 1,
#   'Multi-player': 15,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 2,
#   'Single-player': 40,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 6,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 5,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2003: {'Captions available': 12,
#   'Co-op': 2,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 0,
#   'Full controller support': 2,
#   'Game demo': 1,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 3,
#   'Local Co-op': 0,
#   'Local Multi-Player': 2,
#   'MMO': 2,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 17,
#   'Online Co-op': 1,
#   'Online Multi-Player': 4,
#   'Partial Controller Support': 5,
#   'Shared/Split Screen': 0,
#   'Single-player': 72,
#   'Stats': 1,
#   'Steam Achievements': 5,
#   'Steam Cloud': 21,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 13,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 2,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2004: {'Captions available': 12,
#   'Co-op': 5,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 3,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 3,
#   'Includes level editor': 4,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 1,
#   'Mods (require HL2)': 0,
#   'Multi-player': 22,
#   'Online Co-op': 0,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 2,
#   'Shared/Split Screen': 1,
#   'Single-player': 61,
#   'Stats': 1,
#   'Steam Achievements': 5,
#   'Steam Cloud': 8,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 13,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 3},
#  2005: {'Captions available': 13,
#   'Co-op': 6,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 1,
#   'Downloadable Content': 4,
#   'Full controller support': 1,
#   'Game demo': 1,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 1,
#   'Includes level editor': 6,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 1,
#   'Mods': 1,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 2,
#   'Multi-player': 27,
#   'Online Co-op': 1,
#   'Online Multi-Player': 1,
#   'Partial Controller Support': 11,
#   'Shared/Split Screen': 2,
#   'Single-player': 89,
#   'Stats': 3,
#   'Steam Achievements': 9,
#   'Steam Cloud': 24,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 13,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 2,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2006: {'Captions available': 13,
#   'Co-op': 8,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 5,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 2,
#   'In-App Purchases': 3,
#   'Includes Source SDK': 1,
#   'Includes level editor': 6,
#   'Local Co-op': 0,
#   'Local Multi-Player': 1,
#   'MMO': 4,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 49,
#   'Online Co-op': 0,
#   'Online Multi-Player': 3,
#   'Partial Controller Support': 9,
#   'Shared/Split Screen': 7,
#   'Single-player': 136,
#   'Stats': 4,
#   'Steam Achievements': 6,
#   'Steam Cloud': 17,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 20,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 2,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 5},
#  2007: {'Captions available': 21,
#   'Co-op': 8,
#   'Commentary available': 4,
#   'Cross-Platform Multiplayer': 2,
#   'Downloadable Content': 1,
#   'Full controller support': 2,
#   'Game demo': 0,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 4,
#   'Includes level editor': 12,
#   'Local Co-op': 1,
#   'Local Multi-Player': 1,
#   'MMO': 4,
#   'Mods': 3,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 4,
#   'Multi-player': 41,
#   'Online Co-op': 1,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 17,
#   'Shared/Split Screen': 6,
#   'Single-player': 140,
#   'Stats': 2,
#   'Steam Achievements': 17,
#   'Steam Cloud': 21,
#   'Steam Leaderboards': 1,
#   'Steam Trading Cards': 17,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 3,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 4},
#  2008: {'Captions available': 18,
#   'Co-op': 12,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 4,
#   'Downloadable Content': 5,
#   'Full controller support': 11,
#   'Game demo': 2,
#   'In-App Purchases': 1,
#   'Includes Source SDK': 2,
#   'Includes level editor': 6,
#   'Local Co-op': 1,
#   'Local Multi-Player': 2,
#   'MMO': 5,
#   'Mods': 2,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 1,
#   'Multi-player': 47,
#   'Online Co-op': 1,
#   'Online Multi-Player': 6,
#   'Partial Controller Support': 24,
#   'Shared/Split Screen': 6,
#   'Single-player': 185,
#   'Stats': 2,
#   'Steam Achievements': 38,
#   'Steam Cloud': 21,
#   'Steam Leaderboards': 3,
#   'Steam Trading Cards': 19,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 1},
#  2009: {'Captions available': 18,
#   'Co-op': 28,
#   'Commentary available': 2,
#   'Cross-Platform Multiplayer': 6,
#   'Downloadable Content': 57,
#   'Full controller support': 39,
#   'Game demo': 5,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 1,
#   'Includes level editor': 16,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 2,
#   'Mods': 4,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 2,
#   'Multi-player': 93,
#   'Online Co-op': 2,
#   'Online Multi-Player': 3,
#   'Partial Controller Support': 38,
#   'Shared/Split Screen': 7,
#   'Single-player': 312,
#   'Stats': 11,
#   'Steam Achievements': 88,
#   'Steam Cloud': 87,
#   'Steam Leaderboards': 45,
#   'Steam Trading Cards': 65,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 34,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 3},
#  2010: {'Captions available': 33,
#   'Co-op': 56,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 14,
#   'Downloadable Content': 105,
#   'Full controller support': 25,
#   'Game demo': 2,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 2,
#   'Includes level editor': 17,
#   'Local Co-op': 2,
#   'Local Multi-Player': 0,
#   'MMO': 3,
#   'Mods': 1,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 148,
#   'Online Co-op': 1,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 128,
#   'Shared/Split Screen': 33,
#   'Single-player': 371,
#   'Stats': 39,
#   'Steam Achievements': 154,
#   'Steam Cloud': 95,
#   'Steam Leaderboards': 75,
#   'Steam Trading Cards': 47,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 6,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 6},
#  2011: {'Captions available': 36,
#   'Co-op': 135,
#   'Commentary available': 3,
#   'Cross-Platform Multiplayer': 15,
#   'Downloadable Content': 228,
#   'Full controller support': 47,
#   'Game demo': 5,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 1,
#   'Includes level editor': 17,
#   'Local Co-op': 5,
#   'Local Multi-Player': 4,
#   'MMO': 8,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 226,
#   'Online Co-op': 6,
#   'Online Multi-Player': 10,
#   'Partial Controller Support': 162,
#   'Shared/Split Screen': 58,
#   'Single-player': 513,
#   'Stats': 57,
#   'Steam Achievements': 247,
#   'Steam Cloud': 160,
#   'Steam Leaderboards': 127,
#   'Steam Trading Cards': 81,
#   'Steam Turn Notifications': 1,
#   'Steam Workshop': 9,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 19},
#  2012: {'Captions available': 45,
#   'Co-op': 249,
#   'Commentary available': 5,
#   'Cross-Platform Multiplayer': 45,
#   'Downloadable Content': 710,
#   'Full controller support': 114,
#   'Game demo': 11,
#   'In-App Purchases': 5,
#   'Includes Source SDK': 0,
#   'Includes level editor': 36,
#   'Local Co-op': 2,
#   'Local Multi-Player': 6,
#   'MMO': 18,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 444,
#   'Online Co-op': 5,
#   'Online Multi-Player': 13,
#   'Partial Controller Support': 299,
#   'Shared/Split Screen': 252,
#   'Single-player': 1043,
#   'Stats': 139,
#   'Steam Achievements': 551,
#   'Steam Cloud': 404,
#   'Steam Leaderboards': 282,
#   'Steam Trading Cards': 168,
#   'Steam Turn Notifications': 5,
#   'Steam Workshop': 22,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 79},
#  2013: {'Captions available': 101,
#   'Co-op': 374,
#   'Commentary available': 8,
#   'Cross-Platform Multiplayer': 109,
#   'Downloadable Content': 902,
#   'Full controller support': 473,
#   'Game demo': 17,
#   'In-App Purchases': 16,
#   'Includes Source SDK': 0,
#   'Includes level editor': 73,
#   'Local Co-op': 14,
#   'Local Multi-Player': 12,
#   'MMO': 39,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 646,
#   'Online Co-op': 18,
#   'Online Multi-Player': 24,
#   'Partial Controller Support': 324,
#   'Shared/Split Screen': 285,
#   'Single-player': 1378,
#   'Stats': 192,
#   'Steam Achievements': 966,
#   'Steam Cloud': 692,
#   'Steam Leaderboards': 505,
#   'Steam Trading Cards': 604,
#   'Steam Turn Notifications': 2,
#   'Steam Workshop': 84,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 79},
#  2014: {'Captions available': 175,
#   'Co-op': 425,
#   'Commentary available': 20,
#   'Cross-Platform Multiplayer': 250,
#   'Downloadable Content': 1346,
#   'Full controller support': 703,
#   'Game demo': 92,
#   'In-App Purchases': 13,
#   'Includes Source SDK': 11,
#   'Includes level editor': 165,
#   'Local Co-op': 13,
#   'Local Multi-Player': 21,
#   'MMO': 99,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 790,
#   'Online Co-op': 29,
#   'Online Multi-Player': 36,
#   'Partial Controller Support': 734,
#   'Shared/Split Screen': 484,
#   'Single-player': 2490,
#   'Stats': 217,
#   'Steam Achievements': 1726,
#   'Steam Cloud': 1220,
#   'Steam Leaderboards': 858,
#   'Steam Trading Cards': 1386,
#   'Steam Turn Notifications': 2,
#   'Steam Workshop': 306,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 70},
#  2015: {'Captions available': 259,
#   'Co-op': 660,
#   'Commentary available': 35,
#   'Cross-Platform Multiplayer': 381,
#   'Downloadable Content': 2156,
#   'Full controller support': 1487,
#   'Game demo': 181,
#   'In-App Purchases': 28,
#   'Includes Source SDK': 12,
#   'Includes level editor': 280,
#   'Local Co-op': 52,
#   'Local Multi-Player': 52,
#   'MMO': 147,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1315,
#   'Online Co-op': 53,
#   'Online Multi-Player': 91,
#   'Partial Controller Support': 1114,
#   'Shared/Split Screen': 728,
#   'Single-player': 4354,
#   'Stats': 414,
#   'Steam Achievements': 2870,
#   'Steam Cloud': 1888,
#   'Steam Leaderboards': 1165,
#   'Steam Trading Cards': 2521,
#   'Steam Turn Notifications': 17,
#   'Steam Workshop': 363,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 55},
#  2016: {'Captions available': 300,
#   'Co-op': 900,
#   'Commentary available': 59,
#   'Cross-Platform Multiplayer': 674,
#   'Downloadable Content': 3121,
#   'Full controller support': 1900,
#   'Game demo': 27,
#   'In-App Purchases': 256,
#   'Includes Source SDK': 12,
#   'Includes level editor': 336,
#   'Local Co-op': 188,
#   'Local Multi-Player': 293,
#   'MMO': 275,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 1770,
#   'Online Co-op': 208,
#   'Online Multi-Player': 538,
#   'Partial Controller Support': 1456,
#   'Shared/Split Screen': 871,
#   'Single-player': 5926,
#   'Stats': 489,
#   'Steam Achievements': 3962,
#   'Steam Cloud': 2193,
#   'Steam Leaderboards': 1258,
#   'Steam Trading Cards': 3571,
#   'Steam Turn Notifications': 33,
#   'Steam Workshop': 451,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 38},
#  2017: {'Captions available': 448,
#   'Co-op': 1310,
#   'Commentary available': 48,
#   'Cross-Platform Multiplayer': 933,
#   'Downloadable Content': 3988,
#   'Full controller support': 2209,
#   'Game demo': 9,
#   'In-App Purchases': 572,
#   'Includes Source SDK': 9,
#   'Includes level editor': 337,
#   'Local Co-op': 417,
#   'Local Multi-Player': 721,
#   'MMO': 312,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 2206,
#   'Online Co-op': 582,
#   'Online Multi-Player': 1379,
#   'Partial Controller Support': 1941,
#   'Shared/Split Screen': 1122,
#   'Single-player': 7990,
#   'Stats': 607,
#   'Steam Achievements': 5028,
#   'Steam Cloud': 2754,
#   'Steam Leaderboards': 1407,
#   'Steam Trading Cards': 3317,
#   'Steam Turn Notifications': 28,
#   'Steam Workshop': 530,
#   'SteamVR Collectibles': 1,
#   'Valve Anti-Cheat enabled': 90},
#  2018: {'Captions available': 6,
#   'Co-op': 3,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 9,
#   'Downloadable Content': 15,
#   'Full controller support': 44,
#   'Game demo': 0,
#   'In-App Purchases': 12,
#   'Includes Source SDK': 0,
#   'Includes level editor': 4,
#   'Local Co-op': 5,
#   'Local Multi-Player': 8,
#   'MMO': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 21,
#   'Online Co-op': 2,
#   'Online Multi-Player': 18,
#   'Partial Controller Support': 29,
#   'Shared/Split Screen': 12,
#   'Single-player': 147,
#   'Stats': 5,
#   'Steam Achievements': 68,
#   'Steam Cloud': 30,
#   'Steam Leaderboards': 13,
#   'Steam Trading Cards': 23,
#   'Steam Turn Notifications': 2,
#   'Steam Workshop': 3,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2019: {'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 2,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 4,
#   'Stats': 0,
#   'Steam Achievements': 2,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2021: {'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 1,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2756: {'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 1,
#   'Stats': 0,
#   'Steam Achievements': 1,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 1,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 1,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0}}

# %% [markdown]
# Sort by values.

# %%
specsEndpointDict_sorted = {}
for y in specsEndpointDict.keys():
    specs = specsEndpointDict[y]
    specs_sorted = {k: v for k, v in sorted(specs.items(), key=lambda item: item[1], reverse=True)}
    specsEndpointDict_sorted[y] = specs_sorted

specsEndpointDict_sorted
# Out:
# {1970: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1975: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1980: {'Captions available': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1981: {'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1982: {'Captions available': 3,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Single-player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1983: {'Captions available': 3,
#   'Partial Controller Support': 1,
#   'Single-player': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1984: {'Captions available': 2,
#   'Partial Controller Support': 2,
#   'Single-player': 2,
#   'Steam Achievements': 2,
#   'Local Co-op': 1,
#   'Steam Cloud': 1,
#   'Steam Leaderboards': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1985: {'Captions available': 2,
#   'Single-player': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1986: {'Captions available': 1,
#   'Single-player': 1,
#   'Steam Cloud': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1987: {'Captions available': 5,
#   'Single-player': 4,
#   'Steam Cloud': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1988: {'Single-player': 5,
#   'Captions available': 1,
#   'Steam Cloud': 1,
#   'Steam Trading Cards': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1989: {'Single-player': 7,
#   'Captions available': 2,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1990: {'Single-player': 10,
#   'Partial Controller Support': 3,
#   'Captions available': 2,
#   'Steam Cloud': 2,
#   'Multi-player': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1991: {'Single-player': 12,
#   'Partial Controller Support': 5,
#   'Captions available': 4,
#   'Local Multi-Player': 1,
#   'Multi-player': 1,
#   'Shared/Split Screen': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1992: {'Single-player': 13,
#   'Partial Controller Support': 4,
#   'Captions available': 2,
#   'Steam Cloud': 2,
#   'Local Co-op': 1,
#   'Multi-player': 1,
#   'Shared/Split Screen': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1993: {'Single-player': 25,
#   'Captions available': 8,
#   'Partial Controller Support': 8,
#   'Steam Cloud': 2,
#   'Steam Trading Cards': 2,
#   'Co-op': 1,
#   'Local Multi-Player': 1,
#   'Multi-player': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1994: {'Single-player': 31,
#   'Partial Controller Support': 15,
#   'Steam Cloud': 6,
#   'Steam Trading Cards': 4,
#   'Captions available': 3,
#   'Steam Achievements': 3,
#   'Multi-player': 2,
#   'Co-op': 1,
#   'Full controller support': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1995: {'Single-player': 30,
#   'Steam Cloud': 6,
#   'Multi-player': 4,
#   'Partial Controller Support': 4,
#   'Steam Trading Cards': 3,
#   'Captions available': 2,
#   'Full controller support': 1,
#   'Local Multi-Player': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1996: {'Single-player': 36,
#   'Multi-player': 9,
#   'Steam Trading Cards': 6,
#   'Steam Cloud': 4,
#   'Captions available': 3,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 2,
#   'Downloadable Content': 1,
#   'Online Multi-Player': 1,
#   'Steam Achievements': 1,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1997: {'Single-player': 39,
#   'Multi-player': 13,
#   'Steam Trading Cards': 10,
#   'Steam Cloud': 9,
#   'Steam Achievements': 5,
#   'Full controller support': 4,
#   'Partial Controller Support': 4,
#   'Captions available': 3,
#   'Co-op': 2,
#   'Downloadable Content': 2,
#   'Local Multi-Player': 2,
#   'Includes level editor': 1,
#   'Local Co-op': 1,
#   'Shared/Split Screen': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  1998: {'Single-player': 50,
#   'Multi-player': 17,
#   'Captions available': 11,
#   'Steam Cloud': 9,
#   'Partial Controller Support': 4,
#   'Steam Trading Cards': 4,
#   'Local Multi-Player': 3,
#   'Co-op': 2,
#   'Online Multi-Player': 1,
#   'Shared/Split Screen': 1,
#   'Steam Achievements': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  1999: {'Single-player': 45,
#   'Multi-player': 13,
#   'Steam Cloud': 10,
#   'Captions available': 7,
#   'Steam Trading Cards': 7,
#   'Co-op': 6,
#   'Downloadable Content': 3,
#   'Partial Controller Support': 3,
#   'Shared/Split Screen': 3,
#   'Local Multi-Player': 2,
#   'Online Multi-Player': 2,
#   'Valve Anti-Cheat enabled': 2,
#   'Full controller support': 1,
#   'In-App Purchases': 1,
#   'MMO': 1,
#   'Steam Achievements': 1,
#   'Steam Workshop': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Game demo': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2000: {'Single-player': 34,
#   'Multi-player': 13,
#   'Captions available': 5,
#   'Steam Cloud': 4,
#   'Steam Trading Cards': 2,
#   'Valve Anti-Cheat enabled': 2,
#   'Co-op': 1,
#   'Cross-Platform Multiplayer': 1,
#   'Includes level editor': 1,
#   'Online Multi-Player': 1,
#   'Shared/Split Screen': 1,
#   'Commentary available': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Partial Controller Support': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2001: {'Single-player': 55,
#   'Multi-player': 25,
#   'Captions available': 13,
#   'Steam Cloud': 12,
#   'Includes level editor': 7,
#   'Co-op': 6,
#   'Steam Trading Cards': 6,
#   'Online Multi-Player': 5,
#   'MMO': 4,
#   'Steam Achievements': 4,
#   'Downloadable Content': 2,
#   'Cross-Platform Multiplayer': 1,
#   'Full controller support': 1,
#   'In-App Purchases': 1,
#   'Local Multi-Player': 1,
#   'Online Co-op': 1,
#   'Shared/Split Screen': 1,
#   'Stats': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Commentary available': 0,
#   'Game demo': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Partial Controller Support': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2002: {'Single-player': 40,
#   'Multi-player': 15,
#   'Captions available': 7,
#   'Steam Cloud': 6,
#   'Steam Trading Cards': 5,
#   'Includes level editor': 3,
#   'Partial Controller Support': 3,
#   'Co-op': 2,
#   'Shared/Split Screen': 2,
#   'Mods (require HL2)': 1,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2003: {'Single-player': 72,
#   'Steam Cloud': 21,
#   'Multi-player': 17,
#   'Steam Trading Cards': 13,
#   'Captions available': 12,
#   'Partial Controller Support': 5,
#   'Steam Achievements': 5,
#   'Online Multi-Player': 4,
#   'Includes level editor': 3,
#   'Co-op': 2,
#   'Full controller support': 2,
#   'Local Multi-Player': 2,
#   'MMO': 2,
#   'Steam Workshop': 2,
#   'Cross-Platform Multiplayer': 1,
#   'Game demo': 1,
#   'Online Co-op': 1,
#   'Stats': 1,
#   'Steam Leaderboards': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Commentary available': 0,
#   'Downloadable Content': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Shared/Split Screen': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2004: {'Single-player': 61,
#   'Multi-player': 22,
#   'Steam Trading Cards': 13,
#   'Captions available': 12,
#   'Steam Cloud': 8,
#   'Co-op': 5,
#   'Steam Achievements': 5,
#   'Includes level editor': 4,
#   'Cross-Platform Multiplayer': 3,
#   'Includes Source SDK': 3,
#   'Valve Anti-Cheat enabled': 3,
#   'Online Multi-Player': 2,
#   'Partial Controller Support': 2,
#   'Mods (require HL1)': 1,
#   'Shared/Split Screen': 1,
#   'Stats': 1,
#   'Commentary available': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2005: {'Single-player': 89,
#   'Multi-player': 27,
#   'Steam Cloud': 24,
#   'Captions available': 13,
#   'Steam Trading Cards': 13,
#   'Partial Controller Support': 11,
#   'Steam Achievements': 9,
#   'Co-op': 6,
#   'Includes level editor': 6,
#   'Downloadable Content': 4,
#   'Stats': 3,
#   'Mods (require HL2)': 2,
#   'Shared/Split Screen': 2,
#   'Steam Workshop': 2,
#   'Commentary available': 1,
#   'Cross-Platform Multiplayer': 1,
#   'Full controller support': 1,
#   'Game demo': 1,
#   'Includes Source SDK': 1,
#   'Local Multi-Player': 1,
#   'MMO': 1,
#   'Mods': 1,
#   'Online Co-op': 1,
#   'Online Multi-Player': 1,
#   'Steam Leaderboards': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'In-App Purchases': 0,
#   'Local Co-op': 0,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2006: {'Single-player': 136,
#   'Multi-player': 49,
#   'Steam Trading Cards': 20,
#   'Steam Cloud': 17,
#   'Captions available': 13,
#   'Partial Controller Support': 9,
#   'Co-op': 8,
#   'Shared/Split Screen': 7,
#   'Includes level editor': 6,
#   'Steam Achievements': 6,
#   'Cross-Platform Multiplayer': 5,
#   'Valve Anti-Cheat enabled': 5,
#   'MMO': 4,
#   'Stats': 4,
#   'In-App Purchases': 3,
#   'Online Multi-Player': 3,
#   'Game demo': 2,
#   'Steam Workshop': 2,
#   'Commentary available': 1,
#   'Includes Source SDK': 1,
#   'Local Multi-Player': 1,
#   'Steam Leaderboards': 1,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Local Co-op': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Online Co-op': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2007: {'Single-player': 140,
#   'Multi-player': 41,
#   'Captions available': 21,
#   'Steam Cloud': 21,
#   'Partial Controller Support': 17,
#   'Steam Achievements': 17,
#   'Steam Trading Cards': 17,
#   'Includes level editor': 12,
#   'Co-op': 8,
#   'Shared/Split Screen': 6,
#   'Commentary available': 4,
#   'Includes Source SDK': 4,
#   'MMO': 4,
#   'Mods (require HL2)': 4,
#   'Valve Anti-Cheat enabled': 4,
#   'Mods': 3,
#   'Steam Workshop': 3,
#   'Cross-Platform Multiplayer': 2,
#   'Full controller support': 2,
#   'In-App Purchases': 2,
#   'Online Multi-Player': 2,
#   'Stats': 2,
#   'Downloadable Content': 1,
#   'Local Co-op': 1,
#   'Local Multi-Player': 1,
#   'Online Co-op': 1,
#   'Steam Leaderboards': 1,
#   'Game demo': 0,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2008: {'Single-player': 185,
#   'Multi-player': 47,
#   'Steam Achievements': 38,
#   'Partial Controller Support': 24,
#   'Steam Cloud': 21,
#   'Steam Trading Cards': 19,
#   'Captions available': 18,
#   'Co-op': 12,
#   'Full controller support': 11,
#   'Includes level editor': 6,
#   'Online Multi-Player': 6,
#   'Shared/Split Screen': 6,
#   'Downloadable Content': 5,
#   'MMO': 5,
#   'Cross-Platform Multiplayer': 4,
#   'Steam Leaderboards': 3,
#   'Game demo': 2,
#   'Includes Source SDK': 2,
#   'Local Multi-Player': 2,
#   'Mods': 2,
#   'Stats': 2,
#   'Commentary available': 1,
#   'In-App Purchases': 1,
#   'Local Co-op': 1,
#   'Mods (require HL2)': 1,
#   'Online Co-op': 1,
#   'Valve Anti-Cheat enabled': 1,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0},
#  2009: {'Single-player': 312,
#   'Multi-player': 93,
#   'Steam Achievements': 88,
#   'Steam Cloud': 87,
#   'Steam Trading Cards': 65,
#   'Downloadable Content': 57,
#   'Steam Leaderboards': 45,
#   'Full controller support': 39,
#   'Partial Controller Support': 38,
#   'Steam Workshop': 34,
#   'Co-op': 28,
#   'Captions available': 18,
#   'Includes level editor': 16,
#   'Stats': 11,
#   'Shared/Split Screen': 7,
#   'Cross-Platform Multiplayer': 6,
#   'Game demo': 5,
#   'Mods': 4,
#   'Online Multi-Player': 3,
#   'Valve Anti-Cheat enabled': 3,
#   'Commentary available': 2,
#   'In-App Purchases': 2,
#   'MMO': 2,
#   'Mods (require HL2)': 2,
#   'Online Co-op': 2,
#   'Includes Source SDK': 1,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'Mods (require HL1)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2010: {'Single-player': 371,
#   'Steam Achievements': 154,
#   'Multi-player': 148,
#   'Partial Controller Support': 128,
#   'Downloadable Content': 105,
#   'Steam Cloud': 95,
#   'Steam Leaderboards': 75,
#   'Co-op': 56,
#   'Steam Trading Cards': 47,
#   'Stats': 39,
#   'Captions available': 33,
#   'Shared/Split Screen': 33,
#   'Full controller support': 25,
#   'Includes level editor': 17,
#   'Cross-Platform Multiplayer': 14,
#   'Steam Workshop': 6,
#   'Valve Anti-Cheat enabled': 6,
#   'MMO': 3,
#   'Game demo': 2,
#   'Includes Source SDK': 2,
#   'Local Co-op': 2,
#   'Online Multi-Player': 2,
#   'Commentary available': 1,
#   'Mods': 1,
#   'Online Co-op': 1,
#   'In-App Purchases': 0,
#   'Local Multi-Player': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0},
#  2011: {'Single-player': 513,
#   'Steam Achievements': 247,
#   'Downloadable Content': 228,
#   'Multi-player': 226,
#   'Partial Controller Support': 162,
#   'Steam Cloud': 160,
#   'Co-op': 135,
#   'Steam Leaderboards': 127,
#   'Steam Trading Cards': 81,
#   'Shared/Split Screen': 58,
#   'Stats': 57,
#   'Full controller support': 47,
#   'Captions available': 36,
#   'Valve Anti-Cheat enabled': 19,
#   'Includes level editor': 17,
#   'Cross-Platform Multiplayer': 15,
#   'Online Multi-Player': 10,
#   'Steam Workshop': 9,
#   'MMO': 8,
#   'Online Co-op': 6,
#   'Game demo': 5,
#   'Local Co-op': 5,
#   'Local Multi-Player': 4,
#   'Commentary available': 3,
#   'In-App Purchases': 2,
#   'Includes Source SDK': 1,
#   'Steam Turn Notifications': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2012: {'Single-player': 1043,
#   'Downloadable Content': 710,
#   'Steam Achievements': 551,
#   'Multi-player': 444,
#   'Steam Cloud': 404,
#   'Partial Controller Support': 299,
#   'Steam Leaderboards': 282,
#   'Shared/Split Screen': 252,
#   'Co-op': 249,
#   'Steam Trading Cards': 168,
#   'Stats': 139,
#   'Full controller support': 114,
#   'Valve Anti-Cheat enabled': 79,
#   'Captions available': 45,
#   'Cross-Platform Multiplayer': 45,
#   'Includes level editor': 36,
#   'Steam Workshop': 22,
#   'MMO': 18,
#   'Online Multi-Player': 13,
#   'Game demo': 11,
#   'Local Multi-Player': 6,
#   'Commentary available': 5,
#   'In-App Purchases': 5,
#   'Online Co-op': 5,
#   'Steam Turn Notifications': 5,
#   'Local Co-op': 2,
#   'Includes Source SDK': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2013: {'Single-player': 1378,
#   'Steam Achievements': 966,
#   'Downloadable Content': 902,
#   'Steam Cloud': 692,
#   'Multi-player': 646,
#   'Steam Trading Cards': 604,
#   'Steam Leaderboards': 505,
#   'Full controller support': 473,
#   'Co-op': 374,
#   'Partial Controller Support': 324,
#   'Shared/Split Screen': 285,
#   'Stats': 192,
#   'Cross-Platform Multiplayer': 109,
#   'Captions available': 101,
#   'Steam Workshop': 84,
#   'Valve Anti-Cheat enabled': 79,
#   'Includes level editor': 73,
#   'MMO': 39,
#   'Online Multi-Player': 24,
#   'Online Co-op': 18,
#   'Game demo': 17,
#   'In-App Purchases': 16,
#   'Local Co-op': 14,
#   'Local Multi-Player': 12,
#   'Commentary available': 8,
#   'Steam Turn Notifications': 2,
#   'Includes Source SDK': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2014: {'Single-player': 2490,
#   'Steam Achievements': 1726,
#   'Steam Trading Cards': 1386,
#   'Downloadable Content': 1346,
#   'Steam Cloud': 1220,
#   'Steam Leaderboards': 858,
#   'Multi-player': 790,
#   'Partial Controller Support': 734,
#   'Full controller support': 703,
#   'Shared/Split Screen': 484,
#   'Co-op': 425,
#   'Steam Workshop': 306,
#   'Cross-Platform Multiplayer': 250,
#   'Stats': 217,
#   'Captions available': 175,
#   'Includes level editor': 165,
#   'MMO': 99,
#   'Game demo': 92,
#   'Valve Anti-Cheat enabled': 70,
#   'Online Multi-Player': 36,
#   'Online Co-op': 29,
#   'Local Multi-Player': 21,
#   'Commentary available': 20,
#   'In-App Purchases': 13,
#   'Local Co-op': 13,
#   'Includes Source SDK': 11,
#   'Steam Turn Notifications': 2,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2015: {'Single-player': 4354,
#   'Steam Achievements': 2870,
#   'Steam Trading Cards': 2521,
#   'Downloadable Content': 2156,
#   'Steam Cloud': 1888,
#   'Full controller support': 1487,
#   'Multi-player': 1315,
#   'Steam Leaderboards': 1165,
#   'Partial Controller Support': 1114,
#   'Shared/Split Screen': 728,
#   'Co-op': 660,
#   'Stats': 414,
#   'Cross-Platform Multiplayer': 381,
#   'Steam Workshop': 363,
#   'Includes level editor': 280,
#   'Captions available': 259,
#   'Game demo': 181,
#   'MMO': 147,
#   'Online Multi-Player': 91,
#   'Valve Anti-Cheat enabled': 55,
#   'Online Co-op': 53,
#   'Local Co-op': 52,
#   'Local Multi-Player': 52,
#   'Commentary available': 35,
#   'In-App Purchases': 28,
#   'Steam Turn Notifications': 17,
#   'Includes Source SDK': 12,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2016: {'Single-player': 5926,
#   'Steam Achievements': 3962,
#   'Steam Trading Cards': 3571,
#   'Downloadable Content': 3121,
#   'Steam Cloud': 2193,
#   'Full controller support': 1900,
#   'Multi-player': 1770,
#   'Partial Controller Support': 1456,
#   'Steam Leaderboards': 1258,
#   'Co-op': 900,
#   'Shared/Split Screen': 871,
#   'Cross-Platform Multiplayer': 674,
#   'Online Multi-Player': 538,
#   'Stats': 489,
#   'Steam Workshop': 451,
#   'Includes level editor': 336,
#   'Captions available': 300,
#   'Local Multi-Player': 293,
#   'MMO': 275,
#   'In-App Purchases': 256,
#   'Online Co-op': 208,
#   'Local Co-op': 188,
#   'Commentary available': 59,
#   'Valve Anti-Cheat enabled': 38,
#   'Steam Turn Notifications': 33,
#   'Game demo': 27,
#   'Includes Source SDK': 12,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0},
#  2017: {'Single-player': 7990,
#   'Steam Achievements': 5028,
#   'Downloadable Content': 3988,
#   'Steam Trading Cards': 3317,
#   'Steam Cloud': 2754,
#   'Full controller support': 2209,
#   'Multi-player': 2206,
#   'Partial Controller Support': 1941,
#   'Steam Leaderboards': 1407,
#   'Online Multi-Player': 1379,
#   'Co-op': 1310,
#   'Shared/Split Screen': 1122,
#   'Cross-Platform Multiplayer': 933,
#   'Local Multi-Player': 721,
#   'Stats': 607,
#   'Online Co-op': 582,
#   'In-App Purchases': 572,
#   'Steam Workshop': 530,
#   'Captions available': 448,
#   'Local Co-op': 417,
#   'Includes level editor': 337,
#   'MMO': 312,
#   'Valve Anti-Cheat enabled': 90,
#   'Commentary available': 48,
#   'Steam Turn Notifications': 28,
#   'Game demo': 9,
#   'Includes Source SDK': 9,
#   'SteamVR Collectibles': 1,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0},
#  2018: {'Single-player': 147,
#   'Steam Achievements': 68,
#   'Full controller support': 44,
#   'Steam Cloud': 30,
#   'Partial Controller Support': 29,
#   'Steam Trading Cards': 23,
#   'Multi-player': 21,
#   'Online Multi-Player': 18,
#   'Downloadable Content': 15,
#   'Steam Leaderboards': 13,
#   'In-App Purchases': 12,
#   'Shared/Split Screen': 12,
#   'Cross-Platform Multiplayer': 9,
#   'Local Multi-Player': 8,
#   'Captions available': 6,
#   'Local Co-op': 5,
#   'Stats': 5,
#   'Includes level editor': 4,
#   'Co-op': 3,
#   'Steam Workshop': 3,
#   'Online Co-op': 2,
#   'Steam Turn Notifications': 2,
#   'MMO': 1,
#   'Commentary available': 0,
#   'Game demo': 0,
#   'Includes Source SDK': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2019: {'Single-player': 4,
#   'Full controller support': 2,
#   'Steam Achievements': 2,
#   'Steam Cloud': 1,
#   'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2021: {'Downloadable Content': 1,
#   'Single-player': 1,
#   'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Achievements': 0,
#   'Steam Cloud': 0,
#   'Steam Leaderboards': 0,
#   'Steam Trading Cards': 0,
#   'Steam Turn Notifications': 0,
#   'Steam Workshop': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0},
#  2756: {'Single-player': 1,
#   'Steam Achievements': 1,
#   'Steam Cloud': 1,
#   'Steam Trading Cards': 1,
#   'Steam Workshop': 1,
#   'Captions available': 0,
#   'Co-op': 0,
#   'Commentary available': 0,
#   'Cross-Platform Multiplayer': 0,
#   'Downloadable Content': 0,
#   'Full controller support': 0,
#   'Game demo': 0,
#   'In-App Purchases': 0,
#   'Includes Source SDK': 0,
#   'Includes level editor': 0,
#   'Local Co-op': 0,
#   'Local Multi-Player': 0,
#   'MMO': 0,
#   'Mods': 0,
#   'Mods (require HL1)': 0,
#   'Mods (require HL2)': 0,
#   'Multi-player': 0,
#   'Online Co-op': 0,
#   'Online Multi-Player': 0,
#   'Partial Controller Support': 0,
#   'Shared/Split Screen': 0,
#   'Stats': 0,
#   'Steam Leaderboards': 0,
#   'Steam Turn Notifications': 0,
#   'SteamVR Collectibles': 0,
#   'Valve Anti-Cheat enabled': 0}}

# %%
with open("datasets/steam_games_endpoint_3_specs.json", "w") as outfile:
    json.dump(specsEndpointDict_sorted, outfile)

# %% [markdown]
# **TEST**

# %%
def specs( Year: str ):
    """
    Se ingresa un año y devuelve un diccionario con los 5 specs que más se repiten en el mismo en el orden correspondiente.
    """
    # Read data
    with open("datasets/steam_games_endpoint_3_specs.json") as json_file:
        specs_dict = json.load(json_file)

    # TODO Add validation

    # Since data is already sorted, get the first 5 as top 5.
    top5 = dict(list(specs_dict[Year].items())[0:5])
    return top5

specs('2018')
# Out:
# {'Single-player': 147,
#  'Steam Achievements': 68,
#  'Full controller support': 44,
#  'Steam Cloud': 30,
#  'Partial Controller Support': 29}

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 4: earlyacces
#
# def earlyaccess( Año: str ): Cantidad de juegos lanzados en un año con early access.
#
# Example:
# | Year | earlyacces |
# | -- | - |
# | 2018 | {125} |
# | 2016 | {1234} |
#
# For this case the only thing that matters to us is "earlyacces" and "year" columns, so we can drop the other ones.

# %%
earlyaccessEndpointDf = gamesWithYearDf[['early_access', 'year']]
earlyaccessEndpointDf.head()
# Out:
#    early_access  year
# 0         False  2018
# 1         False  2018
# 2         False  2017
# 3         False  2017
# 5         False  2018

# %% [markdown]
# Now we can drop all the columns that have a NaN in any of the two columns because they will bring no information to the scope of the genero function.

# %%
earlyaccessEndpointDf['early_access'].describe()
# Out:
# count     29965
# unique        2
# top       False
# freq      28519
# Name: early_access, dtype: object

# %%
earlyaccessEndpointDf.isna().sum()
# Out:
# early_access    0
# year            0
# dtype: int64

# %% [markdown]
# ### Early Access
#
# Just need to group by by ear and count amount of early acces games.

# %%
earlyaccessEndpointDf2 = earlyaccessEndpointDf.groupby(by=['year']).sum()
earlyaccessEndpointDf2.tail()
# Out:
#       early_access
# year
# 2017           733
# 2018            33
# 2019             1
# 2021             0
# 2756             1

# %%
# Now we have exactly what we need.
earlyaccessEndpointDict = earlyaccessEndpointDf2.to_dict()
earlyaccessEndpointDict
# Out:
# {'early_access': {1970: 0,
#   1975: 0,
#   1980: 0,
#   1981: 0,
#   1982: 0,
#   1983: 0,
#   1984: 0,
#   1985: 0,
#   1986: 0,
#   1987: 0,
#   1988: 0,
#   1989: 0,
#   1990: 0,
#   1991: 0,
#   1992: 0,
#   1993: 0,
#   1994: 0,
#   1995: 0,
#   1996: 0,
#   1997: 0,
#   1998: 0,
#   1999: 0,
#   2000: 0,
#   2001: 1,
#   2002: 0,
#   2003: 0,
#   2004: 0,
#   2005: 0,
#   2006: 0,
#   2007: 0,
#   2008: 0,
#   2009: 0,
#   2010: 0,
#   2011: 0,
#   2012: 2,
#   2013: 10,
#   2014: 78,
#   2015: 224,
#   2016: 363,
#   2017: 733,
#   2018: 33,
#   2019: 1,
#   2021: 0,
#   2756: 1}}

# %%
with open("datasets/steam_games_endpoint_4_earlyaccess.json", "w") as outfile:
    json.dump(earlyaccessEndpointDict, outfile)

# %% [markdown]
# **TEST**

# %%
def earlyacces( Year: str ):
    """
    Cantidad de juegos lanzados en un año con early access.
    """
    # Read data
    with open("datasets/steam_games_endpoint_4_earlyaccess.json") as json_file:
        earlyaccess_dict = json.load(json_file)

    # TODO Add validation, Top5 si teine al menos 5

    return {"Año": Year, "Early Access": earlyaccess_dict['early_access'][Year]}


earlyacces('2015')
# Out:
# {'Año': '2015', 'Early Access': 224}

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 5: sentiment
#
# def sentiment( Año: str ): Según el año de lanzamiento, se devuelve una lista con la cantidad de registros que se encuentren categorizados con un análisis de sentimiento.
#
# Ejemplo de retorno: {Mixed = 182, Very Positive = 120, Positive = 278}
#
# For this case the only thing that matters to us is "sentiment" and "year" columns, so we can drop the other ones.

# %%
sentimentEndpointDf = gamesWithYearDf[['sentiment', 'year']]
sentimentEndpointDf.head()
# Out:
#          sentiment  year
# 0              NaN  2018
# 1  Mostly Positive  2018
# 2  Mostly Positive  2017
# 3              NaN  2017
# 5            Mixed  2018

# %% [markdown]
# Now we can drop all the columns that have a NaN in any of the two columns because they will bring no information to the scope of the genero function.

# %%
sentimentEndpointDf.shape
# Out:
# (29965, 2)

# %%
sentimentEndpointDf.isna().sum()
# Out:
# sentiment    6811
# year            0
# dtype: int64

# %%
sentimentEndpointDf = sentimentEndpointDf.dropna()

# %%
sentimentEndpointDf.isna().sum()
# Out:
# sentiment    0
# year         0
# dtype: int64

# %%
sentimentEndpointDf.shape
# Out:
# (23154, 2)

# %% [markdown]
# ### Sentiment
#
# In this column we have various "sentiment" attributes. In the case that there are too few reviews it puts the amount of reviews instead of sentiment.
#
# We could remove all that have "% user reviews"

# %%
sentimentEndpointDf['sentiment'].value_counts()
# Out:
# sentiment
# Mixed                      3861
# Very Positive              3659
# Positive                   2965
# Mostly Positive            2563
# 1 user reviews             2348
# 2 user reviews             1633
# 3 user reviews             1127
# 4 user reviews              882
# 5 user reviews              771
# Mostly Negative             771
# 6 user reviews              673
# 7 user reviews              548
# 8 user reviews              475
# 9 user reviews              433
# Overwhelmingly Positive     293
# Negative                    116
# Very Negative                29
# Overwhelmingly Negative       7
# Name: count, dtype: int64

# %%
# Pattern of regex to extract "% user reviews".
pattern_to_del = '[0-9] user reviews'

filter = sentimentEndpointDf['sentiment'].str.contains(pattern_to_del)

sentimentEndpointDf2 = sentimentEndpointDf[~filter]

# %%
sentimentEndpointDf2['sentiment'].value_counts()
# Out:
# sentiment
# Mixed                      3861
# Very Positive              3659
# Positive                   2965
# Mostly Positive            2563
# Mostly Negative             771
# Overwhelmingly Positive     293
# Negative                    116
# Very Negative                29
# Overwhelmingly Negative       7
# Name: count, dtype: int64

# %% [markdown]
# Now we can make a Groupby to get all the genres of each year. Then unstack it and have a new Data Frame with the data we desire.

# %%
sentimentEndpointDf3 = sentimentEndpointDf2.groupby(by=['year', 'sentiment'])['sentiment'].count()
sentimentEndpointDf3.tail()
# Out:
# year  sentiment
# 2018  Mixed              6
#       Mostly Negative    1
#       Mostly Positive    3
#       Very Positive      3
# 2021  Positive           1
# Name: sentiment, dtype: int64

# %%
sentimentEndpointDf4 = sentimentEndpointDf3.unstack(level=1, fill_value=0)
sentimentEndpointDf4.head()
# Out:
# sentiment  Mixed  Mostly Negative  Mostly Positive  Negative
# year
# 1982           0                0                0         0  \
# 1983           0                0                0         0
# 1984           0                0                0         0
# 1986           1                0                0         0
# 1987           2                0                1         0
#
# sentiment  Overwhelmingly Negative  Overwhelmingly Positive  Positive
# year
# 1982                             0                        0         1  \
# 1983                             0                        0         0
# 1984                             0                        0         1
# 1986                             0                        0         0
# 1987                             0                        0         1
#
# sentiment  Very Negative  Very Positive
# year
# 1982                   0              0
# 1983                   0              1
# 1984                   0              1
# 1986                   0              0
# 1987                   0              0

# %%
# Now we have exactly what we need.
sentimentEndpointDict = sentimentEndpointDf4.to_dict(orient='index')
sentimentEndpointDict
# Out:
# {1982: {'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 1,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1983: {'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 1},
#  1984: {'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 1,
#   'Very Negative': 0,
#   'Very Positive': 1},
#  1986: {'Mixed': 1,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1987: {'Mixed': 2,
#   'Mostly Negative': 0,
#   'Mostly Positive': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 1,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1988: {'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 2,
#   'Very Negative': 0,
#   'Very Positive': 1},
#  1989: {'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 2,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 1,
#   'Very Negative': 0,
#   'Very Positive': 2},
#  1990: {'Mixed': 3,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 1,
#   'Very Negative': 0,
#   'Very Positive': 3},
#  1991: {'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 5,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1992: {'Mixed': 2,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 5,
#   'Very Negative': 0,
#   'Very Positive': 3},
#  1993: {'Mixed': 1,
#   'Mostly Negative': 1,
#   'Mostly Positive': 3,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 1,
#   'Positive': 9,
#   'Very Negative': 0,
#   'Very Positive': 2},
#  1994: {'Mixed': 2,
#   'Mostly Negative': 0,
#   'Mostly Positive': 5,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 11,
#   'Very Negative': 0,
#   'Very Positive': 6},
#  1995: {'Mixed': 4,
#   'Mostly Negative': 1,
#   'Mostly Positive': 3,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 7,
#   'Very Negative': 0,
#   'Very Positive': 9},
#  1996: {'Mixed': 1,
#   'Mostly Negative': 1,
#   'Mostly Positive': 4,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 12,
#   'Very Negative': 0,
#   'Very Positive': 11},
#  1997: {'Mixed': 2,
#   'Mostly Negative': 0,
#   'Mostly Positive': 7,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 2,
#   'Positive': 9,
#   'Very Negative': 0,
#   'Very Positive': 13},
#  1998: {'Mixed': 8,
#   'Mostly Negative': 0,
#   'Mostly Positive': 11,
#   'Negative': 2,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 2,
#   'Positive': 7,
#   'Very Negative': 0,
#   'Very Positive': 15},
#  1999: {'Mixed': 7,
#   'Mostly Negative': 0,
#   'Mostly Positive': 6,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 1,
#   'Positive': 3,
#   'Very Negative': 0,
#   'Very Positive': 22},
#  2000: {'Mixed': 7,
#   'Mostly Negative': 0,
#   'Mostly Positive': 7,
#   'Negative': 1,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 3,
#   'Positive': 3,
#   'Very Negative': 0,
#   'Very Positive': 12},
#  2001: {'Mixed': 11,
#   'Mostly Negative': 5,
#   'Mostly Positive': 7,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 1,
#   'Positive': 5,
#   'Very Negative': 0,
#   'Very Positive': 24},
#  2002: {'Mixed': 8,
#   'Mostly Negative': 1,
#   'Mostly Positive': 7,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 3,
#   'Positive': 8,
#   'Very Negative': 0,
#   'Very Positive': 13},
#  2003: {'Mixed': 16,
#   'Mostly Negative': 1,
#   'Mostly Positive': 20,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 2,
#   'Positive': 7,
#   'Very Negative': 0,
#   'Very Positive': 23},
#  2004: {'Mixed': 15,
#   'Mostly Negative': 1,
#   'Mostly Positive': 11,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 6,
#   'Positive': 4,
#   'Very Negative': 0,
#   'Very Positive': 25},
#  2005: {'Mixed': 16,
#   'Mostly Negative': 0,
#   'Mostly Positive': 21,
#   'Negative': 1,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 1,
#   'Positive': 6,
#   'Very Negative': 0,
#   'Very Positive': 40},
#  2006: {'Mixed': 41,
#   'Mostly Negative': 1,
#   'Mostly Positive': 24,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 5,
#   'Positive': 15,
#   'Very Negative': 0,
#   'Very Positive': 40},
#  2007: {'Mixed': 40,
#   'Mostly Negative': 3,
#   'Mostly Positive': 19,
#   'Negative': 1,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 5,
#   'Positive': 16,
#   'Very Negative': 2,
#   'Very Positive': 45},
#  2008: {'Mixed': 45,
#   'Mostly Negative': 4,
#   'Mostly Positive': 33,
#   'Negative': 1,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 3,
#   'Positive': 19,
#   'Very Negative': 0,
#   'Very Positive': 53},
#  2009: {'Mixed': 65,
#   'Mostly Negative': 18,
#   'Mostly Positive': 50,
#   'Negative': 2,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 7,
#   'Positive': 21,
#   'Very Negative': 0,
#   'Very Positive': 77},
#  2010: {'Mixed': 73,
#   'Mostly Negative': 22,
#   'Mostly Positive': 55,
#   'Negative': 0,
#   'Overwhelmingly Negative': 1,
#   'Overwhelmingly Positive': 14,
#   'Positive': 28,
#   'Very Negative': 1,
#   'Very Positive': 102},
#  2011: {'Mixed': 89,
#   'Mostly Negative': 20,
#   'Mostly Positive': 56,
#   'Negative': 1,
#   'Overwhelmingly Negative': 1,
#   'Overwhelmingly Positive': 12,
#   'Positive': 50,
#   'Very Negative': 1,
#   'Very Positive': 129},
#  2012: {'Mixed': 148,
#   'Mostly Negative': 27,
#   'Mostly Positive': 101,
#   'Negative': 4,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 20,
#   'Positive': 111,
#   'Very Negative': 2,
#   'Very Positive': 191},
#  2013: {'Mixed': 223,
#   'Mostly Negative': 35,
#   'Mostly Positive': 148,
#   'Negative': 3,
#   'Overwhelmingly Negative': 2,
#   'Overwhelmingly Positive': 26,
#   'Positive': 176,
#   'Very Negative': 4,
#   'Very Positive': 277},
#  2014: {'Mixed': 468,
#   'Mostly Negative': 99,
#   'Mostly Positive': 335,
#   'Negative': 27,
#   'Overwhelmingly Negative': 1,
#   'Overwhelmingly Positive': 37,
#   'Positive': 237,
#   'Very Negative': 7,
#   'Very Positive': 431},
#  2015: {'Mixed': 829,
#   'Mostly Negative': 165,
#   'Mostly Positive': 495,
#   'Negative': 31,
#   'Overwhelmingly Negative': 1,
#   'Overwhelmingly Positive': 53,
#   'Positive': 535,
#   'Very Negative': 2,
#   'Very Positive': 658},
#  2016: {'Mixed': 941,
#   'Mostly Negative': 215,
#   'Mostly Positive': 562,
#   'Negative': 23,
#   'Overwhelmingly Negative': 1,
#   'Overwhelmingly Positive': 49,
#   'Positive': 695,
#   'Very Negative': 6,
#   'Very Positive': 767},
#  2017: {'Mixed': 787,
#   'Mostly Negative': 150,
#   'Mostly Positive': 566,
#   'Negative': 19,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 40,
#   'Positive': 953,
#   'Very Negative': 4,
#   'Very Positive': 660},
#  2018: {'Mixed': 6,
#   'Mostly Negative': 1,
#   'Mostly Positive': 3,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 3},
#  2021: {'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 1,
#   'Very Negative': 0,
#   'Very Positive': 0}}

# %% [markdown]
# Sort by values.

# %%
sentimentEndpointDict_sorted = sort_dic(sentimentEndpointDict)
sentimentEndpointDict_sorted
# Out:
# {1982: {'Positive': 1,
#   'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1983: {'Very Positive': 1,
#   'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 0,
#   'Very Negative': 0},
#  1984: {'Positive': 1,
#   'Very Positive': 1,
#   'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1986: {'Mixed': 1,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1987: {'Mixed': 2,
#   'Mostly Positive': 1,
#   'Positive': 1,
#   'Mostly Negative': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1988: {'Positive': 2,
#   'Very Positive': 1,
#   'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1989: {'Mostly Positive': 2,
#   'Very Positive': 2,
#   'Positive': 1,
#   'Mixed': 0,
#   'Mostly Negative': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1990: {'Mixed': 3,
#   'Very Positive': 3,
#   'Positive': 1,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1991: {'Positive': 5,
#   'Mostly Positive': 1,
#   'Mixed': 0,
#   'Mostly Negative': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 0},
#  1992: {'Positive': 5,
#   'Very Positive': 3,
#   'Mixed': 2,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1993: {'Positive': 9,
#   'Mostly Positive': 3,
#   'Very Positive': 2,
#   'Mixed': 1,
#   'Mostly Negative': 1,
#   'Overwhelmingly Positive': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  1994: {'Positive': 11,
#   'Very Positive': 6,
#   'Mostly Positive': 5,
#   'Mixed': 2,
#   'Mostly Negative': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1995: {'Very Positive': 9,
#   'Positive': 7,
#   'Mixed': 4,
#   'Mostly Positive': 3,
#   'Mostly Negative': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1996: {'Positive': 12,
#   'Very Positive': 11,
#   'Mostly Positive': 4,
#   'Mixed': 1,
#   'Mostly Negative': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0},
#  1997: {'Very Positive': 13,
#   'Positive': 9,
#   'Mostly Positive': 7,
#   'Mixed': 2,
#   'Overwhelmingly Positive': 2,
#   'Mostly Negative': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  1998: {'Very Positive': 15,
#   'Mostly Positive': 11,
#   'Mixed': 8,
#   'Positive': 7,
#   'Negative': 2,
#   'Overwhelmingly Positive': 2,
#   'Mostly Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  1999: {'Very Positive': 22,
#   'Mixed': 7,
#   'Mostly Positive': 6,
#   'Positive': 3,
#   'Overwhelmingly Positive': 1,
#   'Mostly Negative': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2000: {'Very Positive': 12,
#   'Mixed': 7,
#   'Mostly Positive': 7,
#   'Overwhelmingly Positive': 3,
#   'Positive': 3,
#   'Negative': 1,
#   'Mostly Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2001: {'Very Positive': 24,
#   'Mixed': 11,
#   'Mostly Positive': 7,
#   'Mostly Negative': 5,
#   'Positive': 5,
#   'Overwhelmingly Positive': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2002: {'Very Positive': 13,
#   'Mixed': 8,
#   'Positive': 8,
#   'Mostly Positive': 7,
#   'Overwhelmingly Positive': 3,
#   'Mostly Negative': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2003: {'Very Positive': 23,
#   'Mostly Positive': 20,
#   'Mixed': 16,
#   'Positive': 7,
#   'Overwhelmingly Positive': 2,
#   'Mostly Negative': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2004: {'Very Positive': 25,
#   'Mixed': 15,
#   'Mostly Positive': 11,
#   'Overwhelmingly Positive': 6,
#   'Positive': 4,
#   'Mostly Negative': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2005: {'Very Positive': 40,
#   'Mostly Positive': 21,
#   'Mixed': 16,
#   'Positive': 6,
#   'Negative': 1,
#   'Overwhelmingly Positive': 1,
#   'Mostly Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2006: {'Mixed': 41,
#   'Very Positive': 40,
#   'Mostly Positive': 24,
#   'Positive': 15,
#   'Overwhelmingly Positive': 5,
#   'Mostly Negative': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2007: {'Very Positive': 45,
#   'Mixed': 40,
#   'Mostly Positive': 19,
#   'Positive': 16,
#   'Overwhelmingly Positive': 5,
#   'Mostly Negative': 3,
#   'Very Negative': 2,
#   'Negative': 1,
#   'Overwhelmingly Negative': 0},
#  2008: {'Very Positive': 53,
#   'Mixed': 45,
#   'Mostly Positive': 33,
#   'Positive': 19,
#   'Mostly Negative': 4,
#   'Overwhelmingly Positive': 3,
#   'Negative': 1,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2009: {'Very Positive': 77,
#   'Mixed': 65,
#   'Mostly Positive': 50,
#   'Positive': 21,
#   'Mostly Negative': 18,
#   'Overwhelmingly Positive': 7,
#   'Negative': 2,
#   'Overwhelmingly Negative': 0,
#   'Very Negative': 0},
#  2010: {'Very Positive': 102,
#   'Mixed': 73,
#   'Mostly Positive': 55,
#   'Positive': 28,
#   'Mostly Negative': 22,
#   'Overwhelmingly Positive': 14,
#   'Overwhelmingly Negative': 1,
#   'Very Negative': 1,
#   'Negative': 0},
#  2011: {'Very Positive': 129,
#   'Mixed': 89,
#   'Mostly Positive': 56,
#   'Positive': 50,
#   'Mostly Negative': 20,
#   'Overwhelmingly Positive': 12,
#   'Negative': 1,
#   'Overwhelmingly Negative': 1,
#   'Very Negative': 1},
#  2012: {'Very Positive': 191,
#   'Mixed': 148,
#   'Positive': 111,
#   'Mostly Positive': 101,
#   'Mostly Negative': 27,
#   'Overwhelmingly Positive': 20,
#   'Negative': 4,
#   'Very Negative': 2,
#   'Overwhelmingly Negative': 0},
#  2013: {'Very Positive': 277,
#   'Mixed': 223,
#   'Positive': 176,
#   'Mostly Positive': 148,
#   'Mostly Negative': 35,
#   'Overwhelmingly Positive': 26,
#   'Very Negative': 4,
#   'Negative': 3,
#   'Overwhelmingly Negative': 2},
#  2014: {'Mixed': 468,
#   'Very Positive': 431,
#   'Mostly Positive': 335,
#   'Positive': 237,
#   'Mostly Negative': 99,
#   'Overwhelmingly Positive': 37,
#   'Negative': 27,
#   'Very Negative': 7,
#   'Overwhelmingly Negative': 1},
#  2015: {'Mixed': 829,
#   'Very Positive': 658,
#   'Positive': 535,
#   'Mostly Positive': 495,
#   'Mostly Negative': 165,
#   'Overwhelmingly Positive': 53,
#   'Negative': 31,
#   'Very Negative': 2,
#   'Overwhelmingly Negative': 1},
#  2016: {'Mixed': 941,
#   'Very Positive': 767,
#   'Positive': 695,
#   'Mostly Positive': 562,
#   'Mostly Negative': 215,
#   'Overwhelmingly Positive': 49,
#   'Negative': 23,
#   'Very Negative': 6,
#   'Overwhelmingly Negative': 1},
#  2017: {'Positive': 953,
#   'Mixed': 787,
#   'Very Positive': 660,
#   'Mostly Positive': 566,
#   'Mostly Negative': 150,
#   'Overwhelmingly Positive': 40,
#   'Negative': 19,
#   'Very Negative': 4,
#   'Overwhelmingly Negative': 0},
#  2018: {'Mixed': 6,
#   'Mostly Positive': 3,
#   'Very Positive': 3,
#   'Mostly Negative': 1,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Positive': 0,
#   'Very Negative': 0},
#  2021: {'Positive': 1,
#   'Mixed': 0,
#   'Mostly Negative': 0,
#   'Mostly Positive': 0,
#   'Negative': 0,
#   'Overwhelmingly Negative': 0,
#   'Overwhelmingly Positive': 0,
#   'Very Negative': 0,
#   'Very Positive': 0}}

# %%
with open("datasets/steam_games_endpoint_5_sentiment.json", "w") as outfile:
    json.dump(sentimentEndpointDict_sorted, outfile)

# %% [markdown]
# **TEST**

# %%
def sentiment( Year: str ):
    """
    Según el año de lanzamiento, se devuelve una lista con la cantidad de registros que se encuentren categorizados con un análisis de sentimiento.

    Ejemplo de retorno: {Mixed = 182, Very Positive = 120, Positive = 278}
    """
    # Read data
    with open("datasets/steam_games_endpoint_5_sentiment.json") as json_file:
        sentiment_dict = json.load(json_file)

    # TODO Add validation

    return {"Año": Year, "Sentiment": sentiment_dict[Year]}

sentiment('2016')
# Out:
# {'Año': '2016',
#  'Sentiment': {'Mixed': 941,
#   'Very Positive': 767,
#   'Positive': 695,
#   'Mostly Positive': 562,
#   'Mostly Negative': 215,
#   'Overwhelmingly Positive': 49,
#   'Negative': 23,
#   'Very Negative': 6,
#   'Overwhelmingly Negative': 1}}

# %% [markdown]
# ---

# %% [markdown]
# ## Endpoint 6: metascore
#
# def metascore( Año: str ): Top 5 juegos según año con mayor metascore.
#
# Example:
# | Year | Genres |
# | -- | - |
# | 2018 | {'Game7': 85, 'Game91': 75, 'Game1232': 74, ...} |
# | 2017 | {'Game56': 98, 'Game6': 84, 'Game32': 82, ...} |
#
# For this case the only thing that matters to us is "metascore", "app_name" and "year" columns, so we can drop the other ones.

# %%
metascoreEndpointDf = gamesWithYearDf[['app_name', 'metascore', 'year']]
metascoreEndpointDf.head()
# Out:
#                   app_name metascore  year
# 0      Lost Summoner Kitty       NaN  2018
# 1                Ironbound       NaN  2018
# 2  Real Pool 3D - Poolians       NaN  2017
# 3                  弹炸人2222       NaN  2017
# 5    Battle Royale Trainer       NaN  2018

# %% [markdown]
# Now we can drop all the columns that have a NaN in any of the two columns because they will bring no information to the scope of the metascore function.

# %%
metascoreEndpointDf.shape
# Out:
# (29965, 3)

# %%
metascoreEndpointDf.isna().sum()
# Out:
# app_name         0
# metascore    27343
# year             0
# dtype: int64

# %%
metascoreEndpointDf = metascoreEndpointDf.dropna()

# %%
metascoreEndpointDf.isna().sum()
# Out:
# app_name     0
# metascore    0
# year         0
# dtype: int64

# %%
metascoreEndpointDf.shape
# Out:
# (2622, 3)

# %% [markdown]
# ### Metascore

# %%
metascoreEndpointDf.shape
# Out:
# (2622, 3)

# %%
metascoreEndpointDf.head()
# Out:
#                            app_name metascore  year
# 28                        Half-Life        96  1998
# 39   Disciples II: Gallean's Return        84  2006
# 40  Disciples II: Rise of the Elves        80  2006
# 41           The Ship: Murder Party        76  2006
# 55                    Advent Rising        70  2005

# %%
metascoreEndpointDf['metascore'].unique()
# Out:
# array([96, 84, 80, 76, 70, 'NA', 69, 81, 75, 72, 66, 67, 77, 91, 89, 83,
#        61, 88, 65, 94, 57, 86, 87, 92, 79, 82, 58, 74, 85, 90, 68, 71, 60,
#        73, 59, 64, 54, 53, 78, 51, 44, 63, 38, 56, 49, 52, 62, 93, 48, 34,
#        95, 43, 55, 24, 46, 41, 20, 39, 45, 35, 47, 40, 36, 50, 32, 37, 33,
#        42, 27, 29, 30], dtype=object)

# %% [markdown]
# Convert to int, remove 'NA' to metascore because it does not give us any information.

# %%
metascoreEndpointDf = metascoreEndpointDf[metascoreEndpointDf['metascore'] != 'NA']

# %%
metascoreEndpointDf.shape
# Out:
# (2552, 3)

# %%
metascoreEndpointDf['metascore'].unique()
# Out:
# array([96, 84, 80, 76, 70, 69, 81, 75, 72, 66, 67, 77, 91, 89, 83, 61, 88,
#        65, 94, 57, 86, 87, 92, 79, 82, 58, 74, 85, 90, 68, 71, 60, 73, 59,
#        64, 54, 53, 78, 51, 44, 63, 38, 56, 49, 52, 62, 93, 48, 34, 95, 43,
#        55, 24, 46, 41, 20, 39, 45, 35, 47, 40, 36, 50, 32, 37, 33, 42, 27,
#        29, 30], dtype=object)

# %% [markdown]
# Now we can make a Groupby to get all the genres of each year. Then unstack it and have a new Data Frame with the data we desire.

# %%
metascoreEndpointDf2 = metascoreEndpointDf.groupby(by=['year']).apply(lambda df: dict(zip(df['app_name'], df['metascore'])))
metascoreEndpointDf2.head(20)
# Out:
# year
# 1992                               {'Reservoir Dogs': 50}
# 1993                                     {'realMYST': 66}
# 1994                                      {'DOOM II': 83}
# 1996    {'Harvester': 53, 'Star Control: Kessari Quadr...
# 1997    {'POSTAL': 56, 'The Last Express Gold Edition'...
# 1998    {'Half-Life': 96, 'Railroad Tycoon II Platinum...
# 1999    {'X: Beyond the Frontier': 67, 'Gabriel Knight...
# 2000    {'The Longest Journey': 91, 'Unreal Tournament...
# 2001    {'Return to Castle Wolfenstein': 88, 'Max Payn...
# 2002    {'Arx Fatalis': 77, 'The Sum of All Fears': 72...
# 2003    {'Ghost Master®': 81, 'Railroad Tycoon 3': 80,...
# 2004    {'Rome: Total War™ - Collection': 92, 'Manhunt...
# 2005    {'Advent Rising': 70, 'FlatOut': 72, 'Act of W...
# 2006    {'Disciples II: Gallean's Return': 84, 'Discip...
# 2007    {'Lost Planet™: Extreme Condition': 66, 'Tomb ...
# 2008    {'Command & Conquer: Red Alert 3': 82, 'Confli...
# 2009    {'Saints Row 2': 72, 'Mirror's Edge™': 81, 'F....
# 2010    {'Avencast: Rise of the Mage': 68, 'UFO: Extra...
# 2011    {'Mafia II': 77, 'Zeit²': 72, 'A.R.E.S.: Extin...
# 2012    {'Hard Reset Extended Edition': 73, 'Oil Rush'...
# dtype: object

# %%
# Now we have exactly what we need.
metascoreEndpointDict = metascoreEndpointDf2.to_dict()
metascoreEndpointDict
# Out:
# {1992: {'Reservoir Dogs': 50},
#  1993: {'realMYST': 66},
#  1994: {'DOOM II': 83},
#  1996: {'Harvester': 53,
#   'Star Control: Kessari Quadrant': 89,
#   'FROM DUSK TILL DAWN': 58,
#   'Lords of the Realm II': 77},
#  1997: {'POSTAL': 56,
#   'The Last Express Gold Edition': 82,
#   'Total Annihilation': 86,
#   'Fallout: A Post Nuclear Role Playing Game': 89,
#   'Tony Tough and the Night of Roasted Moths': 68,
#   'Shadow Warrior (Classic)': 73,
#   'Riven: The Sequel to MYST': 83,
#   'STAR WARS™ Jedi Knight: Dark Forces II': 91},
#  1998: {'Half-Life': 96,
#   'Railroad Tycoon II Platinum': 89,
#   'Fallout 2: A Post Nuclear Role Playing Game': 86,
#   'Shogo: Mobile Armor Division': 88,
#   'Falcon 4.0': 85,
#   'Blood: One Unit Whole Blood': 82,
#   'Blood II: The Chosen + Expansion': 72,
#   'Thief™ Gold': 92},
#  1999: {'X: Beyond the Frontier': 67,
#   'Gabriel Knight® 3: Blood of the Sacred, Blood of the Damned': 80,
#   'Army Men II': 67,
#   'Septerra Core': 72,
#   'System Shock 2': 92,
#   'Dawn of Discovery™: Venice': 78},
#  2000: {'The Longest Journey': 91,
#   'Unreal Tournament: Game of the Year Edition': 92,
#   'Sacrifice': 89,
#   'Call to Power II': 72,
#   'Vampire: The Masquerade - Redemption': 74,
#   'Beachhead 2000': 46,
#   'Hidden & Dangerous: Action Pack': 74,
#   'Ground Control Anthology': 86,
#   'B-17 Flying Fortress: The Mighty 8th': 82,
#   'Soulbringer': 70,
#   'Earth 2150 Trilogy': 78,
#   'Thief™ II: The Metal Age': 87,
#   'MDK 2': 83,
#   'Delta Force Land Warrior': 74,
#   'QUAKE III: Team Arena': 69,
#   'Hitman: Codename 47': 73,
#   'Deus Ex: Game of the Year Edition': 90,
#   'Counter-Strike': 88},
#  2001: {'Return to Castle Wolfenstein': 88,
#   'Max Payne': 89,
#   'X-COM: Enforcer': 65,
#   'Fallout Tactics: Brotherhood of Steel': 82,
#   'Serious Sam Classic: The First Encounter': 87,
#   'AquaNox': 67,
#   'Legacy of Kain: Soul Reaver 2': 77,
#   'Startopia': 86,
#   'Anachronox': 77,
#   'Desperados: Wanted Dead or Alive': 78,
#   'Hostile Waters: Antaeus Rising': 80,
#   'The Cameron Files: The Secret at Loch Ness': 66,
#   'The Corporate Machine': 80,
#   'Conquest: Frontier Wars': 80,
#   'Deadly Dozen': 56,
#   'Anarchy Online': 72,
#   'WWII Online': 73,
#   'Independence War® 2: Edge of Chaos': 83,
#   'Echelon': 70,
#   'Eurofighter Typhoon': 69,
#   'Dracula 2: The Last Sanctuary': 68,
#   'Summoner': 78,
#   'Etherlords': 77,
#   'Original War': 61,
#   'Stronghold HD': 81,
#   'World War III: Black Gold': 71,
#   'Wizardry 8': 85,
#   "Kohan: Ahriman's Gift": 79,
#   'Kohan: Immortal Sovereigns': 87,
#   'Cossacks: European Wars': 74,
#   'Red Faction': 78,
#   'Comanche 4': 74,
#   "Tom Clancy's Ghost Recon®": 80,
#   "Sid Meier's Civilization® III Complete": 90,
#   'Sub Command': 84,
#   'Gothic 1': 81,
#   'Half-Life: Blue Shift': 71},
#  2002: {'Arx Fatalis': 77,
#   'The Sum of All Fears': 72,
#   'Freedom Force': 90,
#   'The Elder Scrolls III: Morrowind® Game of the Year Edition': 89,
#   'Cossacks: Back to War': 60,
#   'Serious Sam Classic: The Second Encounter': 85,
#   'Grand Theft Auto III': 93,
#   'Divine Divinity': 81,
#   'Dark Fall: The Journal': 68,
#   'Warrior Kings': 73,
#   'Army Men RTS': 67,
#   'The Guild Gold Edition': 82,
#   'RollerCoaster Tycoon® 2: Triple Thrill Pack': 74,
#   'Iron Storm': 69,
#   'Incoming Forces': 67,
#   'MoonBase Commander': 77,
#   'Stronghold Crusader HD': 78,
#   'Conflict Desert Storm™': 56,
#   'Worms Blast': 73,
#   'Post Mortem': 71,
#   'Robin Hood: The Legend of Sherwood': 80,
#   'Cossacks: Art of War': 74,
#   'Syberia': 82,
#   'Dungeon Siege': 86,
#   'STAR WARS™ Starfighter™': 71,
#   'Delta Force: Task Force Dagger': 51,
#   "Tom Clancy's Ghost Recon® Desert Siege™": 82,
#   "Tom Clancy's Ghost Recon® Island Thunder™": 82,
#   'Hitman 2: Silent Assassin': 87,
#   'Commandos 2: Men of Courage': 87,
#   'Mafia': 88},
#  2003: {'Ghost Master®': 81,
#   'Railroad Tycoon 3': 80,
#   'BloodRayne': 65,
#   'Midnight Club 2': 81,
#   'Max Payne 2: The Fall of Max Payne': 86,
#   'Unreal 2: The Awakening': 75,
#   "Tom Clancy's Splinter Cell®": 91,
#   "Tom Clancy's Rainbow Six® 3 Gold": 85,
#   'Armed and Dangerous®': 78,
#   'Massive Assault': 77,
#   'AquaNox 2: Revelation': 59,
#   'Grand Theft Auto: Vice City': 94,
#   'POSTAL 2': 59,
#   'Legacy of Kain: Defiance': 70,
#   'RC Cars': 65,
#   'Warrior Kings: Battles': 64,
#   'Black Mirror I': 65,
#   'Curse: The Eye of Isis': 63,
#   'Tron 2.0': 84,
#   'Highland Warriors': 58,
#   'Journey to the Center of the Earth': 65,
#   'Hidden & Dangerous 2: Courage Under Fire': 75,
#   'Line of Sight: Vietnam': 68,
#   'Master of Orion 3': 64,
#   'Impossible Creatures Steam Edition': 72,
#   'Railroad Pioneer': 50,
#   'Salammbô: Battle for Carthage': 77,
#   "Rocko's Quest": 41,
#   'Praetorians': 78,
#   'Nosferatu: The Wrath of Malachi': 70,
#   'Etherlords II': 78,
#   'Ragnarok Online': 79,
#   'Enclave': 71,
#   'American Conquest: Fight Back': 66,
#   'American Conquest': 76,
#   'EVE Online': 88,
#   'Chaser': 66,
#   'Broken Sword 3 - the Sleeping Dragon': 82,
#   'Nancy Drew®: The Haunted Carousel': 85,
#   'Nancy Drew®: Danger on Deception Island': 81,
#   'STAR WARS™ Jedi Knight II - Jedi Outcast™': 89,
#   'STAR WARS™ Jedi Knight - Jedi Academy™': 81,
#   'Red Faction II': 64,
#   'Delta Force: Black Hawk Down': 77,
#   'Prince of Persia®: The Sands of Time': 89,
#   'Commandos 3: Destination Berlin': 72,
#   'Runaway, A Road Adventure': 74,
#   'Call of Duty®': 91,
#   'X2: The Threat': 72,
#   'Day of Defeat': 79},
#  2004: {'Rome: Total War™ - Collection': 92,
#   'Manhunt': 75,
#   'Far Cry®': 89,
#   'Port Royale 2': 75,
#   'Beyond Divinity': 73,
#   'Dark Fall 2: Lights Out': 66,
#   'Marine Sharpshooter II: Jungle Warfare': 52,
#   'Perimeter': 77,
#   'Konung 2': 35,
#   'Echelon: Wind Warriors': 63,
#   'Fair Strike': 56,
#   'Men of Valor': 71,
#   'Nancy Drew®: The Secret of Shadow Ranch': 68,
#   'The Punisher': 67,
#   'Codename: Panzers, Phase One': 81,
#   'Nemesis of the Roman Empire': 74,
#   'Warlords Battlecry III': 73,
#   'Lords of the Realm III': 65,
#   'Zoo Empire': 59,
#   'Wars and Warriors: Joan of Arc': 60,
#   'Marine Park Empire': 58,
#   'Ground Control II: Operation Exodus': 80,
#   'Shadow Ops: Red Mercury': 61,
#   'Soldiers: Heroes of World War II': 77,
#   'Neighbours from Hell Compilation': 69,
#   'World War II: Panzer Claws': 61,
#   'Silent Storm Gold Edition': 83,
#   'Kohan II: Kings of War': 81,
#   'Syberia II': 80,
#   'Aura: Fate of the Ages': 63,
#   'Nancy Drew®: Curse of Blackmoor Manor': 81,
#   'Sherlock Holmes: The Silver Earring': 68,
#   'Evil Genius': 75,
#   'Prince of Persia: Warrior Within™': 83,
#   'Nexus - The Jupiter Incident': 77,
#   'Full Spectrum Warrior': 80,
#   'Gish': 80,
#   'DOOM 3': 87,
#   'Vampire: The Masquerade - Bloodlines': 80,
#   'Thief: Deadly Shadows': 85,
#   'Deus Ex: Invisible War': 80,
#   'Call of Duty: United Offensive': 87,
#   'Counter-Strike: Source': 88,
#   'Half-Life 2': 96,
#   "Unreal Tournament 2004: Editor's Choice Edition": 93,
#   'Counter-Strike: Condition Zero': 65},
#  2005: {'Advent Rising': 70,
#   'FlatOut': 72,
#   'Act of War: Direct Action': 82,
#   'Silent Hunter® III': 90,
#   'Bone: Out From Boneville': 68,
#   'Brothers in Arms: Earned in Blood™': 84,
#   'Knights of Honor': 77,
#   'Guild Wars': 89,
#   'Star Wars: Battlefront 2 (Classic, 2005)': 78,
#   "Tom Clancy's Splinter Cell Chaos Theory®": 92,
#   "The Bard's Tale": 70,
#   'Grand Theft Auto: San Andreas': 93,
#   'Still Life': 75,
#   'Serious Sam 2': 74,
#   'STAR WARS™ Knights of the Old Republic™ II - The Sith Lords™': 85,
#   'GT Legends': 84,
#   'FATE': 80,
#   'Cold War': 64,
#   'The Moment of Silence': 70,
#   'Saw': 55,
#   'EMERGENCY 3': 58,
#   'Codename: Panzers, Phase Two': 80,
#   'Space Hack': 63,
#   'Imperial Glory': 69,
#   'Obscure': 63,
#   'Cossacks II: Napoleonic Wars': 73,
#   'Quake IV': 81,
#   'F.E.A.R.': 88,
#   'Nancy Drew®: Last Train to Blue Moon Canyon': 77,
#   'Nancy Drew®: Secret of the Old Clock': 80,
#   'Sniper Elite': 76,
#   'STAR WARS™ Republic Commando™': 78,
#   'Delta Force: Xtreme': 65,
#   'Judge Dredd: Dredd vs. Death': 55,
#   'Prince of Persia: The Two Thrones™': 85,
#   'Crazy Machines': 78,
#   'Crazy Machines 1.5': 78,
#   'The Settlers®: Heritage of Kings': 58,
#   'Cold Fear™': 66,
#   'Brothers in Arms: Road to Hill 30™': 87,
#   'DOOM 3 Resurrection of Evil': 78,
#   'Project: Snowblind': 76,
#   'Psychonauts': 87,
#   'GUN™': 76,
#   'Call of Duty® 2': 86,
#   'Shattered Union': 67,
#   "Sid Meier's Civilization® IV": 94,
#   'BloodRayne 2': 67,
#   "Sid Meier's Pirates!": 88,
#   'Darwinia': 84,
#   'Rag Doll Kung Fu': 69,
#   'Dungeon Siege II': 80,
#   'X3: Reunion': 71},
#  2006: {"Disciples II: Gallean's Return": 84,
#   'Disciples II: Rise of the Elves': 80,
#   'The Ship: Murder Party': 76,
#   'DEFCON': 84,
#   'Gumboy - Crazy Adventures™': 69,
#   'Dreamfall: The Longest Journey': 75,
#   'FlatOut 2™': 76,
#   'CivCity: Rome': 67,
#   'Civilization IV®: Warlords': 84,
#   "Sid Meier's Railroads!": 77,
#   'Devil May Cry® 3 Special Edition': 66,
#   'Warhammer® 40,000: Dawn of War® - Game of the Year Edition': 86,
#   'Warhammer® 40,000: Dawn of War® - Dark Crusade': 87,
#   'Rome: Total War™ - Alexander': 79,
#   'Tomb Raider: Legend': 82,
#   'Tycoon City: New York': 67,
#   "Desperados 2: Cooper's Revenge": 66,
#   'Act of War: High Treason': 74,
#   'RollerCoaster Tycoon® 3: Platinum': 81,
#   "Tom Clancy's Rainbow Six® Vegas": 85,
#   'IL-2 Sturmovik: 1946': 86,
#   'Bone: The Great Cow Race': 76,
#   'Heroes of Might & Magic V: Hammers of Fate': 66,
#   'Guild Wars Nightfall': 84,
#   'Guild Wars Factions': 84,
#   'Call of Cthulhu®: Dark Corners of the Earth': 76,
#   'Nancy Drew®: The Creature of Kapu Cave': 68,
#   'Condemned: Criminal Origins': 78,
#   "Marc Eckō's Getting Up: Contents Under Pressure": 69,
#   'El Matador': 54,
#   'Brigade E5: New Jagged Union': 41,
#   "Perimeter: Emperor's Testament": 72,
#   'Battle Of Europe': 54,
#   'Caesar™ IV': 74,
#   'Elite Warriors: Vietnam': 46,
#   'MX vs. ATV Unleashed': 71,
#   'Disney•Pixar Cars': 73,
#   'Wings Over Europe': 62,
#   "Al Emmo and the Lost Dutchman's Mine": 77,
#   'Faces of War': 67,
#   'Cossacks II: Battle for Europe': 69,
#   'The Guild II': 61,
#   'Gothic® 3': 63,
#   'Nancy Drew®: Danger by Design': 70,
#   "Tom Clancy's Splinter Cell Double Agent®": 80,
#   'Hearts of Iron 2 Complete': 83,
#   'Pacific Storm': 67,
#   'Sacred Gold': 74,
#   "Tom Clancy's Rainbow Six Lockdown™": 59,
#   'Heroes of Might & Magic V': 77,
#   'Darkstar One': 71,
#   'Safecracker: The Ultimate Puzzle Adventure': 69,
#   'Full Spectrum Warrior: Ten Hammers': 70,
#   'Company of Heroes - Legacy Edition': 93,
#   'Just Cause': 75,
#   'Hitman: Blood Money': 82,
#   'Joint Task Force': 68,
#   'Rogue Trooper': 69,
#   'Space Empires V': 68,
#   'RoboBlitz': 80,
#   'Medieval II: Total War™': 88,
#   'Heroes of Annihilated Empires': 65,
#   'Red Orchestra: Ostfront 41-45': 81,
#   'Space Empires IV Deluxe': 79,
#   'Dangerous Waters': 82,
#   'Earth 2160': 73,
#   'Shadowgrounds': 74,
#   'Half-Life 2: Episode One': 87,
#   'SiN Episodes: Emergence': 75,
#   'Iron Warriors: T - 72 Tank Command': 56,
#   'Uplink': 75,
#   'Xpand Rally': 82,
#   'Dark Messiah of Might & Magic': 72},
#  2007: {'Lost Planet™: Extreme Condition': 66,
#   'Tomb Raider: Anniversary': 83,
#   'Vigil: Blood Bitterness™': 61,
#   'QUAKE': 94,
#   'Genesis Rising': 57,
#   'BioShock™': 96,
#   'PuzzleQuest: Challenge of the Warlords': 84,
#   'Culpa Innata': 66,
#   'ARMA: Combat Operations': 74,
#   'Death to Spies': 69,
#   'Rayman Raving Rabbids™': 58,
#   'Silent Hunter®: Wolves of the Pacific': 79,
#   'Pacific Storm Allies': 60,
#   'Crysis': 91,
#   'Heroes of Might & Magic V: Tribes of the East': 70,
#   'Penumbra Overture': 73,
#   'Unreal Tournament 3 Black': 83,
#   'The Elder Scrolls IV: Oblivion® Game of the Year Edition': 94,
#   'Nancy Drew®: Legend of the Crystal Skull': 79,
#   'Nancy Drew®: The White Wolf of Icicle Creek': 73,
#   'Thrillville®: Off the Rails™': 70,
#   'TimeShift™': 71,
#   'Medal of Honor: Airborne': 78,
#   'Overlord™': 81,
#   'Command & Conquer 3: Tiberium Wars': 85,
#   'Guild Wars: Eye of the North®': 79,
#   'Supreme Commander': 86,
#   'Hard to Be a God': 55,
#   'Sinking Island': 68,
#   'Bus Driver': 61,
#   'UFO: Afterlight': 71,
#   'Depths of Peril': 79,
#   'The Guild II - Pirates of the European Seas': 63,
#   'Theatre of War': 66,
#   'Eschalon: Book I': 75,
#   'Hospital Tycoon': 51,
#   'Maelstrom: The Battle for Earth Begins': 58,
#   'Driver® Parallel Lines': 61,
#   'Europa Universalis III Complete': 83,
#   'Mr. Robot': 83,
#   'Aquaria': 82,
#   'Portal': 90,
#   'Sam & Max 201: Ice Station Santa': 82,
#   'Shadowgrounds Survivor': 79,
#   'RACE 07': 83,
#   'Civilization IV: Beyond the Sword': 86,
#   'Team Fortress 2': 92,
#   'Half-Life 2: Episode Two': 90,
#   'Painkiller Overdose': 65,
#   'Alpha Prime': 59,
#   'Loki': 61,
#   'Call of Juarez™': 72,
#   'Medieval II: Total War™ Kingdoms': 85,
#   'Call of Duty® 4: Modern Warfare®': 92,
#   'Kane and Lynch: Dead Men™': 67,
#   'Geometry Wars: Retro Evolved': 76,
#   'Battlestations: Midway': 76,
#   'S.T.A.L.K.E.R.: Shadow of Chernobyl': 82,
#   'Jade Empire™: Special Edition': 81,
#   'Silverfall': 62,
#   'Making History: The Calm & the Storm': 70},
#  2008: {'Command & Conquer: Red Alert 3': 82,
#   'Conflict: Denied Ops': 58,
#   'Ninja Reflex: Steamworks Edition': 57,
#   'Dracula Origin': 70,
#   'Sherlock Holmes - Nemesis': 71,
#   'FlatOut: Ultimate Carnage': 79,
#   'GTR Evolution Expansion Pack for RACE 07': 83,
#   'S.T.A.L.K.E.R.: Clear Sky': 75,
#   'Crysis Warhead®': 84,
#   "The Witcher: Enhanced Edition Director's Cut": 86,
#   'Multiwinia': 76,
#   "Sid Meier's Civilization IV: Colonization": 83,
#   'LEGO Batman': 80,
#   'Hinterland': 65,
#   "Brothers in Arms: Hell's Highway™": 79,
#   'The Settlers®: Rise Of An Empire Gold Edition': 66,
#   'Peggle™ Nights': 76,
#   'World of Goo': 90,
#   'X3: Terran Conflict': 73,
#   'Bully: Scholarship Edition': 72,
#   "Far Cry® 2: Fortune's Edition": 85,
#   'Dead Space': 86,
#   'Rise of the Argonauts': 59,
#   'Defense Grid: The Awakening': 81,
#   "King's Bounty: The Legend": 79,
#   'Nancy Drew®: The Phantom of Venice': 69,
#   'LEGO® Indiana Jones™: The Original Adventures': 78,
#   'Bionic Commando: Rearmed': 86,
#   'Devil May Cry 4': 78,
#   'Iron Grip: Warlord': 59,
#   'Alone in the Dark': 55,
#   'Rhiannon: Curse of the Four Branches': 67,
#   'Overclocked: A History of Violence': 70,
#   'SAGA': 61,
#   'A Vampyre Story': 75,
#   'The Lost Crown': 71,
#   'Ubersoldier II': 62,
#   'Obscure II (Obscure: The Aftermath)': 59,
#   'Sword of the Stars: Complete Collection': 75,
#   'Sherlock Holmes: The Mystery of the Mummy': 61,
#   'Sherlock Holmes: The Awakened - Remastered Edition': 72,
#   'Mata Hari': 63,
#   'Nikopol: Secrets of the Immortals': 68,
#   'Supreme Ruler 2020 Gold': 65,
#   'Chronicles of Mystery: The Scorpio Ritual': 62,
#   'Legend - Hand of God': 57,
#   'Europa Universalis: Rome - Gold Edition': 79,
#   'Dangerous High School Girls in Trouble!™': 81,
#   'Fallout 3': 91,
#   'Mount & Blade': 72,
#   'Silent Hill Homecoming': 64,
#   'Left 4 Dead': 89,
#   'Call of Duty: World at War': 83,
#   'Bejeweled Twist': 78,
#   'Tomb Raider: Underworld': 80,
#   'Prince of Persia®': 82,
#   'Need for Speed Undercover': 65,
#   "Strong Bad's Cool Game for Attractive People: Season 1": 82,
#   'Mass Effect': 89,
#   'SPORE™': 84,
#   'Imperium Romanum Gold Edition': 63,
#   'Crazy Machines 2': 72,
#   'Insecticide Part 1': 65,
#   'Jack Keane': 69,
#   'Children of the Nile: Enhanced Edition': 75,
#   "Assassin's Creed™: Director's Cut Edition": 79,
#   "Tom Clancy's Rainbow Six® Vegas 2": 78,
#   'Trackmania United Forever Star Edition': 80,
#   'LUMINES™': 74,
#   'Everyday Shooter': 77,
#   'Sam & Max 203: Night of the Raving Dead': 79,
#   'Sam & Max 202: Moai Better Blues': 80,
#   'Sam & Max: Season Two': 82,
#   'Sam & Max 204: Chariots of the Dogs': 85,
#   'AudioSurf': 85,
#   'Frontlines™: Fuel of War™': 73,
#   'The Club™': 67},
#  2009: {'Saints Row 2': 72,
#   "Mirror's Edge™": 81,
#   'F.E.A.R. 2: Project Origin': 79,
#   'Larva Mortus': 64,
#   'Ceville': 73,
#   'Watchmen: The End is Nigh': 61,
#   'Drakensang': 75,
#   'Burnout Paradise: The Ultimate Box': 87,
#   'The Maw': 75,
#   'Two Worlds Epic Edition': 65,
#   'Helldorado': 65,
#   'X-Blades': 54,
#   'Zeno Clash': 77,
#   'Death Track®: Resurrection': 53,
#   'Light of Altair': 66,
#   'Prototype™': 79,
#   'Blueberry Garden': 68,
#   'The Elder Scrolls IV: Oblivion® Game of the Year Edition Deluxe': 94,
#   'Call of Juarez®: Bound in Blood': 78,
#   'Tales of Monkey Island Complete Pack': 79,
#   'Street Fighter® IV': 91,
#   'The Secret of Monkey Island: Special Edition': 86,
#   'Clutch': 51,
#   'Nancy Drew®: Ransom of the Seven Ships': 78,
#   'Bionic Commando': 69,
#   'Watchmen: The End is Nigh Part 2': 44,
#   'Osmos': 80,
#   'Time Gentlemen, Please! and Ben There, Dan That! Special Edition  Double Pack': 84,
#   'Mini Ninjas': 74,
#   'Risen': 77,
#   'Machinarium': 85,
#   'Need for Speed: Shift': 83,
#   'Torchlight': 83,
#   'East India Company: Privateer': 63,
#   'Painkiller: Resurrection': 38,
#   'SpellForce 2 - Anniversary Edition': 80,
#   'Rush for Berlin Gold': 76,
#   'Men of War: Red Tide': 77,
#   'SpellForce - Platinum Edition': 74,
#   'Nancy Drew® Dossier: Resorting to Danger!': 77,
#   'Serious Sam HD: The First Encounter': 68,
#   'Secret Files 2: Puritas Cordis': 64,
#   'Dragon Age: Origins': 91,
#   'Call of Duty®: Modern Warfare® 2': 86,
#   'LEGO® Star Wars™ - The Complete Saga': 77,
#   "Command & Conquer 3: Kane's Wrath": 77,
#   'Gratuitous Space Battles': 72,
#   'Wings of Prey': 78,
#   'STAR WARS™ - The Force Unleashed™ Ultimate Sith Edition': 65,
#   'Europa Universalis III: Heir to the Throne': 86,
#   'Fallout 3: Game of the Year Edition': 91,
#   'Roogoo': 72,
#   'The Sims™ 3': 86,
#   'The Sims™ 3 World Adventures': 81,
#   'Still Life 2': 67,
#   'Champions Online': 72,
#   'Disney G-Force': 61,
#   'Venetica - Gold Edition': 61,
#   'Age of Empires® III: Complete Collection': 81,
#   'Theatre of War 2: Africa 1943': 63,
#   'Sherlock Holmes versus Jack the Ripper': 73,
#   'Left 4 Dead 2': 89,
#   'Gyromancer': 71,
#   'Ninja Blade': 61,
#   'Rogue Warrior': 29,
#   "King's Bounty: Armored Princess": 82,
#   'Altitude': 79,
#   'Borderlands: The Zombie Island of Dr. Ned': 84,
#   'AI War: Fleet Command': 80,
#   'Elven Legacy: Ranger': 68,
#   'Borderlands': 81,
#   'Operation Flashpoint: Dragon Rising': 76,
#   'STAR WARS™: The Clone Wars - Republic Heroes™': 46,
#   'Lucidity™': 59,
#   'Tropico 3': 79,
#   'Red Faction Guerrilla Steam Edition': 82,
#   'Resident Evil™ 5/ Biohazard 5®': 86,
#   "Zuma's Revenge!": 78,
#   'Twin Sector': 49,
#   'Majesty 2': 72,
#   'Madballs in Babo:Invasion': 79,
#   'AaAaAA!!! - A Reckless Disregard for Gravity': 81,
#   'Quantz': 67,
#   'Hearts of Iron III': 77,
#   'Darkest of Days': 51,
#   'Death to Spies: Moment of Truth': 73,
#   'Emerald City Confidential™': 71,
#   'East India Company': 67,
#   'Order of War™': 69,
#   'Nancy Drew®: The Haunting of Castle Malloy': 81,
#   'SPORE™ Galactic Adventures': 70,
#   'Arma 2': 77,
#   'Trine Enchanted Edition': 80,
#   'Overlord II': 79,
#   'Dawn of Discovery™': 82,
#   'Crayon Physics Deluxe': 79,
#   'Men of War™': 80,
#   'Tunnel Rats': 30,
#   'Killing Floor': 72,
#   'NecroVision': 63,
#   'Damnation': 41,
#   'Restaurant Empire II': 64,
#   'Battlestations Pacific': 74,
#   'Velvet Assassin': 61,
#   'Plants vs. Zombies GOTY Edition': 87,
#   'Dark Sector': 66,
#   'And Yet It Moves': 75,
#   'Elven Legacy': 71,
#   'Company of Heroes: Tales of Valor': 70,
#   'Flock!': 65,
#   'Braid': 90,
#   'Cogs': 73,
#   'Drug Wars': 35,
#   'The Path': 79,
#   'Perimeter 2: New Earth': 43,
#   'Warhammer 40,000: Dawn of War II': 85,
#   'Empire: Total War™': 90,
#   'Puzzle Quest: Galactrix': 72,
#   "Tom Clancy's EndWar™": 68,
#   'The Last Remnant™': 66,
#   'Grand Ages: Rome': 72,
#   'Penumbra: Black Plague Gold Edition': 78},
#  2010: {'Avencast: Rise of the Mage': 68,
#   'UFO: Extraterrestrials Gold': 68,
#   'LEGO® Indiana Jones™ 2: The Adventure Continues': 66,
#   'Vancouver 2010™ - The Official Video Game of the Olympic Winter Games': 57,
#   'Mount & Blade: Warband': 78,
#   'Plain Sight': 76,
#   'Lead and Gold: Gangs of the Wild West': 70,
#   'Beat Hazard': 70,
#   'M.U.D. TV': 53,
#   'The Misadventures of P.B. Winterbottom': 79,
#   'Rocket Knight': 63,
#   'Alpha Protocol™': 72,
#   'Alien Breed: Impact': 64,
#   'Alien Swarm': 77,
#   'Disciples III - Renaissance Steam Special Edition': 56,
#   'Tidalis': 75,
#   'Razor2: Hidden Skies': 61,
#   'Kane & Lynch 2: Dog Days': 66,
#   'The Guild II Renaissance': 56,
#   'Fantasy Wars': 67,
#   'Puzzle Quest 2': 83,
#   'Burn Zombie Burn!': 72,
#   'Ship Simulator Extremes': 49,
#   'Worms Reloaded': 79,
#   'Making History II: The War of the World': 38,
#   'Victoria II': 75,
#   'VVVVVV': 81,
#   'Amnesia: The Dark Descent': 85,
#   "Recettear: An Item Shop's Tale": 82,
#   'Patrician IV - Steam Special Edition': 66,
#   "King's Bounty: Crossworlds": 78,
#   "Sid Meier's Civilization® V": 90,
#   'Blade Kitten': 52,
#   'Alien Breed 2: Assault': 63,
#   'Darksiders™': 83,
#   "The Kings' Crusade": 71,
#   "Age of Wonders II: The Wizard's Throne": 86,
#   'Age of Wonders Shadow Magic': 82,
#   'Medal of Honor™': 72,
#   'Grotesque Tactics: Evil Heroes': 65,
#   'Lost Planet® 2': 63,
#   'Doc Clock: The Toasted Sandwich of Time': 62,
#   'Fallout: New Vegas': 84,
#   'Nimbus': 80,
#   'DeathSpank': 77,
#   'Shank': 67,
#   'The Ball': 68,
#   'STAR WARS™: The Force Unleashed™ II': 59,
#   'Patrician III': 75,
#   'Alternativa': 63,
#   'Call of Duty®: Black Ops': 81,
#   'Back to the Future: The Game': 74,
#   'The Sims™ 3 Late Night': 74,
#   'The Sims™ 3 Ambitions': 74,
#   'Armada 2526': 66,
#   'Star Trek Online': 76,
#   'Serious Sam HD: The Second Encounter': 76,
#   "Din's Curse": 76,
#   '15 Days': 63,
#   'Dragon Saga': 65,
#   'Split/Second': 79,
#   'Disney TRON: Evolution': 57,
#   'Disney Alice in Wonderland': 63,
#   'Bejeweled® 3': 82,
#   'RUSH': 73,
#   'Greed Corp': 76,
#   'Need For Speed: Hot Pursuit': 86,
#   'Battlefield: Bad Company 2 Vietnam': 86,
#   'The UnderGarden': 67,
#   'Alien Breed 3: Descent': 64,
#   'Poker Night at the Inventory': 71,
#   'DeathSpank: Thongs of Virtue': 78,
#   'Super Meat Boy': 87,
#   "nail'd": 69,
#   'Dragon Age: Origins - Ultimate Edition': 91,
#   'Grand Theft Auto IV: Complete Edition': 90,
#   'Blood Bowl® Legendary Edition': 73,
#   'Bloody Good Time': 73,
#   'ArcaniA': 63,
#   'Dead Rising® 2': 78,
#   'Lost Horizon': 77,
#   'Front Mission Evolved': 63,
#   'Lara Croft and the Guardian of Light': 82,
#   "Borderlands: Claptrap's Robot Revolution": 69,
#   'Commander: Conquest of the Americas': 68,
#   'Alter Ego': 59,
#   'Hearts of Iron III: Semper Fi': 65,
#   'Prince of Persia: The Forgotten Sands™': 75,
#   'Jolly Rover': 71,
#   'Sniper: Ghost Warrior': 55,
#   'Puzzle Dimension': 79,
#   'Rig n Roll': 61,
#   'Reign: Conflict of Nations': 60,
#   'Day of Defeat: Source': 80,
#   'Blacklight: Tango Down': 65,
#   'LEGO Harry Potter: Years 1-4': 79,
#   'Arma 2: Operation Arrowhead': 73,
#   'Singularity™': 76,
#   'Tropico 3: Absolute Power': 79,
#   'Napoleon: Total War™': 81,
#   'Borderlands: The Secret Armory of General Knoxx': 86,
#   'Napoleon: Total War™ Imperial Edition': 81,
#   'Battlefield: Bad Company™ 2': 87,
#   'Supreme Commander 2': 77,
#   'Sonic & SEGA All-Stars Racing': 65,
#   'Silent Hunter 5®: Battle of the Atlantic': 62,
#   "Assassin's Creed 2 Deluxe Edition": 86,
#   'Just Cause 2': 84,
#   'Warhammer® 40,000: Dawn of War® II Chaos Rising': 85,
#   'Shatter': 84,
#   'Dragon Age™: Origins Awakening': 82,
#   'Command & Conquer 4: Tiberian Twilight': 64,
#   'Dark Fall: Lost Souls': 75,
#   "Tom Clancy's Splinter Cell Conviction™ Deluxe Edition": 83,
#   'Flotilla': 72,
#   'Sol Survivor': 75,
#   'Nancy Drew®: Warnings at Waverly Academy': 76,
#   'Dark Void™': 57,
#   'Bob Came in Pieces': 73,
#   'Mass Effect 2': 94,
#   'Hotel Giant 2': 58,
#   'Mass Effect 2 Digital Deluxe Edition': 94,
#   'Toki Tori': 80,
#   'Aliens vs. Predator™': 68,
#   'BioShock® 2': 88,
#   'Lost Planet: Extreme Condition Colonies Edition': 70,
#   'S.T.A.L.K.E.R.: Call of Pripyat': 80,
#   'Galcon Fusion': 68,
#   'Batman: Arkham Asylum Game of the Year Edition': 91},
#  2011: {'Mafia II': 77,
#   'Zeit²': 72,
#   'A.R.E.S.: Extinction Agenda': 68,
#   'APOX': 48,
#   'Dead Space™ 2': 87,
#   'Kaptain Brawe: A Brawe New World': 69,
#   'Monday Night Combat': 82,
#   "Who's That Flying?!": 76,
#   'Two Worlds II HD': 76,
#   'YOU DON’T KNOW JACK®': 71,
#   'Test Drive Unlimited 2': 72,
#   'DUNGEONS - Steam Special Edition': 65,
#   'RISK™: Factions': 77,
#   'Homefront': 70,
#   'Fate of the World': 70,
#   'Shadow Harvest: Phantom Ops': 34,
#   'Anomaly: Warzone Earth': 80,
#   'Darkest Hour: A Hearts of Iron Game': 81,
#   'Dino D-Day': 53,
#   'Patrician IV: Rise of a Dynasty': 67,
#   'Portal 2': 95,
#   'Sanctum': 70,
#   'Frozen Synapse': 85,
#   'Hunted: The Demon’s Forge™': 61,
#   "Hamilton's Great Adventure": 77,
#   'The Sims™ 3 Generations': 70,
#   'Ghostbusters: Sanctum of Slime Challenge Pack DLC': 43,
#   'Dungeon Siege III': 72,
#   'Duke Nukem Forever': 54,
#   'Spiral Knights': 64,
#   'Magic: The Gathering - Duels of the Planeswalkers 2012': 77,
#   'Solar 2': 72,
#   'F.E.A.R. 3': 74,
#   'Puzzle Agent 2': 63,
#   "Tobe's Vertical Adventure": 75,
#   'IL-2 Sturmovik: Cliffs of Dover': 60,
#   'Runespell: Overture': 69,
#   'Tropico 4': 78,
#   'EDGE': 74,
#   'Space Pirates and Zombies': 74,
#   'Fallout New Vegas®: Lonesome Road™': 57,
#   'The Baconing': 63,
#   'Warhammer 40,000: Space Marine': 74,
#   'Men of War: Vietnam': 68,
#   'Rock of Ages': 74,
#   'Red Orchestra 2: Heroes of Stalingrad with Rising Storm': 76,
#   'Call of Juarez®: The Cartel': 51,
#   'Sengoku': 70,
#   'Two Worlds II - Pirates of the Flying Fortress': 78,
#   'Might & Magic: Heroes VI': 77,
#   'Supreme Commander: Forged Alliance': 81,
#   'The Binding of Isaac': 84,
#   'Off-Road Drive': 60,
#   'Fate of the World: Tipping Point': 70,
#   'Sniper: Ghost Warrior - Second Strike': 55,
#   'Air Conflicts: Secret Wars': 65,
#   'Dead Rising 2: Off the Record': 66,
#   'Disciples III - Resurrection': 63,
#   'The Sims™ 3 Pets': 79,
#   'Serious Sam: The Random Encounter': 64,
#   'Before the Echo': 70,
#   'Airline Tycoon 2': 57,
#   'The Haunted: Hells Reach': 51,
#   'DC Universe™ Online': 72,
#   'Saints Row: The Third Initiation Station': 84,
#   'Sonic Generations Collection': 77,
#   'L.A. Noire': 83,
#   'SkyDrift': 73,
#   'Galactic Civilizations® II: Ultimate Edition': 92,
#   'Earth Defense Force: Insect Armageddon': 69,
#   'X3: Albion Prelude': 75,
#   'Fable - The Lost Chapters': 83,
#   'Postal III': 24,
#   'To the Moon': 81,
#   'Black Mirror II': 71,
#   'Disney•Pixar Toy Story 3: The Video Game': 73,
#   'Black Mirror III': 75,
#   'Panzer Corps': 80,
#   'TrackMania² Canyon': 81,
#   'The Witcher 2: Assassins of Kings Enhanced Edition': 88,
#   'Fallen Earth Free2Play': 71,
#   'EverQuest® II Free-To-Play. Your Way.™': 83,
#   'Sideway™ New York': 71,
#   'Saints Row: The Third': 84,
#   'Rochard': 81,
#   'Gemini Rue': 82,
#   'Global Ops: Commando Libya': 37,
#   'Renegade Ops': 76,
#   'Ignite': 59,
#   'Bloodline Champions': 79,
#   'Take On Helicopters': 70,
#   'inMomentum': 59,
#   'Lord of the Rings: War in the North': 66,
#   'Dungeon Defenders': 81,
#   'PAYDAY™ The Heist': 76,
#   'Steel Storm: Burning Retribution': 55,
#   'RAGE': 79,
#   'Orcs Must Die!': 83,
#   'Might & Magic: Clash of Heroes': 76,
#   'Nuclear Dawn': 71,
#   'Dungeons - The Dark Lord': 72,
#   'Worms Ultimate Mayhem': 66,
#   'King Arthur: Fallen Champions': 54,
#   'Xotic': 67,
#   'F1 2011': 83,
#   'Blocks That Matter': 72,
#   'Bastion': 86,
#   'From Dust': 76,
#   'Avadon: The Black Fortress': 75,
#   'Chantelise - A Tale of Two Sisters': 62,
#   'Supreme Ruler: Cold War': 63,
#   'Pirates of Black Cove': 56,
#   'LIMBO': 88,
#   'Achron': 54,
#   'Trauma': 62,
#   'Critical Mass': 81,
#   'Cthulhu Saves the World': 78,
#   'Dungeons of Dredmor': 79,
#   'Trapped Dead': 50,
#   'Operation Flashpoint: Red River': 67,
#   'Red Faction®: Armageddon™': 75,
#   'Pride of Nations': 70,
#   'Jamestown': 81,
#   'Vertex Dispenser': 70,
#   'Runaway: A Twist of Fate': 79,
#   'The Next BIG Thing': 75,
#   'Hector: Badge of Carnage - Full Series': 75,
#   "Yar's Revenge": 56,
#   'Capsized': 80,
#   'Universe Sandbox': 83,
#   'Mount & Blade: With Fire & Sword': 68,
#   'Section 8®: Prejudice™': 77,
#   'The Tiny Bang Story': 63,
#   'Garshasp: The Monster Slayer': 49,
#   'Hydrophobia: Prophecy': 64,
#   'Lume': 69,
#   'Terraria': 83,
#   'BRINK': 70,
#   'Duels of the Planeswalkers Gold Deck Bundle': 69,
#   'Naval Warfare': 57,
#   'Hearts of Iron III Semper Fi: Dies Irae Götterdämmerung': 65,
#   'Fortix 2': 74,
#   'NightSky': 78,
#   'SpaceChem': 84,
#   'The Settlers 7: Paths to a Kingdom: Deluxe Gold Edition': 79,
#   'Atom Zombie Smasher': 75,
#   'Post Apocalyptic Mayhem': 44,
#   'Revenge of the Titans': 79,
#   'Assassin’s Creed® Brotherhood': 88,
#   'LEGO® Star Wars™ III - The Clone Wars™': 76,
#   'Theatre of War 3: Korea': 49,
#   'Shift 2 Unleashed': 84,
#   'HOARD': 65,
#   'Cities in Motion': 70,
#   'Men of War: Assault Squad': 77,
#   'CreaVures': 55,
#   'Painkiller Redemption': 43,
#   'Magicka': 74,
#   'Europa Universalis III: Divine Wind': 71},
#  2012: {'Hard Reset Extended Edition': 73,
#   'Oil Rush': 67,
#   'King Arthur II: The Role-Playing Wargame': 66,
#   'Jagged Alliance - Back in Action': 62,
#   'Pineapple Smash Crew': 62,
#   'Victoria II: A House Divided': 76,
#   'PixelJunk™ Eden': 81,
#   'Crusader Kings II': 82,
#   'Alan Wake': 83,
#   'Starpoint Gemini': 46,
#   'Realm of the Mad God': 82,
#   'Rayman® Origins': 86,
#   'Painkiller: Recurring Evil': 38,
#   'Vessel': 81,
#   'Stacking': 80,
#   'Wizorb': 81,
#   'Defenders of Ardania': 58,
#   'Cubemen': 74,
#   'Myst V': 80,
#   'Ys: The Oath in Felghana': 73,
#   'Waveform': 81,
#   'Total War: Shogun 2 - Fall of the Samurai': 86,
#   'Tropico 4: Modern Times': 78,
#   'Ridge Racer™ Unbounded': 72,
#   'Confrontation': 51,
#   'Risen 2: Dark Waters': 69,
#   'Binary Domain': 68,
#   'Analogue: A Hate Story': 62,
#   'Toy Soldiers': 71,
#   'Resident Evil: Operation Raccoon City': 48,
#   'Gratuitous Tank Battles': 69,
#   'Ys Origin': 76,
#   'Max Payne 3': 87,
#   'The Lord of the Rings Online™': 86,
#   'Splice': 70,
#   'Krater': 52,
#   'Vindictus': 76,
#   'The Dark Eye: Chains of Satinav': 75,
#   "Tom Clancy's Ghost Recon: Future Soldier™": 71,
#   'Quantum Conundrum': 77,
#   'Tribes: Ascend': 86,
#   'MDK2 HD': 73,
#   'The Book of Unwritten Tales': 82,
#   'A Virus Named TOM': 65,
#   'Hero Academy': 75,
#   'Iron Brigade': 75,
#   'Counter-Strike: Global Offensive': 83,
#   'Closure': 78,
#   'Batman: Arkham City - Game of the Year Edition': 91,
#   'Intrusion 2': 80,
#   'The Testament of Sherlock Holmes': 73,
#   'Cortex Command': 44,
#   'Rocketbirds: Hardboiled Chicken': 74,
#   'Rocksmith™': 78,
#   "Edna & Harvey: Harvey's New Eyes": 75,
#   'Unity of Command: Stalingrad Campaign': 84,
#   'Primal Carnage': 67,
#   'Giana Sisters: Twisted Dreams': 77,
#   'A Game of Dwarves': 60,
#   'Hotline Miami': 85,
#   'Guns of Icarus Online': 64,
#   'F1 RACE STARS™': 62,
#   'Chaos on Deponia': 78,
#   'Gemini Wars': 53,
#   'Sine Mora': 77,
#   "Fly'N": 80,
#   'Memento Mori': 66,
#   'Call of Duty®: Black Ops II': 74,
#   'Miasmata': 76,
#   'Stealth Bastard Deluxe': 80,
#   'The Book of Unwritten Tales: The Critter Chronicles': 73,
#   'Primordia': 72,
#   'A New Beginning - Final Cut': 72,
#   'Inquisitor': 64,
#   'The Cat Lady': 81,
#   'Gas Guzzlers: Combat Carnage': 58,
#   'Haunted': 76,
#   'Drox Operative': 74,
#   'Waking Mars': 79,
#   'Dishonored: Dunwall City Trials': 75,
#   'Sword of the Stars II: Enhanced Edition': 65,
#   'Karateka': 48,
#   'Far Cry 3': 88,
#   'Super Hexagon': 88,
#   'LEGO The Lord of the Rings': 80,
#   'Miner Wars 2081': 52,
#   'Little Inferno': 68,
#   'Scribblenauts Unlimited': 75,
#   'Hitman: Absolution™': 79,
#   'PlanetSide 2': 84,
#   'Assassin’s Creed® III': 80,
#   'Thomas Was Alone': 77,
#   'Clan of Champions': 42,
#   'Natural Selection 2': 80,
#   'Painkiller Hell & Damnation': 64,
#   'Pid': 63,
#   'Deadlight': 78,
#   "King's Bounty: Warriors of the North": 74,
#   'Lucius': 59,
#   'Chivalry: Medieval Warfare': 79,
#   'Mark of the Ninja': 91,
#   'Worms Revolution': 73,
#   'Of Orcs And Men': 69,
#   'Hell Yeah! Wrath of the Dead Rabbit': 64,
#   'McPixel': 76,
#   'Dishonored': 91,
#   'Half Minute Hero: Super Mega Neo Climax Ultimate Boy': 75,
#   'Sniper Elite V2 - The Neudorf Outpost Pack': 66,
#   'Dream Pinball 3D': 61,
#   'Torchlight II': 88,
#   'XCOM: Enemy Unknown': 89,
#   'Gateways': 72,
#   'Tryst': 50,
#   'FTL: Faster Than Light': 84,
#   'Borderlands 2': 89,
#   'Secret Files 3': 67,
#   'F1 2012™': 80,
#   'Home': 69,
#   "Shad'O": 68,
#   'I Am Alive': 66,
#   'DARK SOULS™: Prepare To Die™ Edition': 85,
#   'Tiny Troopers': 57,
#   'Jagged Alliance: Crossfire': 63,
#   'They Bleed Pixels': 74,
#   'Snapshot': 74,
#   'Galactic Civilizations® I: Ultimate Edition': 83,
#   'Tower Wars': 59,
#   'Tales From Space: Mutant Blobs Attack': 83,
#   'Check vs Mate': 69,
#   'Thirty Flights of Loving': 88,
#   'Cannon Fodder 3': 49,
#   'Symphony': 75,
#   'Deponia': 74,
#   'Rigonauts': 60,
#   'Unmechanical': 74,
#   'Awesomenauts - the 2D moba': 78,
#   'Resonance': 76,
#   'Orcs Must Die! 2': 83,
#   'Prototype 2': 76,
#   'Blacklight: Retribution': 75,
#   'Endless Space® - Collection': 77,
#   "Tiny and Big: Grandpa's Leftovers": 75,
#   'SpellForce 2: Faith in Destiny': 55,
#   'Fray: Reloaded Edition': 27,
#   'Magic: The Gathering - Duels of the Planeswalkers 2013': 77,
#   'Game of Thrones': 58,
#   'Spec Ops: The Line': 76,
#   'Sins of a Solar Empire®: Rebellion': 82,
#   'Iron Front: Digital War Edition': 55,
#   "Alan Wake's American Nightmare": 73,
#   'Botanicula': 82,
#   'Nexuiz': 54,
#   'Street Fighter X Tekken': 79,
#   'Offspring Fling!': 79,
#   'The Dream Machine: Chapter 1 & 2': 75,
#   'Sonic the Hedgehog 4 - Episode II': 54,
#   "MacGuffin's Curse": 73,
#   'Blades of Time': 63,
#   "Lone Survivor: The Director's Cut": 81,
#   'The Walking Dead': 82,
#   'Fireburst': 59,
#   'A Valley Without Wind': 54,
#   'Noitu Love 2: Devolution': 80,
#   'Warlock - Master of the Arcane': 71,
#   'Naval War: Arctic Circle': 64,
#   'Legend of Grimrock': 82,
#   'Stellar Impact': 74,
#   'Avernum: Escape From the Pit': 76,
#   'Men of War: Condemned Heroes': 57,
#   'Insanely Twisted Shadow Planet': 76,
#   'Deep Black: Reloaded': 39,
#   'Super MNC': 76,
#   'Sniper Elite V2': 66,
#   'Mount & Blade: Warband - Napoleonic Wars': 83,
#   'Wargame: European Escalation': 81,
#   'Stronghold Kingdoms': 75,
#   'Shank 2': 72,
#   'The Blackwell Legacy': 80,
#   'Blackwell Deception': 73,
#   'Evochron Mercenary': 70,
#   'Dustforce DX': 79,
#   'Kingdoms of Amalur: Reckoning™': 81,
#   'Unstoppable Gorg': 73,
#   'The Darkness II': 77,
#   'Crusader Kings Complete': 73,
#   'SOL: Exodus': 57,
#   'LEGO Harry Potter: Years 5-7': 80,
#   'Choplifter HD': 65},
#  2013: {'RIFT': 84,
#   'Trine 2: Complete Story': 84,
#   'Fieldrunners 2': 73,
#   'Strike Suit Zero': 66,
#   'The Cave': 68,
#   'Ace Combat Assault Horizon - Enhanced Edition': 77,
#   'DmC: Devil May Cry': 85,
#   'Retrovirus': 70,
#   'Super House of Dead Ninjas': 79,
#   'A Valley Without Wind 2': 68,
#   'March of the Eagles': 71,
#   'Incredipede': 74,
#   'Trials Evolution: Gold Edition': 85,
#   'Resident Evil 6 / Biohazard 6': 69,
#   'Anodyne': 75,
#   'Evoland': 61,
#   'Lords of Football': 52,
#   'Sang-Froid - Tales of Werewolves': 79,
#   'Cubemen 2': 68,
#   'Papo & Yo': 70,
#   'Surgeon Simulator': 71,
#   'God Mode': 58,
#   'Eador. Masters of the Broken World': 74,
#   'Mars: War Logs': 59,
#   'Poker Night 2': 75,
#   'StarDrive': 61,
#   'Sanctum 2': 77,
#   'Reus': 75,
#   'Bad Bots': 49,
#   'Resident Evil Revelations / Biohazard Revelations': 77,
#   'Expansion - Crusader Kings II: The Old Gods': 88,
#   'Remember Me': 65,
#   'Prime World: Defenders': 58,
#   "Borderlands 2: Tiny Tina's Assault on Dragon Keep": 87,
#   'Company of Heroes 2': 80,
#   'The Walking Dead: 400 Days': 78,
#   'DARK': 41,
#   'TrackMania² Valley': 79,
#   'BIT.TRIP FATE': 74,
#   'The Raven - Legacy of a Master Thief': 74,
#   'Ittle Dew': 67,
#   'Shadowrun Returns': 76,
#   'Citadels': 20,
#   'CastleStorm': 73,
#   'Skulls of the Shogun': 72,
#   'BioShock Infinite: Clash in the Clouds': 69,
#   'Rise of the Triad': 67,
#   'Cloudberry Kingdom™': 67,
#   'Saints Row IV: Inauguration Station': 86,
#   'Beatbuddy: Tale of the Guardians': 75,
#   'Dishonored: The Brigmore Witches': 80,
#   'DuckTales: Remastered': 66,
#   'Worms Clan Wars': 73,
#   'Space Hulk': 58,
#   'PixelJunk™ Monsters Ultimate': 72,
#   'Shelter': 69,
#   'Lilly Looking Through': 71,
#   'Game Dev Tycoon': 68,
#   'Guardians of Middle-earth': 56,
#   'Outlast': 80,
#   'MirrorMoon EP': 73,
#   'Rise of Flight: Ace Pack': 77,
#   "Dragon's Prophet": 63,
#   'Ironclad Tactics': 69,
#   'Foul Play': 69,
#   'Angry Video Game Nerd Adventures': 77,
#   'Urban Trial Freestyle': 58,
#   'Scribblenauts Unmasked: A DC Comics Adventure': 68,
#   'Alien Rage - Unlimited': 52,
#   'The Stanley Parable': 88,
#   'Soundodger+': 78,
#   'The Wolf Among Us': 85,
#   '140': 80,
#   'Face Noir': 59,
#   'Space Rangers HD: A War Apart': 68,
#   'Goodbye Deponia': 80,
#   "Deus Ex: Human Revolution - Director's Cut": 91,
#   'Contagion': 62,
#   'Slender: The Arrival': 65,
#   'Master Reboot': 59,
#   'Alone in the Dark: The New Nightmare': 66,
#   "Deadly Premonition: The Director's Cut": 59,
#   'State of Decay': 79,
#   "King Arthur's Gold": 81,
#   'Desktop Dungeons': 82,
#   'A Walk in the Dark': 67,
#   'Adventure Park': 49,
#   'Risk of Rain': 77,
#   'Long Live The Queen': 67,
#   'Rain Blood Chronicles: Mirage': 68,
#   'PixelJunk™ Shooter': 73,
#   'XCOM: Enemy Within': 86,
#   'Signal Ops': 61,
#   'Expansion - Crusader Kings II: Sons of Abraham': 77,
#   'Ring Runner: Flight of the Sages': 75,
#   "Montague's Mount": 39,
#   'Darkout': 55,
#   'Oozi: Earth Adventure': 66,
#   'Neverwinter': 74,
#   'Paper Sorcerer': 73,
#   'The Yawhg': 66,
#   'Oknytt': 61,
#   'How to Survive': 60,
#   'FINAL FANTASY XIV Online Free Trial': 83,
#   'Pandora: First Contact': 68,
#   'Sir, You Are Being Hunted': 63,
#   'FINAL FANTASY XIV Online Starter Edition': 83,
#   'Driftmoon': 73,
#   'Total War: ROME II - Caesar in Gaul Campaign Pack': 63,
#   'Dementium II HD': 37,
#   'Teslagrad': 77,
#   'Stick it to The Man!': 83,
#   'Violett Remastered': 61,
#   'Samurai Gunn': 78,
#   'Gomo': 50,
#   'The Novelist': 66,
#   'Speedball 2 HD': 53,
#   'SteamWorld Dig': 76,
#   'Two Brothers': 57,
#   'Gas Guzzlers Extreme': 73,
#   'Redshirt': 62,
#   'Chivalry: Deadliest Warrior': 69,
#   'Deadfall Adventures': 53,
#   'X Rebirth': 33,
#   'Contrast': 62,
#   "Baldur's Gate II: Enhanced Edition": 78,
#   'Dungeonland': 67,
#   'Final Exam': 66,
#   'Avadon 2: The Corruption': 82,
#   'Valdis Story: Abyssal City': 83,
#   'Sniper Elite: Nazi Zombie Army 2': 53,
#   'Journey of a Roach': 65,
#   'Fester Mudd: Curse of the Gold - Episode 1': 76,
#   'Battle Worlds: Kronos': 71,
#   'Eldritch': 77,
#   'LEGO® Marvel™ Super Heroes': 78,
#   'Borderlands 2: Headhunter 1: Bloody Harvest': 89,
#   'Syder Arcade': 76,
#   'Defense Technica': 63,
#   'ENSLAVED™: Odyssey to the West™ Premium Edition': 70,
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM 3 Full Burst HD': 80,
#   'Batman™: Arkham Origins': 74,
#   'Nihilumbra': 75,
#   'Tetrobot and Co.': 72,
#   'Democracy 3': 70,
#   'Megabyte Punch': 69,
#   'Shadow Warrior': 73,
#   'Giana Sisters: Twisted Dreams - Rise of the Owlverlord': 84,
#   'Rise of Venice': 66,
#   'The Inner World': 72,
#   'Arma Tactics': 47,
#   'Knock-knock': 57,
#   'Tactical Intervention': 47,
#   'Bionic Dues': 71,
#   'Air Conflicts: Vietnam': 43,
#   'Rise of Flight: Battle of Saint-Mihiel': 77,
#   'Rise of Flight: Birth of Warbirds': 77,
#   'Rise of Flight: Bloody April': 77,
#   'Rise of Flight: Ultimately the Best Fighter': 77,
#   'Rise of Flight: Furious Wings': 77,
#   'Rise of Flight United': 77,
#   'Rise of Flight: Legendary Bombers': 77,
#   'Amnesia: A Machine for Pigs': 72,
#   'Dominions 3: The Awakening': 82,
#   'Arma 3': 74,
#   'Aarklash: Legacy': 72,
#   'Volgarr the Viking': 76,
#   'The Chaos Engine': 40,
#   'Memoria': 79,
#   'Total War™: ROME II - Emperor Edition': 76,
#   'Rayman® Legends': 89,
#   'Gone Home': 86,
#   'Brothers - A Tale of Two Sons': 90,
#   'The Bureau: XCOM Declassified': 66,
#   'Saints Row IV': 86,
#   'Divekick': 73,
#   'Skullgirls': 83,
#   'Spelunky': 90,
#   'Papers, Please': 85,
#   'Guacamelee! Gold Edition': 88,
#   'Europa Universalis IV': 87,
#   'Guncraft': 73,
#   'Hammerwatch': 72,
#   'Teleglitch: Die More Edition': 78,
#   'Super Splatters': 73,
#   'Rogue Legacy': 85,
#   'Storm': 63,
#   'TrackMania² Stadium': 77,
#   'Fist Puncher': 73,
#   'Hexodius': 47,
#   'Joe Danger 2: The Movie': 82,
#   'The Night of the Rabbit': 75,
#   'Cubetractor': 75,
#   'Wargame: Airland Battle': 80,
#   'Expeditions: Conquistador': 77,
#   'The Swapper': 87,
#   'Rising Storm Game of the Year Edition': 82,
#   'Fallen Enchantress: Legendary Heroes': 80,
#   'The Incredible Adventures of Van Helsing': 72,
#   'Skyward Collapse': 64,
#   'Element4l': 77,
#   'Call of Juarez® Gunslinger': 79,
#   'Gunpoint': 83,
#   'GRID 2': 80,
#   'Thunder Wolves': 69,
#   'Anomaly 2': 77,
#   'Strike Suit Infinity': 66,
#   'FEZ': 91,
#   'Far Cry 3 - Blood Dragon': 81,
#   "Monaco: What's Yours Is Mine": 83,
#   'Kairo': 76,
#   'Dyad': 80,
#   'Anna - Extended Edition': 75,
#   'La-Mulana': 80,
#   'Starseed Pilgrim': 83,
#   'Sacred Citadel': 61,
#   'Age of Empires II HD': 68,
#   'ShootMania Storm': 76,
#   'Dungeon Hearts': 73,
#   'Cities in Motion 2': 72,
#   'Warframe': 69,
#   'BioShock Infinite': 94,
#   'Shattered Haven': 59,
#   'Weird Worlds: Return to Infinite Space': 79,
#   'Sniper: Ghost Warrior 2': 52,
#   'BIT.TRIP Presents... Runner2: Future Legend of Rhythm Alien': 85,
#   'Star Conflict': 75,
#   'Sniper Elite: Nazi Zombie Army': 62,
#   'Armada 2526 Gold Edition': 66,
#   'Tomb Raider': 86,
#   'The Showdown Effect': 67,
#   'Kentucky Route Zero': 81,
#   'The Bridge': 74,
#   'The Banner Saga: Factions': 67,
#   'Brutal Legend': 80,
#   "Bientôt l'été": 62,
#   'Impire': 45,
#   'Proteus': 80,
#   'Sonic & All-Stars Racing Transformed': 79,
#   'Antichamber': 82,
#   '10,000,000': 67,
#   'Expansion - Crusader Kings II: The Republic': 81,
#   'Euro Truck Simulator 2': 79,
#   "Baldur's Gate: Enhanced Edition": 78,
#   'The Journey Down: Chapter One': 72},
#  2014: {'BeatBlasters III': 56,
#   'Blood of the Werewolf': 65,
#   'Particulars': 74,
#   'CONSORTIUM': 66,
#   'Nidhogg': 81,
#   'Humans Must Answer': 55,
#   'Insurgency': 74,
#   'Our Darker Purpose': 74,
#   'The Castle Doctrine': 58,
#   'rymdkapsel': 77,
#   'Octodad: Dadliest Catch': 69,
#   'Agarest: Generations of War': 45,
#   'NaissanceE': 66,
#   'Eschalon: Book III': 67,
#   'Ikaruga': 84,
#   'Castlevania: Lords of Shadow 2': 58,
#   'Talisman: Digital Edition': 51,
#   'Windforge': 53,
#   'Dominique Pamplemousse': 62,
#   'TowerFall Ascension': 87,
#   'Constant C': 60,
#   'Deus Ex: The Fall': 45,
#   'LUFTRAUSERS': 80,
#   'BioShock Infinite: Burial at Sea - Episode Two': 80,
#   'Cloudbuilt': 72,
#   'Mercenary Kings': 76,
#   'Actual Sunlight': 77,
#   'Half Minute Hero: The Second Coming': 79,
#   'Halo: Spartan Assault': 70,
#   'Dracula: The Resurrection': 67,
#   'Nostradamus: The Last Prophecy': 70,
#   'Croixleur Sigma': 56,
#   'Jet Car Stunts': 57,
#   'Full Bore': 72,
#   'Croixleur Sigma Demo': 56,
#   'Blade Symphony': 72,
#   'The Last Tinker™: City of Colors': 72,
#   'DreadOut': 55,
#   'BattleBlock Theater®': 85,
#   'Qbeh-1: The Atlas Cube': 72,
#   'Men of War: Assault Squad 2': 68,
#   'Tropico 5': 75,
#   'Expansion - Europa Universalis IV: Wealth of Nations': 84,
#   'Anomaly Defenders': 70,
#   'Where is my Heart?': 74,
#   'The Fall': 76,
#   'Richard & Alice': 70,
#   'Nether: Resurrected': 57,
#   'Lifeless Planet Premier Edition': 59,
#   'Munin': 68,
#   'Enemy Front': 52,
#   'Xenonauts': 77,
#   'MotoGP™14': 76,
#   'Company of Heroes 2 - The Western Front Armies': 80,
#   'Divinity: Original Sin (Classic)': 87,
#   'Warface': 62,
#   'MouseCraft': 72,
#   'Expansion - Europa Universalis IV: Res Publica': 79,
#   'Magic 2015 - Duels of the Planeswalkers': 60,
#   'Rulers of Nations': 63,
#   'Sokobond': 82,
#   'Freedom Planet': 83,
#   'Vertical Drop Heroes HD': 70,
#   'The Room': 73,
#   'The Legend of Heroes: Trails in the Sky': 85,
#   'Sacred 3': 57,
#   'GRID Autosport - Coupé Style Pack': 78,
#   'Road Not Taken': 75,
#   'Orbital Gear': 59,
#   'Mega Coin Squad': 56,
#   'Guacamelee! Super Turbo Championship Edition': 80,
#   'Shadowgate (2014)': 68,
#   'Super Time Force Ultra': 80,
#   'The Journey Down: Chapter Two': 78,
#   'Metro: Last Light Redux': 76,
#   'Lichdom: Battlemage': 69,
#   'GoD Factory: Wingmen': 76,
#   'Minimum': 69,
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM Revolution': 61,
#   'Endless Legend™': 82,
#   'WAKFU': 76,
#   'Heavy Bullets': 72,
#   'Age of Wonders III - Golden Realms Expansion': 82,
#   "Wasteland 2: Director's Cut": 87,
#   'Stronghold Crusader 2': 65,
#   'DG2: Defense Grid 2': 81,
#   'Pier Solar and the Great Architects': 73,
#   'Sherlock Holmes: Crimes and Punishments': 77,
#   'Middle-earth: Shadow of Mordor - GOTY Edition Upgrade': 84,
#   'Silence of the Sleep': 66,
#   'Qora': 63,
#   'Styx: Master of Shadows': 71,
#   'Costume Quest 2': 68,
#   'The Evil Within': 68,
#   'Ultimate General: Gettysburg': 84,
#   'F1 2014': 61,
#   'Screencheat': 71,
#   'Spacebase DF-9': 49,
#   'BlazeRush': 66,
#   'Farming Simulator 15': 64,
#   'Defenders of Time': 55,
#   'Crowntakers': 70,
#   'A Bird Story': 66,
#   'Toybox Turbos': 69,
#   'Space Hulk Ascension': 72,
#   'Chariot': 76,
#   "Randal's Monday": 57,
#   'Sneaky Sneaky': 63,
#   'Company of Heroes 2 - Ardennes Assault': 81,
#   'Far Cry® 4': 80,
#   'The Blue Flamingo': 55,
#   'Escape Dead Island': 52,
#   "Letter Quest: Grimm's Journey": 73,
#   'The Witcher Adventure Game': 68,
#   "Joe Dever's Lone Wolf HD Remastered": 78,
#   'JUJU': 65,
#   'LISA': 78,
#   'Metrocide': 68,
#   'Dead Effect': 59,
#   'METAL GEAR SOLID V: GROUND ZEROES': 80,
#   'Vertiginous Golf': 63,
#   'WildStar': 82,
#   'Roundabout': 75,
#   'The Talos Principle': 85,
#   'Vertical Drop Heroes HD Demo': 70,
#   'Redux: Dark Matters': 61,
#   'LARA CROFT AND THE TEMPLE OF OSIRIS™': 73,
#   'Dead State: Reanimated': 70,
#   'Fight The Dragon': 76,
#   'The Crew™': 71,
#   'Lumino City': 70,
#   'The Old City: Leviathan': 62,
#   'Akaneiro: Demon Hunters': 53,
#   'Warhammer 40,000: Armageddon': 68,
#   'Rollers of the Realm': 68,
#   'Frozen Synapse Prime': 83,
#   'This War of Mine': 83,
#   'Lords of Xulima': 71,
#   'Basketball Pro Management 2015': 69,
#   'Shadows: Heretic Kingdoms': 74,
#   'The Marvellous Miss Take': 69,
#   "Five Nights at Freddy's 2": 62,
#   'FOTONICA': 71,
#   'Icewind Dale: Enhanced Edition': 80,
#   'The Detail': 77,
#   'Lords Of The Fallen™': 73,
#   'Majestic Nights': 32,
#   "Buzz Aldrin's Space Program Manager": 62,
#   'Call of Duty®: Advanced Warfare - Gold Edition': 78,
#   'Depth': 65,
#   'Dungeon of the Endless™': 79,
#   'Kromaia': 68,
#   "Sid Meier's Civilization®: Beyond Earth™": 81,
#   'Ziggurat': 75,
#   'Door Kickers': 83,
#   'Poltergeist: A Pixelated Horror': 70,
#   'Wings! Remastered Edition': 61,
#   'DeadCore': 78,
#   'Gabriel Knight: Sins of the Fathers 20th Anniversary Edition': 74,
#   'Expansion - Crusader Kings II: Charlemagne': 80,
#   'Borderlands: The Pre-Sequel': 75,
#   'Alien: Isolation': 81,
#   'TRI: Of Friendship and Madness': 74,
#   'A Golden Wake': 68,
#   'Ryse: Son of Rome': 61,
#   'Schrödinger’s Cat And The Raiders Of The Lost Quark': 59,
#   'Fenix Rage': 75,
#   "The Vanishing of Ethan Carter - Collector's Edition Upgrade": 82,
#   'The Vanishing of Ethan Carter': 82,
#   'Kraven Manor': 58,
#   'Starpoint Gemini 2': 70,
#   'Neverending Nightmares': 68,
#   'Outland': 83,
#   'Shadow Puppeteer': 57,
#   'SPACECOM': 68,
#   "Shadowrun: Dragonfall - Director's Cut": 87,
#   'J.U.L.I.A.: Among the Stars': 71,
#   'Battle Academy 2: Eastern Front': 78,
#   'To End All Wars': 71,
#   'Runers': 68,
#   'Train Fever': 67,
#   'Hatoful Boyfriend': 68,
#   "Hack 'n' Slash": 73,
#   'Lethal League': 82,
#   'Bravada': 70,
#   'Risen 3 - Titan Lords': 65,
#   "Five Nights at Freddy's": 78,
#   'Chess 2: The Sequel': 62,
#   "King's Bounty: Dark Side": 73,
#   'Back to Bed': 57,
#   'Pure Pool': 68,
#   'The Sun at Night': 59,
#   'Eidolon': 64,
#   'Pineview Drive': 58,
#   'Lovely Planet': 61,
#   'Unrest': 65,
#   'Gods Will Be Watching': 64,
#   'UnEpic': 68,
#   'Only If': 39,
#   'OlliOlli': 78,
#   'Medieval II: Total War Kingdoms': 85,
#   'So Many Me': 78,
#   'Light': 49,
#   'Quest for Infamy': 63,
#   'Abyss Odyssey': 69,
#   'Wayward Manor': 41,
#   'Terrian Saga: KR-17': 83,
#   'Whispering Willows': 64,
#   '4PM': 41,
#   'Meridian: New World': 43,
#   'Battleplan: American Civil War': 66,
#   'Shovel Knight: Treasure Trove': 85,
#   'GRID Autosport': 78,
#   'Crimsonland': 68,
#   'SPINTIRES™': 67,
#   'Space Run': 73,
#   'The Incredible Adventures of Van Helsing II': 77,
#   'Qvadriga': 72,
#   'Rise of Nations: Extended Edition': 89,
#   'Concursion': 66,
#   'Ionball 2: Ionstorm': 70,
#   'Freespace 2': 91,
#   'Crimzon Clover WORLD IGNITION': 85,
#   'The Floor is Jelly': 83,
#   'Astebreed: Definitive Edition': 86,
#   'Murdered: Soul Suspect': 59,
#   '1001 Spikes': 80,
#   'Defiance': 64,
#   'Distant Worlds: Universe': 81,
#   'ibb & obb': 83,
#   'Watch_Dogs™': 77,
#   'FINAL FANTASY III': 68,
#   'Panzer Tactics HD': 69,
#   'A Story About My Uncle': 73,
# ...
#   'Shadwen': 53,
#   'Disgaea PC / 魔界戦記ディスガイア PC': 74,
#   'SUPERHOT': 82,
#   'The Count Lucanor': 78,
#   'The Guest': 68,
#   'Momodora: Reverie Under The Moonlight': 82,
#   "Alekhine's Gun": 40,
#   'Obscuritas': 63,
#   'Nelly Cootalot: The Fowl Fleet': 81,
#   'Zombasite': 66,
#   'Samorost 3': 80,
#   'Hyper Light Drifter': 84,
#   'The Minims': 73,
#   'Good Robot': 67,
#   'DARIUSBURST Chronicle Saviours - Space Harrier': 80,
#   'DARIUSBURST Chronicle Saviours - Fantasy Zone': 80,
#   'DARIUSBURST Chronicle Saviours - Galaxy Force II': 80,
#   'Code of Princess': 53,
#   'LOUD on Planet X': 72,
#   'Corpse Party': 71,
#   'Cornerstone: The Song of Tyrim': 58,
#   'Wailing Heights': 70,
#   'Ori and the Blind Forest: Definitive Edition': 88,
#   'Offworld Trading Company': 78,
#   'Back in 1995': 52,
#   'N.E.R.O.: Nothing Ever Remains Obscure': 59,
#   'Kathy Rain': 77,
#   'Fragments of Him': 69,
#   'Battleborn': 69,
#   'TransOcean 2: Rivals': 69,
#   'Goliath': 57,
#   'Homefront®: The Revolution': 54,
#   'Salt and Sanctuary': 84,
#   'Overfall': 71,
#   'Duskers': 83,
#   'OmniBus': 55,
#   'Planar Conquest': 53,
#   'Turmoil': 73,
#   "Sherlock Holmes: The Devil's Daughter": 65,
#   'Trials of the Blood Dragon': 54,
#   'BLACKHOLE: Challenge Vault': 82,
#   "WildStar: Captain's Pack": 82,
#   'WildStar: Cute & Cuddly Pack': 82,
#   'Furi': 76,
#   "The Lion's Song: Episode 1 - Silence": 78,
#   'Fossil Echo': 61,
#   'VIDEOBALL': 82,
#   'Muv-Luv': 76,
#   'EARTH DEFENSE FORCE 4.1 The Shadow of New Despair': 79,
#   "Ian's Eyes": 36,
#   'Kelvin and the Infamous Machine': 79,
#   'DreamBreak': 46,
#   '8DAYS - PEACE IS OUR BUSINESS': 64,
#   'Starbound': 81,
#   'Human: Fall Flat': 70,
#   'Lovely Planet Arcade': 78,
#   'Headlander': 74,
#   "Little King's Story": 62,
#   'Road to Ballhalla': 75,
#   'The Silver Case': 67,
#   'Ray Gigant': 55,
#   'Reigns': 77,
#   'Grow Up': 71,
#   'F1 2016': 86,
#   'Worms W.M.D': 79,
#   'Deus Ex: Mankind Divided': 83,
#   'Hue': 79,
#   'The Turing Test': 74,
#   'Talent Not Included': 73,
#   'The Final Station': 76,
#   'The Warlock of Firetop Mountain': 70,
#   'Halcyon 6: Starbase Commander': 71,
#   'The Bunker': 57,
#   'Wheels of Aurelia': 63,
#   'Seraph': 80,
#   'Zenith': 57,
#   'NBA 2K17': 90,
#   'Fractured Space': 79,
#   'Klang': 71,
#   'Lichtspeer': 72,
#   'Clustertruck': 76,
#   'Sunless Sea - Zubmariner': 78,
#   'Mantis Burn Racing®': 71,
#   'GoNNER': 81,
#   'Crazy Machines 3': 71,
#   'Orwell: Keeping an Eye On You': 77,
#   'Sid Meier’s Civilization® VI': 88,
#   'Farming Simulator 17': 69,
#   'Slayaway Camp': 83,
#   'Oh...Sir!! The Insult Simulator': 64,
#   'The Elder Scrolls V: Skyrim Special Edition': 74,
#   'Football Manager 2017': 80,
#   'Beholder': 75,
#   'Yesterday Origins': 74,
#   'Silence': 75,
#   'Candle': 80,
#   "Don't open the doors!": 68,
#   'ICEY': 84,
#   'Killing Floor 2': 75,
#   'Cities: Skylines - Natural Disasters': 80,
#   'The Dwarves': 61,
#   'Steep™': 72,
#   'Dungeon Souls': 67,
#   "Her Majesty's SPIFFING": 60,
#   'Hearts of Iron IV: Together for Victory': 71,
#   'Hide and Shriek': 68,
#   'Dark Train': 76,
#   'Torment: Tides of Numenera': 81,
#   'Youtubers Life': 63,
#   'Ladykiller in a Bind': 73,
#   '99Vidas': 69,
#   'Shantae: Half-Genie Hero': 76,
#   'Stereo Aereo': 58,
#   'The Little Acre': 62,
#   'OneShot': 81,
#   'Nitroplus Blasterz: Heroines Infinite Duel': 63,
#   'Maize': 65,
#   'Quern - Undying Thoughts': 83,
#   'Planet Coaster': 84,
#   'RollerCoaster Tycoon World™': 43,
#   'Super Rad Raygun': 64,
#   'ENIGMA:': 56,
#   'Dofus': 72,
#   'Mekazoo': 80,
#   'Dishonored 2': 86,
#   'Ashes of the Singularity: Escalation': 81,
#   'Motorsport Manager': 81,
#   'Small Radios Big Televisions': 67,
#   'Pirate Pop Plus': 65,
#   'Call of Duty®: Infinite Warfare': 73,
#   'Xanadu Next': 78,
#   'Creepy Castle': 82,
#   'Franchise Hockey Manager 3': 64,
#   'Owlboy': 88,
#   'Rusty Lake: Roots': 75,
#   'Endless Legend™ - Tempest': 82,
#   'Shadow Warrior 2': 78,
#   'Duke Nukem 3D: 20th Anniversary World Tour': 72,
#   'Ride 2': 67,
#   'WRC 6 FIA World Rally Championship': 68,
#   "Five Nights at Freddy's: Sister Location": 62,
#   'Mafia III': 62,
#   'Atlas Reactor': 81,
#   'Aragami': 71,
#   'Shu': 85,
#   'Masquerada: Songs and Shadows': 64,
#   'Wuppo': 78,
#   'The Metronomicon: Slay The Dance Floor': 79,
#   'Hybrid Wars': 54,
#   'Burly Men at Sea': 82,
#   'Rogue Wizards': 67,
#   'Toy Odyssey: The Lost and Found': 66,
#   'Diaries of a Spaceport Janitor': 69,
#   'Marooners': 70,
#   'Event[0]': 75,
#   'Ember': 70,
#   'STEINS;GATE': 87,
#   'Project Highrise': 73,
#   'How to Survive 2': 69,
#   "Unbox: Newbie's Adventure": 68,
#   'Mother Russia Bleeds': 70,
#   'Tadpole Treble': 90,
#   'The Curious Expedition': 74,
#   'Seasons after Fall': 75,
#   'Tahira: Echoes of the Astral Empire': 66,
#   'RunGunJumpGun': 82,
#   'Shiny': 51,
#   'Livelock': 73,
#   'N++ (NPLUSPLUS)': 90,
#   'Master of Orion': 74,
#   'Virginia': 74,
#   'Metrico+': 66,
#   'Duelyst': 82,
#   'Guards': 49,
#   'Okhlos: Omega': 69,
#   'Champions of Anteria™': 67,
#   "No Man's Sky": 61,
#   'Tricky Towers': 80,
#   'ABZU': 83,
#   'Near Death': 70,
#   'Overcooked': 81,
#   'Quadrilateral Cowboy': 81,
#   'MilitAnt': 41,
#   'Tumblestone': 91,
#   'Poly Bridge': 73,
#   'The Real Texas': 74,
#   'Anarcute': 79,
#   'Krai Mira: Extended Cut': 50,
#   'Arma 3 Apex': 74,
#   'Song of the Deep': 71,
#   'Crush Your Enemies': 63,
#   'Mighty No. 9': 52,
#   'VA-11 Hall-A: Cyberpunk Bartender Action': 77,
#   'Space Run Galaxy': 75,
#   'Pro Cycling Manager 2016': 64,
#   'Valentino Rossi The Game': 72,
#   'On Rusty Trails': 77,
#   'WildStar: Adventure Pack': 82,
#   'WildStar: Hero Pack': 82,
#   'WildStar: Legend Pack (NA)': 82,
#   'SteamWorld Heist': 81,
#   'Last Days of Old Earth': 66,
#   'WASTED': 68,
#   'Hearts of Iron IV': 83,
#   'Super Duper Party Pooper': 40,
#   "Hunter's Legacy": 58,
#   'Hard Reset Redux': 73,
#   'Dangerous Golf': 54,
#   'Brigador: Up-Armored Edition': 70,
#   'SENRAN KAGURA SHINOVI VERSUS': 70,
#   'TurnOn': 67,
#   'Chronicle: RuneScape Legends': 76,
#   'Excubitor': 69,
#   'Blacksea Odyssey': 74,
#   'Total War: WARHAMMER': 86,
#   'Lumo': 77,
#   'POSTAL Redux': 54,
#   'Koihime Enbu': 68,
#   'Sengoku Jidai: Shadow of the Shogun': 80,
#   'Demetrios - The BIG Cynical Adventure': 72,
#   'DOOM': 85,
#   'Ryzom': 64,
#   'Scrap Garden': 58,
#   'Dead Effect 2': 53,
#   'Stellaris': 78,
#   'Cars': 73,
#   'Neon Chrome': 74,
#   'March of the Living': 63,
#   'Megamagic: Wizards of the Neon Age': 67,
#   "Don't Starve Together": 83,
#   'Battlefleet Gothic: Armada': 77,
#   'Rogue Stormers': 68,
#   "Stephen's Sausage Roll": 90,
#   'Battlezone 98 Redux': 75,
#   'Danganronpa 2: Goodbye Despair': 83,
#   'HEX: Shards of Fate': 87,
#   'IS Defense': 50,
#   'The Banner Saga 2': 82,
#   'FINAL FANTASY IX': 84,
#   'Goetia': 79,
#   "Everybody's Gone to the Rapture": 76,
#   'Aurion: Legacy of the Kori-Odan': 69,
#   'DARK SOULS™ III': 89,
#   'Stories: The Path of Destinies': 74,
#   'Mushroom Wars': 80,
#   'Kill to Collect': 57,
#   'Enter the Gungeon': 84,
#   '1979 Revolution: Black Friday': 80,
#   "Baldur's Gate: Siege of Dragonspear": 77,
#   'Leap of Fate': 80,
#   'Epistory - Typing Chronicles': 74,
#   'Magical Eyes - Red is for Anguish': 77,
#   "The Last Door: Season 2 - Collector's Edition": 85,
#   'Slain: Back from Hell': 74,
#   'The Descendant: Rest of Season': 57,
#   'The Descendant': 59,
#   'Day of the Tentacle Remastered': 86,
#   'Polaris Sector': 76,
#   'Out of the Park Baseball 17': 92,
#   'Music Pack - Music for Code EP': 85,
#   'Moon Hunters': 62,
#   'WWE 2K16': 74,
#   'Deathsmiles': 78,
#   'Gremlins, Inc.': 75,
#   'Ares Omega': 49,
#   'Into the Stars': 61,
#   'E.T. Armies': 54,
#   'Stardew Valley': 89,
#   'Far Cry® Primal': 74,
#   'Shardlight': 75,
#   'Deponia Doomsday': 76,
#   'Blood Alloy: Reborn': 48,
#   'Soul Axiom': 57,
#   'Grim Dawn': 83,
#   "Heaven's Hope - Special Edition": 74,
#   'Ninja Senki DX': 72,
#   'Obliteracers': 78,
#   'Devil Daggers': 83,
#   'Cities: Skylines - Snowfall': 72,
#   'ARSLAN: THE WARRIORS OF LEGEND': 57,
#   'American Truck Simulator': 76,
#   'Firewatch': 81,
#   'XCOM® 2': 88,
#   'Cobalt': 69,
#   'Rusty Lake Hotel': 65,
#   'CALENDULA': 67,
#   'DarkMaus': 83,
#   "The Order of the Thorne - The King's Challenge": 71,
#   'Crashlands': 78,
#   'Dinocide': 51,
#   'Move or Die': 80,
#   'The Westport Independent': 63,
#   'Monumental': 41,
#   'Between Me and The Night': 62,
#   'Slybots: Frantic Zone': 65,
#   'Gemini: Heroes Reborn': 54,
#   'Shooting Stars!': 59,
#   'The Aquatic Adventure of the Last Human': 76,
#   'The Bug Butcher': 81,
#   'The Deadly Tower of Monsters': 73,
#   'Darkest Dungeon®': 84,
#   'Echoes of Aetheria': 77,
#   'Pony Island': 86,
#   'Sora': 74},
#  2017: {'Drifting Lands': 71,
#   'Milkmaid of the Milky Way': 74,
#   'Stars in Shadow': 75,
#   'SpiritSphere': 64,
#   'RESIDENT EVIL 7 biohazard / BIOHAZARD 7 resident evil': 83,
#   'Memoranda': 58,
#   'Aliens Go Home Run': 84,
#   'Atelier Sophie: The Alchemist of the Mysterious Book': 73,
#   'Take On Mars': 62,
#   'FOR HONOR™': 76,
#   'BOOR': 71,
#   'Hidden Folks': 78,
#   'Night in the Woods': 88,
#   'Hollow Knight': 86,
#   'Downward': 77,
#   'DESYNC': 69,
#   'Loot Rascals': 71,
#   'Dead Rising 4': 74,
#   'Toukiden 2': 73,
#   'Monster Slayers': 86,
#   'Quern - Undying Thoughts (Original Soundtrack)': 83,
#   'Mantis Burn Racing® - Elite Class': 71,
#   'Mantis Burn Racing® - Snowbound Pack': 71,
#   'Thimbleweed Park™': 84,
#   'LEGO City Undercover': 80,
#   'Slime-san': 78,
#   'The Sexy Brutale': 83,
#   'Bayonetta': 90,
#   'Yooka-Laylee': 73,
#   'Snow Moto Racing Freedom': 50,
#   'Cosmic Star Heroine': 77,
#   'Voodoo Vince: Remastered': 63,
#   "Marvel's Guardians of the Galaxy: The Telltale Series": 78,
#   'Full Throttle Remastered': 77,
#   'Forts': 74,
#   'Little Nightmares': 81,
#   'Dawn of Andromeda': 70,
#   'World to the West': 75,
#   'Rakuen': 84,
#   'Empathy: Path of Whispers': 57,
#   'Bounty Train': 66,
#   'Bokida - Heartfelt Reunion': 75,
#   'Cities: Skylines - Mass Transit': 78,
#   'Mages of Mystralia': 74,
#   'Portal Knights': 72,
#   'The Infectious Madness of Doctor Dekker': 78,
#   'Dynasty Feud': 68,
#   'Starpoint Gemini Warlords': 74,
#   'Black Desert Online': 73,
#   'Danger Zone': 64,
#   'Rising Storm 2: Vietnam': 81,
#   'The Long Journey Home': 68,
#   'Formula Fusion': 58,
#   'TEKKEN 7': 82,
#   'Blitzkrieg 3': 68,
#   'Monolith': 83,
#   'Pro Cycling Manager 2017': 71,
#   'Darkest Dungeon®: The Crimson Court': 82,
#   'Nex Machina': 84,
#   'GET EVEN': 75,
#   'BULLET SOUL / バレットソウル - 弾魂 - Original Soundtrack': 76,
#   'Antihero': 81,
#   'Lode Runner Legacy': 76,
#   'Serial Cleaner': 64,
#   'Yonder: The Cloud Catcher Chronicles': 70,
#   'Dream Daddy: A Dad Dating Simulator': 72,
#   'Super Cloudbuilt': 76,
#   'Pyre': 82,
#   'Solstice Chronicles: MIA': 68,
#   'BULLET SOUL INFINITE BURST - Original Soundtrack': 76,
#   'Secret World Legends': 76,
#   'Aztez': 81,
#   'Slime Rancher': 81,
#   'The Legend of Heroes: Trails of Cold Steel': 80,
#   'The Shrouded Isle': 69,
#   'Cat Quest': 78,
#   'Fictorum': 64,
#   'West of Loathing': 86,
#   'Sudden Strike 4': 70,
#   '>observer_': 78,
#   'Nidhogg 2': 80,
#   'XCOM 2: War of the Chosen - Propaganda Center': 88,
#   'XCOM 2: War of the Chosen': 88,
#   'ARK: Survival Evolved': 70,
#   'Ys SEVEN': 80,
#   'Songbringer': 67,
#   'Fall of Light': 69,
#   'PRO EVOLUTION SOCCER 2018': 81,
#   'Oriental Empires': 74,
#   'Mantis Burn Racing® - Battle Cars': 71,
#   'Dishonored®: Death of the Outsider™': 80,
#   'ATOMEGA': 65,
#   'ECHO': 72,
#   'Marvel vs. Capcom: Infinite': 69,
#   'Auto Age: Standoff': 59,
#   'Heat Signature': 79,
#   'Figment': 77,
#   'BLUE REFLECTION / BLUE REFLECTION\u3000幻に舞う少女の剣': 61,
#   'RUINER': 75,
#   'Vaporum': 78,
#   'JYDGE': 81,
#   'A Hat in Time': 79,
#   'Mushroom Wars 2': 76,
#   'Deadbeat Heroes': 66,
#   'Bomber Crew': 75,
#   'Attentat 1942': 75,
#   'Sonic Forces': 58,
#   'Battlerite': 85,
#   'Reigns: Her Majesty': 81,
#   'SpellForce 3': 74,
#   'Gorogoa': 83,
#   'Bridge Constructor Portal': 78,
#   'Raiders of the Broken Planet - Ultimate Edition': 54,
#   'Purrfect Date - Visual Novel/Dating Simulator': 76,
#   'Finding Paradise': 82,
#   'No Escape': 63,
#   'OKAMI HD / 大神 絶景版': 93,
#   'Hello Neighbor': 40,
#   'Breakneck': 76,
#   'Battle Chef Brigade': 80,
#   'HYAKKI CASTLE': 65,
#   'World of Warships': 81,
#   'Syberia 3': 51,
#   'Football Manager 2018': 82,
#   'Hand of Fate 2': 80,
#   '.hack//G.U. Last Recode': 69,
#   'Zwei: The Ilvard Insurrection': 80,
#   'Wolfenstein II: The New Colossus': 86,
#   'Freaky Awesome': 54,
#   'WWE 2K18': 66,
#   'Dungeons 3': 75,
#   'The Evil Within 2': 81,
#   'Field of Glory II': 84,
#   'Inmates': 46,
#   'Ogre': 66,
#   'EMPYRE: Lords of the Sea Gates': 56,
#   'Battle Chasers: Nightwar': 79,
#   'Mutant Football League': 75,
#   'Microsoft Allegiance': 86,
#   'Cuphead': 88,
#   'Total War: WARHAMMER II': 86,
#   'Hob': 77,
#   'RAID: World War II': 53,
#   'Pylon: Rogue': 50,
#   'Raiders of the Broken Planet - Eternal Soldier Campaign': 54,
#   'SteamWorld Dig 2': 85,
#   'The Journey Down: Chapter Three': 78,
#   'Stellaris: Synthetic Dawn Story Pack': 83,
#   "Another Lost Phone: Laura's Story": 73,
#   'CHASER': 66,
#   'Super Hydorah': 82,
#   'NBA 2K18': 87,
#   'Divinity: Original Sin 2': 93,
#   'Tooth and Tail': 80,
#   'Tokyo Dark': 70,
#   'Beat The Game': 55,
#   'Darkestville Castle': 68,
#   'Last Day of June': 75,
#   'Battlestar Galactica Deadlock': 77,
#   'Life is Strange: Before the Storm': 79,
#   'Absolver': 75,
#   'Sonic Mania': 84,
#   'F1™ 2017': 89,
#   'The Escapists 2': 74,
#   'Subsurface Circular': 83,
#   'Moero Chronicle | 限界凸記 モエロクロニクル | 極限凸記\u3000萌萌編年史': 64,
#   'Halcyon 6: Starbase Commander (LIGHTSPEED EDITION)': 73,
#   'LawBreakers': 76,
#   "Hellblade: Senua's Sacrifice": 83,
#   'Tacoma': 76,
#   'Sundered': 74,
#   'Immortal Planet': 65,
#   'Aven Colony': 65,
#   'Dreamfall Chapters': 71,
#   'Behold the Kickmen': 58,
#   'Aporia: Beyond The Valley': 71,
#   'Gigantic': 76,
#   'Kingsway': 80,
#   'Children of Zodiarcs': 73,
#   'The End Is Nigh': 84,
#   'Black The Fall': 72,
#   'Baobabs Mausoleum Ep.1: Ovnifagos Don´t Eat Flamingos': 69,
#   'No70: Eye of Basir': 52,
#   'CRYPTARK': 80,
#   'FINAL FANTASY XIV: Stormblood': 87,
#   'DiRT 4': 78,
#   'Randall': 48,
#   'Conarium': 73,
#   'Lydia': 78,
#   'AereA': 53,
#   'Rezrog': 70,
#   'Tokyo 42': 70,
#   'Hover': 69,
#   'Emily is Away Too': 81,
#   'RiME': 78,
#   'Friday the 13th: The Game': 61,
#   'Vanquish': 78,
#   'Steel Division: Normandy 44': 83,
#   'Impact Winter': 62,
#   'The Fidelio Incident': 69,
#   "Old Man's Journey": 77,
#   'Regalia: Of Men and Monarchs': 73,
#   'The Surge': 72,
#   'Plasma Puncher': 69,
#   'OVIVO': 71,
#   "Block'hood": 77,
#   'NBA Playgrounds': 67,
#   'The Legend of Heroes: Trails in the Sky the 3rd': 83,
#   'Expeditions: Viking': 74,
#   'Immortal Redneck': 70,
#   'What Remains of Edith Finch': 89,
#   'Everything': 78,
#   'Orcs Must Die! Unchained': 87,
#   'Flinthook': 80,
#   'Shiness: The Lightning Kingdom': 68,
#   'Altitude': 79,
#   'Bulletstorm: Full Clip Edition': 76,
#   'The Franz Kafka Videogame': 65,
#   'BULLET SOUL / バレットソウル - 弾魂 -': 76,
#   'Blackwood Crossing': 70,
#   'FlatOut 4: Total Insanity': 52,
#   'The Great Whale Road': 61,
#   'Miniature Garden': 66,
#   'Rain World': 66,
#   'Fallout Shelter': 63,
#   'Battle Brothers': 80,
#   'Has-Been Heroes': 63,
#   'Mafia III: Faster, Baby!': 62,
#   'Bush Hockey League': 48,
#   'Snake Pass': 71,
#   'Out of the Park Baseball 18': 86,
#   "The Crow's Eye": 65,
#   'Kona': 73,
#   'NieR:Automata™': 84,
#   'The Keep': 61,
#   'Future Unfolding': 75,
#   '2Dark': 68,
#   'Blossom Tales: The Sleeping King': 78,
#   'Faeria': 80,
#   'Stories Untold': 81,
#   'Shadows of Adam': 78,
#   'Herald: An Interactive Period Drama - Book I & II': 77,
#   'DYSTORIA': 72,
#   '🔴 Circles': 76,
#   'NeverEnd': 44,
#   'The Wardrobe': 72,
#   'We Are Chicago': 49,
#   'Alone With You': 75,
#   'Brut@l': 66,
#   'Leaving Lyndow': 74,
#   'Bleed 2': 83,
#   'Arelite Core': 59,
#   'WWE 2K17': 61,
#   'Phoning Home': 61,
#   'Splasher': 79,
#   'Nights of Azure': 64,
#   'Diluvion': 66,
#   "Alwa's Awakening": 71,
#   'Angels with Scaly Wings': 67,
#   'Disgaea 2 PC / 魔界戦記ディスガイア2 PC': 81,
#   'Double Dragon IV': 50,
#   'Linelight': 90,
#   'A Normal Lost Phone': 71,
#   'Nefarious': 67,
#   'Urban Empire': 62,
#   'Warhammer 40,000: Sanctus Reach': 68,
#   'Tales of Berseria™': 80,
#   'HoPiKo': 82,
#   'She Remembered Caterpillars': 82,
#   'Mainlining': 73,
#   'The Darkside Detective': 75,
#   'Among the Sleep - Enhanced Edition': 66,
#   'Project Earth': 67}}

# %% [markdown]
# Sort by values.

# %%
metascoreEndpointDict_sorted = sort_dic(metascoreEndpointDict)
metascoreEndpointDict_sorted
# Out:
# {1992: {'Reservoir Dogs': 50},
#  1993: {'realMYST': 66},
#  1994: {'DOOM II': 83},
#  1996: {'Star Control: Kessari Quadrant': 89,
#   'Lords of the Realm II': 77,
#   'FROM DUSK TILL DAWN': 58,
#   'Harvester': 53},
#  1997: {'STAR WARS™ Jedi Knight: Dark Forces II': 91,
#   'Fallout: A Post Nuclear Role Playing Game': 89,
#   'Total Annihilation': 86,
#   'Riven: The Sequel to MYST': 83,
#   'The Last Express Gold Edition': 82,
#   'Shadow Warrior (Classic)': 73,
#   'Tony Tough and the Night of Roasted Moths': 68,
#   'POSTAL': 56},
#  1998: {'Half-Life': 96,
#   'Thief™ Gold': 92,
#   'Railroad Tycoon II Platinum': 89,
#   'Shogo: Mobile Armor Division': 88,
#   'Fallout 2: A Post Nuclear Role Playing Game': 86,
#   'Falcon 4.0': 85,
#   'Blood: One Unit Whole Blood': 82,
#   'Blood II: The Chosen + Expansion': 72},
#  1999: {'System Shock 2': 92,
#   'Gabriel Knight® 3: Blood of the Sacred, Blood of the Damned': 80,
#   'Dawn of Discovery™: Venice': 78,
#   'Septerra Core': 72,
#   'X: Beyond the Frontier': 67,
#   'Army Men II': 67},
#  2000: {'Unreal Tournament: Game of the Year Edition': 92,
#   'The Longest Journey': 91,
#   'Deus Ex: Game of the Year Edition': 90,
#   'Sacrifice': 89,
#   'Counter-Strike': 88,
#   'Thief™ II: The Metal Age': 87,
#   'Ground Control Anthology': 86,
#   'MDK 2': 83,
#   'B-17 Flying Fortress: The Mighty 8th': 82,
#   'Earth 2150 Trilogy': 78,
#   'Vampire: The Masquerade - Redemption': 74,
#   'Hidden & Dangerous: Action Pack': 74,
#   'Delta Force Land Warrior': 74,
#   'Hitman: Codename 47': 73,
#   'Call to Power II': 72,
#   'Soulbringer': 70,
#   'QUAKE III: Team Arena': 69,
#   'Beachhead 2000': 46},
#  2001: {"Sid Meier's Civilization® III Complete": 90,
#   'Max Payne': 89,
#   'Return to Castle Wolfenstein': 88,
#   'Serious Sam Classic: The First Encounter': 87,
#   'Kohan: Immortal Sovereigns': 87,
#   'Startopia': 86,
#   'Wizardry 8': 85,
#   'Sub Command': 84,
#   'Independence War® 2: Edge of Chaos': 83,
#   'Fallout Tactics: Brotherhood of Steel': 82,
#   'Stronghold HD': 81,
#   'Gothic 1': 81,
#   'Hostile Waters: Antaeus Rising': 80,
#   'The Corporate Machine': 80,
#   'Conquest: Frontier Wars': 80,
#   "Tom Clancy's Ghost Recon®": 80,
#   "Kohan: Ahriman's Gift": 79,
#   'Desperados: Wanted Dead or Alive': 78,
#   'Summoner': 78,
#   'Red Faction': 78,
#   'Legacy of Kain: Soul Reaver 2': 77,
#   'Anachronox': 77,
#   'Etherlords': 77,
#   'Cossacks: European Wars': 74,
#   'Comanche 4': 74,
#   'WWII Online': 73,
#   'Anarchy Online': 72,
#   'World War III: Black Gold': 71,
#   'Half-Life: Blue Shift': 71,
#   'Echelon': 70,
#   'Eurofighter Typhoon': 69,
#   'Dracula 2: The Last Sanctuary': 68,
#   'AquaNox': 67,
#   'The Cameron Files: The Secret at Loch Ness': 66,
#   'X-COM: Enforcer': 65,
#   'Original War': 61,
#   'Deadly Dozen': 56},
#  2002: {'Grand Theft Auto III': 93,
#   'Freedom Force': 90,
#   'The Elder Scrolls III: Morrowind® Game of the Year Edition': 89,
#   'Mafia': 88,
#   'Hitman 2: Silent Assassin': 87,
#   'Commandos 2: Men of Courage': 87,
#   'Dungeon Siege': 86,
#   'Serious Sam Classic: The Second Encounter': 85,
#   'The Guild Gold Edition': 82,
#   'Syberia': 82,
#   "Tom Clancy's Ghost Recon® Desert Siege™": 82,
#   "Tom Clancy's Ghost Recon® Island Thunder™": 82,
#   'Divine Divinity': 81,
#   'Robin Hood: The Legend of Sherwood': 80,
#   'Stronghold Crusader HD': 78,
#   'Arx Fatalis': 77,
#   'MoonBase Commander': 77,
#   'RollerCoaster Tycoon® 2: Triple Thrill Pack': 74,
#   'Cossacks: Art of War': 74,
#   'Warrior Kings': 73,
#   'Worms Blast': 73,
#   'The Sum of All Fears': 72,
#   'Post Mortem': 71,
#   'STAR WARS™ Starfighter™': 71,
#   'Iron Storm': 69,
#   'Dark Fall: The Journal': 68,
#   'Army Men RTS': 67,
#   'Incoming Forces': 67,
#   'Cossacks: Back to War': 60,
#   'Conflict Desert Storm™': 56,
#   'Delta Force: Task Force Dagger': 51},
#  2003: {'Grand Theft Auto: Vice City': 94,
#   "Tom Clancy's Splinter Cell®": 91,
#   'Call of Duty®': 91,
#   'STAR WARS™ Jedi Knight II - Jedi Outcast™': 89,
#   'Prince of Persia®: The Sands of Time': 89,
#   'EVE Online': 88,
#   'Max Payne 2: The Fall of Max Payne': 86,
#   "Tom Clancy's Rainbow Six® 3 Gold": 85,
#   'Nancy Drew®: The Haunted Carousel': 85,
#   'Tron 2.0': 84,
#   'Broken Sword 3 - the Sleeping Dragon': 82,
#   'Ghost Master®': 81,
#   'Midnight Club 2': 81,
#   'Nancy Drew®: Danger on Deception Island': 81,
#   'STAR WARS™ Jedi Knight - Jedi Academy™': 81,
#   'Railroad Tycoon 3': 80,
#   'Ragnarok Online': 79,
#   'Day of Defeat': 79,
#   'Armed and Dangerous®': 78,
#   'Praetorians': 78,
#   'Etherlords II': 78,
#   'Massive Assault': 77,
#   'Salammbô: Battle for Carthage': 77,
#   'Delta Force: Black Hawk Down': 77,
#   'American Conquest': 76,
#   'Unreal 2: The Awakening': 75,
#   'Hidden & Dangerous 2: Courage Under Fire': 75,
#   'Runaway, A Road Adventure': 74,
#   'Impossible Creatures Steam Edition': 72,
#   'Commandos 3: Destination Berlin': 72,
#   'X2: The Threat': 72,
#   'Enclave': 71,
#   'Legacy of Kain: Defiance': 70,
#   'Nosferatu: The Wrath of Malachi': 70,
#   'Line of Sight: Vietnam': 68,
#   'American Conquest: Fight Back': 66,
#   'Chaser': 66,
#   'BloodRayne': 65,
#   'RC Cars': 65,
#   'Black Mirror I': 65,
#   'Journey to the Center of the Earth': 65,
#   'Warrior Kings: Battles': 64,
#   'Master of Orion 3': 64,
#   'Red Faction II': 64,
#   'Curse: The Eye of Isis': 63,
#   'AquaNox 2: Revelation': 59,
#   'POSTAL 2': 59,
#   'Highland Warriors': 58,
#   'Railroad Pioneer': 50,
#   "Rocko's Quest": 41},
#  2004: {'Half-Life 2': 96,
#   "Unreal Tournament 2004: Editor's Choice Edition": 93,
#   'Rome: Total War™ - Collection': 92,
#   'Far Cry®': 89,
#   'Counter-Strike: Source': 88,
#   'DOOM 3': 87,
#   'Call of Duty: United Offensive': 87,
#   'Thief: Deadly Shadows': 85,
#   'Silent Storm Gold Edition': 83,
#   'Prince of Persia: Warrior Within™': 83,
#   'Codename: Panzers, Phase One': 81,
#   'Kohan II: Kings of War': 81,
#   'Nancy Drew®: Curse of Blackmoor Manor': 81,
#   'Ground Control II: Operation Exodus': 80,
#   'Syberia II': 80,
#   'Full Spectrum Warrior': 80,
#   'Gish': 80,
#   'Vampire: The Masquerade - Bloodlines': 80,
#   'Deus Ex: Invisible War': 80,
#   'Perimeter': 77,
#   'Soldiers: Heroes of World War II': 77,
#   'Nexus - The Jupiter Incident': 77,
#   'Manhunt': 75,
#   'Port Royale 2': 75,
#   'Evil Genius': 75,
#   'Nemesis of the Roman Empire': 74,
#   'Beyond Divinity': 73,
#   'Warlords Battlecry III': 73,
#   'Men of Valor': 71,
#   'Neighbours from Hell Compilation': 69,
#   'Nancy Drew®: The Secret of Shadow Ranch': 68,
#   'Sherlock Holmes: The Silver Earring': 68,
#   'The Punisher': 67,
#   'Dark Fall 2: Lights Out': 66,
#   'Lords of the Realm III': 65,
#   'Counter-Strike: Condition Zero': 65,
#   'Echelon: Wind Warriors': 63,
#   'Aura: Fate of the Ages': 63,
#   'Shadow Ops: Red Mercury': 61,
#   'World War II: Panzer Claws': 61,
#   'Wars and Warriors: Joan of Arc': 60,
#   'Zoo Empire': 59,
#   'Marine Park Empire': 58,
#   'Fair Strike': 56,
#   'Marine Sharpshooter II: Jungle Warfare': 52,
#   'Konung 2': 35},
#  2005: {"Sid Meier's Civilization® IV": 94,
#   'Grand Theft Auto: San Andreas': 93,
#   "Tom Clancy's Splinter Cell Chaos Theory®": 92,
#   'Silent Hunter® III': 90,
#   'Guild Wars': 89,
#   'F.E.A.R.': 88,
#   "Sid Meier's Pirates!": 88,
#   'Brothers in Arms: Road to Hill 30™': 87,
#   'Psychonauts': 87,
#   'Call of Duty® 2': 86,
#   'STAR WARS™ Knights of the Old Republic™ II - The Sith Lords™': 85,
#   'Prince of Persia: The Two Thrones™': 85,
#   'Brothers in Arms: Earned in Blood™': 84,
#   'GT Legends': 84,
#   'Darwinia': 84,
#   'Act of War: Direct Action': 82,
#   'Quake IV': 81,
#   'FATE': 80,
#   'Codename: Panzers, Phase Two': 80,
#   'Nancy Drew®: Secret of the Old Clock': 80,
#   'Dungeon Siege II': 80,
#   'Star Wars: Battlefront 2 (Classic, 2005)': 78,
#   'STAR WARS™ Republic Commando™': 78,
#   'Crazy Machines': 78,
#   'Crazy Machines 1.5': 78,
#   'DOOM 3 Resurrection of Evil': 78,
#   'Knights of Honor': 77,
#   'Nancy Drew®: Last Train to Blue Moon Canyon': 77,
#   'Sniper Elite': 76,
#   'Project: Snowblind': 76,
#   'GUN™': 76,
#   'Still Life': 75,
#   'Serious Sam 2': 74,
#   'Cossacks II: Napoleonic Wars': 73,
#   'FlatOut': 72,
#   'X3: Reunion': 71,
#   'Advent Rising': 70,
#   "The Bard's Tale": 70,
#   'The Moment of Silence': 70,
#   'Imperial Glory': 69,
#   'Rag Doll Kung Fu': 69,
#   'Bone: Out From Boneville': 68,
#   'Shattered Union': 67,
#   'BloodRayne 2': 67,
#   'Cold Fear™': 66,
#   'Delta Force: Xtreme': 65,
#   'Cold War': 64,
#   'Space Hack': 63,
#   'Obscure': 63,
#   'EMERGENCY 3': 58,
#   'The Settlers®: Heritage of Kings': 58,
#   'Saw': 55,
#   'Judge Dredd: Dredd vs. Death': 55},
#  2006: {'Company of Heroes - Legacy Edition': 93,
#   'Medieval II: Total War™': 88,
#   'Warhammer® 40,000: Dawn of War® - Dark Crusade': 87,
#   'Half-Life 2: Episode One': 87,
#   'Warhammer® 40,000: Dawn of War® - Game of the Year Edition': 86,
#   'IL-2 Sturmovik: 1946': 86,
#   "Tom Clancy's Rainbow Six® Vegas": 85,
#   "Disciples II: Gallean's Return": 84,
#   'DEFCON': 84,
#   'Civilization IV®: Warlords': 84,
#   'Guild Wars Nightfall': 84,
#   'Guild Wars Factions': 84,
#   'Hearts of Iron 2 Complete': 83,
#   'Tomb Raider: Legend': 82,
#   'Hitman: Blood Money': 82,
#   'Dangerous Waters': 82,
#   'Xpand Rally': 82,
#   'RollerCoaster Tycoon® 3: Platinum': 81,
#   'Red Orchestra: Ostfront 41-45': 81,
#   'Disciples II: Rise of the Elves': 80,
#   "Tom Clancy's Splinter Cell Double Agent®": 80,
#   'RoboBlitz': 80,
#   'Rome: Total War™ - Alexander': 79,
#   'Space Empires IV Deluxe': 79,
#   'Condemned: Criminal Origins': 78,
#   "Sid Meier's Railroads!": 77,
#   "Al Emmo and the Lost Dutchman's Mine": 77,
#   'Heroes of Might & Magic V': 77,
#   'The Ship: Murder Party': 76,
#   'FlatOut 2™': 76,
#   'Bone: The Great Cow Race': 76,
#   'Call of Cthulhu®: Dark Corners of the Earth': 76,
#   'Dreamfall: The Longest Journey': 75,
#   'Just Cause': 75,
#   'SiN Episodes: Emergence': 75,
#   'Uplink': 75,
#   'Act of War: High Treason': 74,
#   'Caesar™ IV': 74,
#   'Sacred Gold': 74,
#   'Shadowgrounds': 74,
#   'Disney•Pixar Cars': 73,
#   'Earth 2160': 73,
#   "Perimeter: Emperor's Testament": 72,
#   'Dark Messiah of Might & Magic': 72,
#   'MX vs. ATV Unleashed': 71,
#   'Darkstar One': 71,
#   'Nancy Drew®: Danger by Design': 70,
#   'Full Spectrum Warrior: Ten Hammers': 70,
#   'Gumboy - Crazy Adventures™': 69,
#   "Marc Eckō's Getting Up: Contents Under Pressure": 69,
#   'Cossacks II: Battle for Europe': 69,
#   'Safecracker: The Ultimate Puzzle Adventure': 69,
#   'Rogue Trooper': 69,
#   'Nancy Drew®: The Creature of Kapu Cave': 68,
#   'Joint Task Force': 68,
#   'Space Empires V': 68,
#   'CivCity: Rome': 67,
#   'Tycoon City: New York': 67,
#   'Faces of War': 67,
#   'Pacific Storm': 67,
#   'Devil May Cry® 3 Special Edition': 66,
#   "Desperados 2: Cooper's Revenge": 66,
#   'Heroes of Might & Magic V: Hammers of Fate': 66,
#   'Heroes of Annihilated Empires': 65,
#   'Gothic® 3': 63,
#   'Wings Over Europe': 62,
#   'The Guild II': 61,
#   "Tom Clancy's Rainbow Six Lockdown™": 59,
#   'Iron Warriors: T - 72 Tank Command': 56,
#   'El Matador': 54,
#   'Battle Of Europe': 54,
#   'Elite Warriors: Vietnam': 46,
#   'Brigade E5: New Jagged Union': 41},
#  2007: {'BioShock™': 96,
#   'QUAKE': 94,
#   'The Elder Scrolls IV: Oblivion® Game of the Year Edition': 94,
#   'Team Fortress 2': 92,
#   'Call of Duty® 4: Modern Warfare®': 92,
#   'Crysis': 91,
#   'Portal': 90,
#   'Half-Life 2: Episode Two': 90,
#   'Supreme Commander': 86,
#   'Civilization IV: Beyond the Sword': 86,
#   'Command & Conquer 3: Tiberium Wars': 85,
#   'Medieval II: Total War™ Kingdoms': 85,
#   'PuzzleQuest: Challenge of the Warlords': 84,
#   'Tomb Raider: Anniversary': 83,
#   'Unreal Tournament 3 Black': 83,
#   'Europa Universalis III Complete': 83,
#   'Mr. Robot': 83,
#   'RACE 07': 83,
#   'Aquaria': 82,
#   'Sam & Max 201: Ice Station Santa': 82,
#   'S.T.A.L.K.E.R.: Shadow of Chernobyl': 82,
#   'Overlord™': 81,
#   'Jade Empire™: Special Edition': 81,
#   'Silent Hunter®: Wolves of the Pacific': 79,
#   'Nancy Drew®: Legend of the Crystal Skull': 79,
#   'Guild Wars: Eye of the North®': 79,
#   'Depths of Peril': 79,
#   'Shadowgrounds Survivor': 79,
#   'Medal of Honor: Airborne': 78,
#   'Geometry Wars: Retro Evolved': 76,
#   'Battlestations: Midway': 76,
#   'Eschalon: Book I': 75,
#   'ARMA: Combat Operations': 74,
#   'Penumbra Overture': 73,
#   'Nancy Drew®: The White Wolf of Icicle Creek': 73,
#   'Call of Juarez™': 72,
#   'TimeShift™': 71,
#   'UFO: Afterlight': 71,
#   'Heroes of Might & Magic V: Tribes of the East': 70,
#   'Thrillville®: Off the Rails™': 70,
#   'Making History: The Calm & the Storm': 70,
#   'Death to Spies': 69,
#   'Sinking Island': 68,
#   'Kane and Lynch: Dead Men™': 67,
#   'Lost Planet™: Extreme Condition': 66,
#   'Culpa Innata': 66,
#   'Theatre of War': 66,
#   'Painkiller Overdose': 65,
#   'The Guild II - Pirates of the European Seas': 63,
#   'Silverfall': 62,
#   'Vigil: Blood Bitterness™': 61,
#   'Bus Driver': 61,
#   'Driver® Parallel Lines': 61,
#   'Loki': 61,
#   'Pacific Storm Allies': 60,
#   'Alpha Prime': 59,
#   'Rayman Raving Rabbids™': 58,
#   'Maelstrom: The Battle for Earth Begins': 58,
#   'Genesis Rising': 57,
#   'Hard to Be a God': 55,
#   'Hospital Tycoon': 51},
#  2008: {'Fallout 3': 91,
#   'World of Goo': 90,
#   'Left 4 Dead': 89,
#   'Mass Effect': 89,
#   "The Witcher: Enhanced Edition Director's Cut": 86,
#   'Dead Space': 86,
#   'Bionic Commando: Rearmed': 86,
#   "Far Cry® 2: Fortune's Edition": 85,
#   'Sam & Max 204: Chariots of the Dogs': 85,
#   'AudioSurf': 85,
#   'Crysis Warhead®': 84,
#   'SPORE™': 84,
#   'GTR Evolution Expansion Pack for RACE 07': 83,
#   "Sid Meier's Civilization IV: Colonization": 83,
#   'Call of Duty: World at War': 83,
#   'Command & Conquer: Red Alert 3': 82,
#   'Prince of Persia®': 82,
#   "Strong Bad's Cool Game for Attractive People: Season 1": 82,
#   'Sam & Max: Season Two': 82,
#   'Defense Grid: The Awakening': 81,
#   'Dangerous High School Girls in Trouble!™': 81,
#   'LEGO Batman': 80,
#   'Tomb Raider: Underworld': 80,
#   'Trackmania United Forever Star Edition': 80,
#   'Sam & Max 202: Moai Better Blues': 80,
#   'FlatOut: Ultimate Carnage': 79,
#   "Brothers in Arms: Hell's Highway™": 79,
#   "King's Bounty: The Legend": 79,
#   'Europa Universalis: Rome - Gold Edition': 79,
#   "Assassin's Creed™: Director's Cut Edition": 79,
#   'Sam & Max 203: Night of the Raving Dead': 79,
#   'LEGO® Indiana Jones™: The Original Adventures': 78,
#   'Devil May Cry 4': 78,
#   'Bejeweled Twist': 78,
#   "Tom Clancy's Rainbow Six® Vegas 2": 78,
#   'Everyday Shooter': 77,
#   'Multiwinia': 76,
#   'Peggle™ Nights': 76,
#   'S.T.A.L.K.E.R.: Clear Sky': 75,
#   'A Vampyre Story': 75,
#   'Sword of the Stars: Complete Collection': 75,
#   'Children of the Nile: Enhanced Edition': 75,
#   'LUMINES™': 74,
#   'X3: Terran Conflict': 73,
#   'Frontlines™: Fuel of War™': 73,
#   'Bully: Scholarship Edition': 72,
#   'Sherlock Holmes: The Awakened - Remastered Edition': 72,
#   'Mount & Blade': 72,
#   'Crazy Machines 2': 72,
#   'Sherlock Holmes - Nemesis': 71,
#   'The Lost Crown': 71,
#   'Dracula Origin': 70,
#   'Overclocked: A History of Violence': 70,
#   'Nancy Drew®: The Phantom of Venice': 69,
#   'Jack Keane': 69,
#   'Nikopol: Secrets of the Immortals': 68,
#   'Rhiannon: Curse of the Four Branches': 67,
#   'The Club™': 67,
#   'The Settlers®: Rise Of An Empire Gold Edition': 66,
#   'Hinterland': 65,
#   'Supreme Ruler 2020 Gold': 65,
#   'Need for Speed Undercover': 65,
#   'Insecticide Part 1': 65,
#   'Silent Hill Homecoming': 64,
#   'Mata Hari': 63,
#   'Imperium Romanum Gold Edition': 63,
#   'Ubersoldier II': 62,
#   'Chronicles of Mystery: The Scorpio Ritual': 62,
#   'SAGA': 61,
#   'Sherlock Holmes: The Mystery of the Mummy': 61,
#   'Rise of the Argonauts': 59,
#   'Iron Grip: Warlord': 59,
#   'Obscure II (Obscure: The Aftermath)': 59,
#   'Conflict: Denied Ops': 58,
#   'Ninja Reflex: Steamworks Edition': 57,
#   'Legend - Hand of God': 57,
#   'Alone in the Dark': 55},
#  2009: {'The Elder Scrolls IV: Oblivion® Game of the Year Edition Deluxe': 94,
#   'Street Fighter® IV': 91,
#   'Dragon Age: Origins': 91,
#   'Fallout 3: Game of the Year Edition': 91,
#   'Braid': 90,
#   'Empire: Total War™': 90,
#   'Left 4 Dead 2': 89,
#   'Burnout Paradise: The Ultimate Box': 87,
#   'Plants vs. Zombies GOTY Edition': 87,
#   'The Secret of Monkey Island: Special Edition': 86,
#   'Call of Duty®: Modern Warfare® 2': 86,
#   'Europa Universalis III: Heir to the Throne': 86,
#   'The Sims™ 3': 86,
#   'Resident Evil™ 5/ Biohazard 5®': 86,
#   'Machinarium': 85,
#   'Warhammer 40,000: Dawn of War II': 85,
#   'Time Gentlemen, Please! and Ben There, Dan That! Special Edition  Double Pack': 84,
#   'Borderlands: The Zombie Island of Dr. Ned': 84,
#   'Need for Speed: Shift': 83,
#   'Torchlight': 83,
#   "King's Bounty: Armored Princess": 82,
#   'Red Faction Guerrilla Steam Edition': 82,
#   'Dawn of Discovery™': 82,
#   "Mirror's Edge™": 81,
#   'The Sims™ 3 World Adventures': 81,
#   'Age of Empires® III: Complete Collection': 81,
#   'Borderlands': 81,
#   'AaAaAA!!! - A Reckless Disregard for Gravity': 81,
#   'Nancy Drew®: The Haunting of Castle Malloy': 81,
#   'Osmos': 80,
#   'SpellForce 2 - Anniversary Edition': 80,
#   'AI War: Fleet Command': 80,
#   'Trine Enchanted Edition': 80,
#   'Men of War™': 80,
#   'F.E.A.R. 2: Project Origin': 79,
#   'Prototype™': 79,
#   'Tales of Monkey Island Complete Pack': 79,
#   'Altitude': 79,
#   'Tropico 3': 79,
#   'Madballs in Babo:Invasion': 79,
#   'Overlord II': 79,
#   'Crayon Physics Deluxe': 79,
#   'The Path': 79,
#   'Call of Juarez®: Bound in Blood': 78,
#   'Nancy Drew®: Ransom of the Seven Ships': 78,
#   'Wings of Prey': 78,
#   "Zuma's Revenge!": 78,
#   'Penumbra: Black Plague Gold Edition': 78,
#   'Zeno Clash': 77,
#   'Risen': 77,
#   'Men of War: Red Tide': 77,
#   'Nancy Drew® Dossier: Resorting to Danger!': 77,
#   'LEGO® Star Wars™ - The Complete Saga': 77,
#   "Command & Conquer 3: Kane's Wrath": 77,
#   'Hearts of Iron III': 77,
#   'Arma 2': 77,
#   'Rush for Berlin Gold': 76,
#   'Operation Flashpoint: Dragon Rising': 76,
#   'Drakensang': 75,
#   'The Maw': 75,
#   'And Yet It Moves': 75,
#   'Mini Ninjas': 74,
#   'SpellForce - Platinum Edition': 74,
#   'Battlestations Pacific': 74,
#   'Ceville': 73,
#   'Sherlock Holmes versus Jack the Ripper': 73,
#   'Death to Spies: Moment of Truth': 73,
#   'Cogs': 73,
#   'Saints Row 2': 72,
#   'Gratuitous Space Battles': 72,
#   'Roogoo': 72,
#   'Champions Online': 72,
#   'Majesty 2': 72,
#   'Killing Floor': 72,
#   'Puzzle Quest: Galactrix': 72,
#   'Grand Ages: Rome': 72,
#   'Gyromancer': 71,
#   'Emerald City Confidential™': 71,
#   'Elven Legacy': 71,
#   'SPORE™ Galactic Adventures': 70,
#   'Company of Heroes: Tales of Valor': 70,
#   'Bionic Commando': 69,
#   'Order of War™': 69,
#   'Blueberry Garden': 68,
#   'Serious Sam HD: The First Encounter': 68,
#   'Elven Legacy: Ranger': 68,
#   "Tom Clancy's EndWar™": 68,
#   'Still Life 2': 67,
#   'Quantz': 67,
#   'East India Company': 67,
#   'Light of Altair': 66,
#   'Dark Sector': 66,
#   'The Last Remnant™': 66,
#   'Two Worlds Epic Edition': 65,
#   'Helldorado': 65,
#   'STAR WARS™ - The Force Unleashed™ Ultimate Sith Edition': 65,
#   'Flock!': 65,
#   'Larva Mortus': 64,
#   'Secret Files 2: Puritas Cordis': 64,
#   'Restaurant Empire II': 64,
#   'East India Company: Privateer': 63,
#   'Theatre of War 2: Africa 1943': 63,
#   'NecroVision': 63,
#   'Watchmen: The End is Nigh': 61,
#   'Disney G-Force': 61,
#   'Venetica - Gold Edition': 61,
#   'Ninja Blade': 61,
#   'Velvet Assassin': 61,
#   'Lucidity™': 59,
#   'X-Blades': 54,
#   'Death Track®: Resurrection': 53,
#   'Clutch': 51,
#   'Darkest of Days': 51,
#   'Twin Sector': 49,
#   'STAR WARS™: The Clone Wars - Republic Heroes™': 46,
#   'Watchmen: The End is Nigh Part 2': 44,
#   'Perimeter 2: New Earth': 43,
#   'Damnation': 41,
#   'Painkiller: Resurrection': 38,
#   'Drug Wars': 35,
#   'Tunnel Rats': 30,
#   'Rogue Warrior': 29},
#  2010: {'Mass Effect 2': 94,
#   'Mass Effect 2 Digital Deluxe Edition': 94,
#   'Dragon Age: Origins - Ultimate Edition': 91,
#   'Batman: Arkham Asylum Game of the Year Edition': 91,
#   "Sid Meier's Civilization® V": 90,
#   'Grand Theft Auto IV: Complete Edition': 90,
#   'BioShock® 2': 88,
#   'Super Meat Boy': 87,
#   'Battlefield: Bad Company™ 2': 87,
#   "Age of Wonders II: The Wizard's Throne": 86,
#   'Need For Speed: Hot Pursuit': 86,
#   'Battlefield: Bad Company 2 Vietnam': 86,
#   'Borderlands: The Secret Armory of General Knoxx': 86,
#   "Assassin's Creed 2 Deluxe Edition": 86,
#   'Amnesia: The Dark Descent': 85,
#   'Warhammer® 40,000: Dawn of War® II Chaos Rising': 85,
#   'Fallout: New Vegas': 84,
#   'Just Cause 2': 84,
#   'Shatter': 84,
#   'Puzzle Quest 2': 83,
#   'Darksiders™': 83,
#   "Tom Clancy's Splinter Cell Conviction™ Deluxe Edition": 83,
#   "Recettear: An Item Shop's Tale": 82,
#   'Age of Wonders Shadow Magic': 82,
#   'Bejeweled® 3': 82,
#   'Lara Croft and the Guardian of Light': 82,
#   'Dragon Age™: Origins Awakening': 82,
#   'VVVVVV': 81,
#   'Call of Duty®: Black Ops': 81,
#   'Napoleon: Total War™': 81,
#   'Napoleon: Total War™ Imperial Edition': 81,
#   'Nimbus': 80,
#   'Day of Defeat: Source': 80,
#   'Toki Tori': 80,
#   'S.T.A.L.K.E.R.: Call of Pripyat': 80,
#   'The Misadventures of P.B. Winterbottom': 79,
#   'Worms Reloaded': 79,
#   'Split/Second': 79,
#   'Puzzle Dimension': 79,
#   'LEGO Harry Potter: Years 1-4': 79,
#   'Tropico 3: Absolute Power': 79,
#   'Mount & Blade: Warband': 78,
#   "King's Bounty: Crossworlds": 78,
#   'DeathSpank: Thongs of Virtue': 78,
#   'Dead Rising® 2': 78,
#   'Alien Swarm': 77,
#   'DeathSpank': 77,
#   'Lost Horizon': 77,
#   'Supreme Commander 2': 77,
#   'Plain Sight': 76,
#   'Star Trek Online': 76,
#   'Serious Sam HD: The Second Encounter': 76,
#   "Din's Curse": 76,
#   'Greed Corp': 76,
#   'Singularity™': 76,
#   'Nancy Drew®: Warnings at Waverly Academy': 76,
#   'Tidalis': 75,
#   'Victoria II': 75,
#   'Patrician III': 75,
#   'Prince of Persia: The Forgotten Sands™': 75,
#   'Dark Fall: Lost Souls': 75,
#   'Sol Survivor': 75,
#   'Back to the Future: The Game': 74,
#   'The Sims™ 3 Late Night': 74,
#   'The Sims™ 3 Ambitions': 74,
#   'RUSH': 73,
#   'Blood Bowl® Legendary Edition': 73,
#   'Bloody Good Time': 73,
#   'Arma 2: Operation Arrowhead': 73,
#   'Bob Came in Pieces': 73,
#   'Alpha Protocol™': 72,
#   'Burn Zombie Burn!': 72,
#   'Medal of Honor™': 72,
#   'Flotilla': 72,
#   "The Kings' Crusade": 71,
#   'Poker Night at the Inventory': 71,
#   'Jolly Rover': 71,
#   'Lead and Gold: Gangs of the Wild West': 70,
#   'Beat Hazard': 70,
#   'Lost Planet: Extreme Condition Colonies Edition': 70,
#   "nail'd": 69,
#   "Borderlands: Claptrap's Robot Revolution": 69,
#   'Avencast: Rise of the Mage': 68,
#   'UFO: Extraterrestrials Gold': 68,
#   'The Ball': 68,
#   'Commander: Conquest of the Americas': 68,
#   'Aliens vs. Predator™': 68,
#   'Galcon Fusion': 68,
#   'Fantasy Wars': 67,
#   'Shank': 67,
#   'The UnderGarden': 67,
#   'LEGO® Indiana Jones™ 2: The Adventure Continues': 66,
#   'Kane & Lynch 2: Dog Days': 66,
#   'Patrician IV - Steam Special Edition': 66,
#   'Armada 2526': 66,
#   'Grotesque Tactics: Evil Heroes': 65,
#   'Dragon Saga': 65,
#   'Hearts of Iron III: Semper Fi': 65,
#   'Blacklight: Tango Down': 65,
#   'Sonic & SEGA All-Stars Racing': 65,
#   'Alien Breed: Impact': 64,
#   'Alien Breed 3: Descent': 64,
#   'Command & Conquer 4: Tiberian Twilight': 64,
#   'Rocket Knight': 63,
#   'Alien Breed 2: Assault': 63,
#   'Lost Planet® 2': 63,
#   'Alternativa': 63,
#   '15 Days': 63,
#   'Disney Alice in Wonderland': 63,
#   'ArcaniA': 63,
#   'Front Mission Evolved': 63,
#   'Doc Clock: The Toasted Sandwich of Time': 62,
#   'Silent Hunter 5®: Battle of the Atlantic': 62,
#   'Razor2: Hidden Skies': 61,
#   'Rig n Roll': 61,
#   'Reign: Conflict of Nations': 60,
#   'STAR WARS™: The Force Unleashed™ II': 59,
#   'Alter Ego': 59,
#   'Hotel Giant 2': 58,
#   'Vancouver 2010™ - The Official Video Game of the Olympic Winter Games': 57,
#   'Disney TRON: Evolution': 57,
#   'Dark Void™': 57,
#   'Disciples III - Renaissance Steam Special Edition': 56,
#   'The Guild II Renaissance': 56,
#   'Sniper: Ghost Warrior': 55,
#   'M.U.D. TV': 53,
#   'Blade Kitten': 52,
#   'Ship Simulator Extremes': 49,
#   'Making History II: The War of the World': 38},
#  2011: {'Portal 2': 95,
#   'Galactic Civilizations® II: Ultimate Edition': 92,
#   'The Witcher 2: Assassins of Kings Enhanced Edition': 88,
#   'LIMBO': 88,
#   'Assassin’s Creed® Brotherhood': 88,
#   'Dead Space™ 2': 87,
#   'Bastion': 86,
#   'Frozen Synapse': 85,
#   'The Binding of Isaac': 84,
#   'Saints Row: The Third Initiation Station': 84,
#   'Saints Row: The Third': 84,
#   'SpaceChem': 84,
#   'Shift 2 Unleashed': 84,
#   'L.A. Noire': 83,
#   'Fable - The Lost Chapters': 83,
#   'EverQuest® II Free-To-Play. Your Way.™': 83,
#   'Orcs Must Die!': 83,
#   'F1 2011': 83,
#   'Universe Sandbox': 83,
#   'Terraria': 83,
#   'Monday Night Combat': 82,
#   'Gemini Rue': 82,
#   'Darkest Hour: A Hearts of Iron Game': 81,
#   'Supreme Commander: Forged Alliance': 81,
#   'To the Moon': 81,
#   'TrackMania² Canyon': 81,
#   'Rochard': 81,
#   'Dungeon Defenders': 81,
#   'Critical Mass': 81,
#   'Jamestown': 81,
#   'Anomaly: Warzone Earth': 80,
#   'Panzer Corps': 80,
#   'Capsized': 80,
#   'The Sims™ 3 Pets': 79,
#   'Bloodline Champions': 79,
#   'RAGE': 79,
#   'Dungeons of Dredmor': 79,
#   'Runaway: A Twist of Fate': 79,
#   'The Settlers 7: Paths to a Kingdom: Deluxe Gold Edition': 79,
#   'Revenge of the Titans': 79,
#   'Tropico 4': 78,
#   'Two Worlds II - Pirates of the Flying Fortress': 78,
#   'Cthulhu Saves the World': 78,
#   'NightSky': 78,
#   'Mafia II': 77,
#   'RISK™: Factions': 77,
#   "Hamilton's Great Adventure": 77,
#   'Magic: The Gathering - Duels of the Planeswalkers 2012': 77,
#   'Might & Magic: Heroes VI': 77,
#   'Sonic Generations Collection': 77,
#   'Section 8®: Prejudice™': 77,
#   'Men of War: Assault Squad': 77,
#   "Who's That Flying?!": 76,
#   'Two Worlds II HD': 76,
#   'Red Orchestra 2: Heroes of Stalingrad with Rising Storm': 76,
#   'Renegade Ops': 76,
#   'PAYDAY™ The Heist': 76,
#   'Might & Magic: Clash of Heroes': 76,
#   'From Dust': 76,
#   'LEGO® Star Wars™ III - The Clone Wars™': 76,
#   "Tobe's Vertical Adventure": 75,
#   'X3: Albion Prelude': 75,
#   'Black Mirror III': 75,
#   'Avadon: The Black Fortress': 75,
#   'Red Faction®: Armageddon™': 75,
#   'The Next BIG Thing': 75,
#   'Hector: Badge of Carnage - Full Series': 75,
#   'Atom Zombie Smasher': 75,
#   'F.E.A.R. 3': 74,
#   'EDGE': 74,
#   'Space Pirates and Zombies': 74,
#   'Warhammer 40,000: Space Marine': 74,
#   'Rock of Ages': 74,
#   'Fortix 2': 74,
#   'Magicka': 74,
#   'SkyDrift': 73,
#   'Disney•Pixar Toy Story 3: The Video Game': 73,
#   'Zeit²': 72,
#   'Test Drive Unlimited 2': 72,
#   'Dungeon Siege III': 72,
#   'Solar 2': 72,
#   'DC Universe™ Online': 72,
#   'Dungeons - The Dark Lord': 72,
#   'Blocks That Matter': 72,
#   'YOU DON’T KNOW JACK®': 71,
#   'Black Mirror II': 71,
#   'Fallen Earth Free2Play': 71,
#   'Sideway™ New York': 71,
#   'Nuclear Dawn': 71,
#   'Europa Universalis III: Divine Wind': 71,
#   'Homefront': 70,
#   'Fate of the World': 70,
#   'Sanctum': 70,
#   'The Sims™ 3 Generations': 70,
#   'Sengoku': 70,
#   'Fate of the World: Tipping Point': 70,
#   'Before the Echo': 70,
#   'Take On Helicopters': 70,
#   'Pride of Nations': 70,
#   'Vertex Dispenser': 70,
#   'BRINK': 70,
#   'Cities in Motion': 70,
#   'Kaptain Brawe: A Brawe New World': 69,
#   'Runespell: Overture': 69,
#   'Earth Defense Force: Insect Armageddon': 69,
#   'Lume': 69,
#   'Duels of the Planeswalkers Gold Deck Bundle': 69,
#   'A.R.E.S.: Extinction Agenda': 68,
#   'Men of War: Vietnam': 68,
#   'Mount & Blade: With Fire & Sword': 68,
#   'Patrician IV: Rise of a Dynasty': 67,
#   'Xotic': 67,
#   'Operation Flashpoint: Red River': 67,
#   'Dead Rising 2: Off the Record': 66,
#   'Lord of the Rings: War in the North': 66,
#   'Worms Ultimate Mayhem': 66,
#   'DUNGEONS - Steam Special Edition': 65,
#   'Air Conflicts: Secret Wars': 65,
#   'Hearts of Iron III Semper Fi: Dies Irae Götterdämmerung': 65,
#   'HOARD': 65,
#   'Spiral Knights': 64,
#   'Serious Sam: The Random Encounter': 64,
#   'Hydrophobia: Prophecy': 64,
#   'Puzzle Agent 2': 63,
#   'The Baconing': 63,
#   'Disciples III - Resurrection': 63,
#   'Supreme Ruler: Cold War': 63,
#   'The Tiny Bang Story': 63,
#   'Chantelise - A Tale of Two Sisters': 62,
#   'Trauma': 62,
#   'Hunted: The Demon’s Forge™': 61,
#   'IL-2 Sturmovik: Cliffs of Dover': 60,
#   'Off-Road Drive': 60,
#   'Ignite': 59,
#   'inMomentum': 59,
#   'Fallout New Vegas®: Lonesome Road™': 57,
#   'Airline Tycoon 2': 57,
#   'Naval Warfare': 57,
#   'Pirates of Black Cove': 56,
#   "Yar's Revenge": 56,
#   'Sniper: Ghost Warrior - Second Strike': 55,
#   'Steel Storm: Burning Retribution': 55,
#   'CreaVures': 55,
#   'Duke Nukem Forever': 54,
#   'King Arthur: Fallen Champions': 54,
#   'Achron': 54,
#   'Dino D-Day': 53,
#   'Call of Juarez®: The Cartel': 51,
#   'The Haunted: Hells Reach': 51,
#   'Trapped Dead': 50,
#   'Garshasp: The Monster Slayer': 49,
#   'Theatre of War 3: Korea': 49,
#   'APOX': 48,
#   'Post Apocalyptic Mayhem': 44,
#   'Ghostbusters: Sanctum of Slime Challenge Pack DLC': 43,
#   'Painkiller Redemption': 43,
#   'Global Ops: Commando Libya': 37,
#   'Shadow Harvest: Phantom Ops': 34,
#   'Postal III': 24},
#  2012: {'Batman: Arkham City - Game of the Year Edition': 91,
#   'Mark of the Ninja': 91,
#   'Dishonored': 91,
#   'XCOM: Enemy Unknown': 89,
#   'Borderlands 2': 89,
#   'Far Cry 3': 88,
#   'Super Hexagon': 88,
#   'Torchlight II': 88,
#   'Thirty Flights of Loving': 88,
#   'Max Payne 3': 87,
#   'Rayman® Origins': 86,
#   'Total War: Shogun 2 - Fall of the Samurai': 86,
#   'The Lord of the Rings Online™': 86,
#   'Tribes: Ascend': 86,
#   'Hotline Miami': 85,
#   'DARK SOULS™: Prepare To Die™ Edition': 85,
#   'Unity of Command: Stalingrad Campaign': 84,
#   'PlanetSide 2': 84,
#   'FTL: Faster Than Light': 84,
#   'Alan Wake': 83,
#   'Counter-Strike: Global Offensive': 83,
#   'Galactic Civilizations® I: Ultimate Edition': 83,
#   'Tales From Space: Mutant Blobs Attack': 83,
#   'Orcs Must Die! 2': 83,
#   'Mount & Blade: Warband - Napoleonic Wars': 83,
#   'Crusader Kings II': 82,
#   'Realm of the Mad God': 82,
#   'The Book of Unwritten Tales': 82,
#   'Sins of a Solar Empire®: Rebellion': 82,
#   'Botanicula': 82,
#   'The Walking Dead': 82,
#   'Legend of Grimrock': 82,
#   'PixelJunk™ Eden': 81,
#   'Vessel': 81,
#   'Wizorb': 81,
#   'Waveform': 81,
#   'The Cat Lady': 81,
#   "Lone Survivor: The Director's Cut": 81,
#   'Wargame: European Escalation': 81,
#   'Kingdoms of Amalur: Reckoning™': 81,
#   'Stacking': 80,
#   'Myst V': 80,
#   'Intrusion 2': 80,
#   "Fly'N": 80,
#   'Stealth Bastard Deluxe': 80,
#   'LEGO The Lord of the Rings': 80,
#   'Assassin’s Creed® III': 80,
#   'Natural Selection 2': 80,
#   'F1 2012™': 80,
#   'Noitu Love 2: Devolution': 80,
#   'The Blackwell Legacy': 80,
#   'LEGO Harry Potter: Years 5-7': 80,
#   'Waking Mars': 79,
#   'Hitman: Absolution™': 79,
#   'Chivalry: Medieval Warfare': 79,
#   'Street Fighter X Tekken': 79,
#   'Offspring Fling!': 79,
#   'Dustforce DX': 79,
#   'Tropico 4: Modern Times': 78,
#   'Closure': 78,
#   'Rocksmith™': 78,
#   'Chaos on Deponia': 78,
#   'Deadlight': 78,
#   'Awesomenauts - the 2D moba': 78,
#   'Quantum Conundrum': 77,
#   'Giana Sisters: Twisted Dreams': 77,
#   'Sine Mora': 77,
#   'Thomas Was Alone': 77,
#   'Endless Space® - Collection': 77,
#   'Magic: The Gathering - Duels of the Planeswalkers 2013': 77,
#   'The Darkness II': 77,
#   'Victoria II: A House Divided': 76,
#   'Ys Origin': 76,
#   'Vindictus': 76,
#   'Miasmata': 76,
#   'Haunted': 76,
#   'McPixel': 76,
#   'Resonance': 76,
#   'Prototype 2': 76,
#   'Spec Ops: The Line': 76,
#   'Avernum: Escape From the Pit': 76,
#   'Insanely Twisted Shadow Planet': 76,
#   'Super MNC': 76,
#   'The Dark Eye: Chains of Satinav': 75,
#   'Hero Academy': 75,
#   'Iron Brigade': 75,
#   "Edna & Harvey: Harvey's New Eyes": 75,
#   'Dishonored: Dunwall City Trials': 75,
#   'Scribblenauts Unlimited': 75,
#   'Half Minute Hero: Super Mega Neo Climax Ultimate Boy': 75,
#   'Symphony': 75,
#   'Blacklight: Retribution': 75,
#   "Tiny and Big: Grandpa's Leftovers": 75,
#   'The Dream Machine: Chapter 1 & 2': 75,
#   'Stronghold Kingdoms': 75,
#   'Cubemen': 74,
#   'Rocketbirds: Hardboiled Chicken': 74,
#   'Call of Duty®: Black Ops II': 74,
#   'Drox Operative': 74,
#   "King's Bounty: Warriors of the North": 74,
#   'They Bleed Pixels': 74,
#   'Snapshot': 74,
#   'Deponia': 74,
#   'Unmechanical': 74,
#   'Stellar Impact': 74,
#   'Hard Reset Extended Edition': 73,
#   'Ys: The Oath in Felghana': 73,
#   'MDK2 HD': 73,
#   'The Testament of Sherlock Holmes': 73,
#   'The Book of Unwritten Tales: The Critter Chronicles': 73,
#   'Worms Revolution': 73,
#   "Alan Wake's American Nightmare": 73,
#   "MacGuffin's Curse": 73,
#   'Blackwell Deception': 73,
#   'Unstoppable Gorg': 73,
#   'Crusader Kings Complete': 73,
#   'Ridge Racer™ Unbounded': 72,
#   'Primordia': 72,
#   'A New Beginning - Final Cut': 72,
#   'Gateways': 72,
#   'Shank 2': 72,
#   'Toy Soldiers': 71,
#   "Tom Clancy's Ghost Recon: Future Soldier™": 71,
#   'Warlock - Master of the Arcane': 71,
#   'Splice': 70,
#   'Evochron Mercenary': 70,
#   'Risen 2: Dark Waters': 69,
#   'Gratuitous Tank Battles': 69,
#   'Of Orcs And Men': 69,
#   'Home': 69,
#   'Check vs Mate': 69,
#   'Binary Domain': 68,
#   'Little Inferno': 68,
#   "Shad'O": 68,
#   'Oil Rush': 67,
#   'Primal Carnage': 67,
#   'Secret Files 3': 67,
#   'King Arthur II: The Role-Playing Wargame': 66,
#   'Memento Mori': 66,
#   'Sniper Elite V2 - The Neudorf Outpost Pack': 66,
#   'I Am Alive': 66,
#   'Sniper Elite V2': 66,
#   'A Virus Named TOM': 65,
#   'Sword of the Stars II: Enhanced Edition': 65,
#   'Choplifter HD': 65,
#   'Guns of Icarus Online': 64,
#   'Inquisitor': 64,
#   'Painkiller Hell & Damnation': 64,
#   'Hell Yeah! Wrath of the Dead Rabbit': 64,
#   'Naval War: Arctic Circle': 64,
#   'Pid': 63,
#   'Jagged Alliance: Crossfire': 63,
#   'Blades of Time': 63,
#   'Jagged Alliance - Back in Action': 62,
#   'Pineapple Smash Crew': 62,
#   'Analogue: A Hate Story': 62,
#   'F1 RACE STARS™': 62,
#   'Dream Pinball 3D': 61,
#   'A Game of Dwarves': 60,
#   'Rigonauts': 60,
#   'Lucius': 59,
#   'Tower Wars': 59,
#   'Fireburst': 59,
#   'Defenders of Ardania': 58,
#   'Gas Guzzlers: Combat Carnage': 58,
#   'Game of Thrones': 58,
#   'Tiny Troopers': 57,
#   'Men of War: Condemned Heroes': 57,
#   'SOL: Exodus': 57,
#   'SpellForce 2: Faith in Destiny': 55,
#   'Iron Front: Digital War Edition': 55,
#   'Nexuiz': 54,
#   'Sonic the Hedgehog 4 - Episode II': 54,
#   'A Valley Without Wind': 54,
#   'Gemini Wars': 53,
#   'Krater': 52,
#   'Miner Wars 2081': 52,
#   'Confrontation': 51,
#   'Tryst': 50,
#   'Cannon Fodder 3': 49,
#   'Resident Evil: Operation Raccoon City': 48,
#   'Karateka': 48,
#   'Starpoint Gemini': 46,
#   'Cortex Command': 44,
#   'Clan of Champions': 42,
#   'Deep Black: Reloaded': 39,
#   'Painkiller: Recurring Evil': 38,
#   'Fray: Reloaded Edition': 27},
#  2013: {'BioShock Infinite': 94,
#   "Deus Ex: Human Revolution - Director's Cut": 91,
#   'FEZ': 91,
#   'Brothers - A Tale of Two Sons': 90,
#   'Spelunky': 90,
#   'Borderlands 2: Headhunter 1: Bloody Harvest': 89,
#   'Rayman® Legends': 89,
#   'Expansion - Crusader Kings II: The Old Gods': 88,
#   'The Stanley Parable': 88,
#   'Guacamelee! Gold Edition': 88,
#   "Borderlands 2: Tiny Tina's Assault on Dragon Keep": 87,
#   'Europa Universalis IV': 87,
#   'The Swapper': 87,
#   'Saints Row IV: Inauguration Station': 86,
#   'XCOM: Enemy Within': 86,
#   'Gone Home': 86,
#   'Saints Row IV': 86,
#   'Tomb Raider': 86,
#   'DmC: Devil May Cry': 85,
#   'Trials Evolution: Gold Edition': 85,
#   'The Wolf Among Us': 85,
#   'Papers, Please': 85,
#   'Rogue Legacy': 85,
#   'BIT.TRIP Presents... Runner2: Future Legend of Rhythm Alien': 85,
#   'RIFT': 84,
#   'Trine 2: Complete Story': 84,
#   'Giana Sisters: Twisted Dreams - Rise of the Owlverlord': 84,
#   'FINAL FANTASY XIV Online Free Trial': 83,
#   'FINAL FANTASY XIV Online Starter Edition': 83,
#   'Stick it to The Man!': 83,
#   'Valdis Story: Abyssal City': 83,
#   'Skullgirls': 83,
#   'Gunpoint': 83,
#   "Monaco: What's Yours Is Mine": 83,
#   'Starseed Pilgrim': 83,
#   'Desktop Dungeons': 82,
#   'Avadon 2: The Corruption': 82,
#   'Dominions 3: The Awakening': 82,
#   'Joe Danger 2: The Movie': 82,
#   'Rising Storm Game of the Year Edition': 82,
#   'Antichamber': 82,
#   "King Arthur's Gold": 81,
#   'Far Cry 3 - Blood Dragon': 81,
#   'Kentucky Route Zero': 81,
#   'Expansion - Crusader Kings II: The Republic': 81,
#   'Company of Heroes 2': 80,
#   'Dishonored: The Brigmore Witches': 80,
#   'Outlast': 80,
#   '140': 80,
#   'Goodbye Deponia': 80,
#   'NARUTO SHIPPUDEN: Ultimate Ninja STORM 3 Full Burst HD': 80,
#   'Wargame: Airland Battle': 80,
#   'Fallen Enchantress: Legendary Heroes': 80,
#   'GRID 2': 80,
#   'Dyad': 80,
#   'La-Mulana': 80,
#   'Brutal Legend': 80,
#   'Proteus': 80,
#   'Super House of Dead Ninjas': 79,
#   'Sang-Froid - Tales of Werewolves': 79,
#   'TrackMania² Valley': 79,
#   'State of Decay': 79,
#   'Memoria': 79,
#   'Call of Juarez® Gunslinger': 79,
#   'Weird Worlds: Return to Infinite Space': 79,
#   'Sonic & All-Stars Racing Transformed': 79,
#   'Euro Truck Simulator 2': 79,
#   'The Walking Dead: 400 Days': 78,
#   'Soundodger+': 78,
#   'Samurai Gunn': 78,
#   "Baldur's Gate II: Enhanced Edition": 78,
#   'LEGO® Marvel™ Super Heroes': 78,
#   'Teleglitch: Die More Edition': 78,
#   "Baldur's Gate: Enhanced Edition": 78,
#   'Ace Combat Assault Horizon - Enhanced Edition': 77,
#   'Sanctum 2': 77,
#   'Resident Evil Revelations / Biohazard Revelations': 77,
#   'Rise of Flight: Ace Pack': 77,
#   'Angry Video Game Nerd Adventures': 77,
#   'Risk of Rain': 77,
#   'Expansion - Crusader Kings II: Sons of Abraham': 77,
#   'Teslagrad': 77,
#   'Eldritch': 77,
#   'Rise of Flight: Battle of Saint-Mihiel': 77,
#   'Rise of Flight: Birth of Warbirds': 77,
#   'Rise of Flight: Bloody April': 77,
#   'Rise of Flight: Ultimately the Best Fighter': 77,
#   'Rise of Flight: Furious Wings': 77,
#   'Rise of Flight United': 77,
#   'Rise of Flight: Legendary Bombers': 77,
#   'TrackMania² Stadium': 77,
#   'Expeditions: Conquistador': 77,
#   'Element4l': 77,
#   'Anomaly 2': 77,
#   'Shadowrun Returns': 76,
#   'SteamWorld Dig': 76,
#   'Fester Mudd: Curse of the Gold - Episode 1': 76,
#   'Syder Arcade': 76,
#   'Volgarr the Viking': 76,
#   'Total War™: ROME II - Emperor Edition': 76,
#   'Kairo': 76,
#   'ShootMania Storm': 76,
#   'Anodyne': 75,
#   'Poker Night 2': 75,
#   'Reus': 75,
#   'Beatbuddy: Tale of the Guardians': 75,
#   'Ring Runner: Flight of the Sages': 75,
#   'Nihilumbra': 75,
#   'The Night of the Rabbit': 75,
#   'Cubetractor': 75,
#   'Anna - Extended Edition': 75,
#   'Star Conflict': 75,
#   'Incredipede': 74,
#   'Eador. Masters of the Broken World': 74,
#   'BIT.TRIP FATE': 74,
#   'The Raven - Legacy of a Master Thief': 74,
#   'Neverwinter': 74,
#   'Batman™: Arkham Origins': 74,
#   'Arma 3': 74,
#   'The Bridge': 74,
#   'Fieldrunners 2': 73,
#   'CastleStorm': 73,
#   'Worms Clan Wars': 73,
#   'MirrorMoon EP': 73,
#   'PixelJunk™ Shooter': 73,
#   'Paper Sorcerer': 73,
#   'Driftmoon': 73,
#   'Gas Guzzlers Extreme': 73,
#   'Shadow Warrior': 73,
#   'Divekick': 73,
#   'Guncraft': 73,
#   'Super Splatters': 73,
#   'Fist Puncher': 73,
#   'Dungeon Hearts': 73,
#   'Skulls of the Shogun': 72,
#   'PixelJunk™ Monsters Ultimate': 72,
#   'Tetrobot and Co.': 72,
#   'The Inner World': 72,
#   'Amnesia: A Machine for Pigs': 72,
#   'Aarklash: Legacy': 72,
#   'Hammerwatch': 72,
#   'The Incredible Adventures of Van Helsing': 72,
#   'Cities in Motion 2': 72,
#   'The Journey Down: Chapter One': 72,
#   'March of the Eagles': 71,
#   'Surgeon Simulator': 71,
#   'Lilly Looking Through': 71,
#   'Battle Worlds: Kronos': 71,
#   'Bionic Dues': 71,
#   'Retrovirus': 70,
#   'Papo & Yo': 70,
#   'ENSLAVED™: Odyssey to the West™ Premium Edition': 70,
#   'Democracy 3': 70,
#   'Resident Evil 6 / Biohazard 6': 69,
#   'BioShock Infinite: Clash in the Clouds': 69,
#   'Shelter': 69,
#   'Ironclad Tactics': 69,
#   'Foul Play': 69,
#   'Chivalry: Deadliest Warrior': 69,
#   'Megabyte Punch': 69,
#   'Thunder Wolves': 69,
#   'Warframe': 69,
#   'The Cave': 68,
#   'A Valley Without Wind 2': 68,
#   'Cubemen 2': 68,
#   'Game Dev Tycoon': 68,
#   'Scribblenauts Unmasked: A DC Comics Adventure': 68,
#   'Space Rangers HD: A War Apart': 68,
#   'Rain Blood Chronicles: Mirage': 68,
#   'Pandora: First Contact': 68,
#   'Age of Empires II HD': 68,
#   'Ittle Dew': 67,
#   'Rise of the Triad': 67,
#   'Cloudberry Kingdom™': 67,
#   'A Walk in the Dark': 67,
#   'Long Live The Queen': 67,
#   'Dungeonland': 67,
#   'The Showdown Effect': 67,
#   'The Banner Saga: Factions': 67,
#   '10,000,000': 67,
#   'Strike Suit Zero': 66,
#   'DuckTales: Remastered': 66,
#   'Alone in the Dark: The New Nightmare': 66,
#   'Oozi: Earth Adventure': 66,
#   'The Yawhg': 66,
#   'The Novelist': 66,
#   'Final Exam': 66,
#   'Rise of Venice': 66,
#   'The Bureau: XCOM Declassified': 66,
#   'Strike Suit Infinity': 66,
#   'Armada 2526 Gold Edition': 66,
#   'Remember Me': 65,
#   'Slender: The Arrival': 65,
#   'Journey of a Roach': 65,
#   'Skyward Collapse': 64,
#   "Dragon's Prophet": 63,
#   'Sir, You Are Being Hunted': 63,
#   'Total War: ROME II - Caesar in Gaul Campaign Pack': 63,
#   'Defense Technica': 63,
#   'Storm': 63,
#   'Contagion': 62,
#   'Redshirt': 62,
#   'Contrast': 62,
#   'Sniper Elite: Nazi Zombie Army': 62,
#   "Bientôt l'été": 62,
#   'Evoland': 61,
#   'StarDrive': 61,
#   'Signal Ops': 61,
#   'Oknytt': 61,
#   'Violett Remastered': 61,
#   'Sacred Citadel': 61,
#   'How to Survive': 60,
#   'Mars: War Logs': 59,
#   'Face Noir': 59,
#   'Master Reboot': 59,
#   "Deadly Premonition: The Director's Cut": 59,
#   'Shattered Haven': 59,
#   'God Mode': 58,
#   'Prime World: Defenders': 58,
#   'Space Hulk': 58,
#   'Urban Trial Freestyle': 58,
#   'Two Brothers': 57,
#   'Knock-knock': 57,
#   'Guardians of Middle-earth': 56,
#   'Darkout': 55,
#   'Speedball 2 HD': 53,
#   'Deadfall Adventures': 53,
#   'Sniper Elite: Nazi Zombie Army 2': 53,
#   'Lords of Football': 52,
#   'Alien Rage - Unlimited': 52,
#   'Sniper: Ghost Warrior 2': 52,
#   'Gomo': 50,
#   'Bad Bots': 49,
#   'Adventure Park': 49,
#   'Arma Tactics': 47,
#   'Tactical Intervention': 47,
#   'Hexodius': 47,
#   'Impire': 45,
#   'Air Conflicts: Vietnam': 43,
#   'DARK': 41,
#   'The Chaos Engine': 40,
#   "Montague's Mount": 39,
#   'Dementium II HD': 37,
#   'X Rebirth': 33,
#   'Citadels': 20},
#  2014: {'Freespace 2': 91,
#   'DARK SOULS™ II': 91,
#   'Rise of Nations: Extended Edition': 89,
#   'Descent 3': 89,
#   'TowerFall Ascension': 87,
#   'Divinity: Original Sin (Classic)': 87,
#   "Wasteland 2: Director's Cut": 87,
#   "Shadowrun: Dragonfall - Director's Cut": 87,
#   'Year Walk': 87,
#   'Astebreed: Definitive Edition': 86,
#   'BattleBlock Theater®': 85,
#   'The Legend of Heroes: Trails in the Sky': 85,
#   'The Talos Principle': 85,
#   'Medieval II: Total War Kingdoms': 85,
#   'Shovel Knight: Treasure Trove': 85,
#   'Crimzon Clover WORLD IGNITION': 85,
#   'Ikaruga': 84,
#   'Expansion - Europa Universalis IV: Wealth of Nations': 84,
#   'Middle-earth: Shadow of Mordor - GOTY Edition Upgrade': 84,
#   'Ultimate General: Gettysburg': 84,
#   'Freedom Planet': 83,
#   'Frozen Synapse Prime': 83,
#   'This War of Mine': 83,
#   'Door Kickers': 83,
#   'Outland': 83,
#   'Terrian Saga: KR-17': 83,
#   'The Floor is Jelly': 83,
#   'ibb & obb': 83,
#   'Transistor': 83,
#   'FINAL FANTASY XIV Online': 83,
#   'METAL GEAR RISING: REVENGEANCE': 83,
#   'Sokobond': 82,
#   'Endless Legend™': 82,
#   'Age of Wonders III - Golden Realms Expansion': 82,
#   'WildStar': 82,
#   "The Vanishing of Ethan Carter - Collector's Edition Upgrade": 82,
#   'The Vanishing of Ethan Carter': 82,
#   'Lethal League': 82,
#   'Ether One': 82,
#   'Nidhogg': 81,
#   'DG2: Defense Grid 2': 81,
#   'Company of Heroes 2 - Ardennes Assault': 81,
#   "Sid Meier's Civilization®: Beyond Earth™": 81,
#   'Alien: Isolation': 81,
#   'Distant Worlds: Universe': 81,
#   'Wolfenstein: The New Order': 81,
#   'Expansion - Europa Universalis IV: Conquest of Paradise': 81,
#   'LUFTRAUSERS': 80,
#   'BioShock Infinite: Burial at Sea - Episode Two': 80,
#   'Company of Heroes 2 - The Western Front Armies': 80,
#   'Guacamelee! Super Turbo Championship Edition': 80,
#   'Super Time Force Ultra': 80,
#   'Far Cry® 4': 80,
#   'METAL GEAR SOLID V: GROUND ZEROES': 80,
#   'Icewind Dale: Enhanced Edition': 80,
#   'Expansion - Crusader Kings II: Charlemagne': 80,
#   '1001 Spikes': 80,
#   'Trials Fusion™': 80,
#   'Expansion - Crusader Kings II: Rajas of India': 80,
#   'The Banner Saga': 80,
#   'Half Minute Hero: The Second Coming': 79,
#   'Expansion - Europa Universalis IV: Res Publica': 79,
#   'Dungeon of the Endless™': 79,
#   "The Last Door - Collector's Edition": 79,
#   'resident evil 4 / biohazard 4': 79,
#   'GRID Autosport - Coupé Style Pack': 78,
#   'The Journey Down: Chapter Two': 78,
#   "Joe Dever's Lone Wolf HD Remastered": 78,
#   'LISA': 78,
#   'Call of Duty®: Advanced Warfare - Gold Edition': 78,
#   'DeadCore': 78,
#   'Battle Academy 2: Eastern Front': 78,
#   "Five Nights at Freddy's": 78,
#   'OlliOlli': 78,
#   'So Many Me': 78,
#   'GRID Autosport': 78,
#   'Wargame: Red Dragon': 78,
#   'STRIDER™ / ストライダー飛竜®': 78,
#   'rymdkapsel': 77,
#   'Actual Sunlight': 77,
#   'Xenonauts': 77,
#   'Sherlock Holmes: Crimes and Punishments': 77,
#   'The Detail': 77,
#   'The Incredible Adventures of Van Helsing II': 77,
#   'Watch_Dogs™': 77,
#   'Child of Light': 77,
#   'NEO Scavenger': 77,
#   'Mercenary Kings': 76,
#   'The Fall': 76,
#   'MotoGP™14': 76,
#   'Metro: Last Light Redux': 76,
#   'GoD Factory: Wingmen': 76,
#   'WAKFU': 76,
#   'Chariot': 76,
#   'Fight The Dragon': 76,
#   'Escape Goat 2': 76,
#   'Tower of Guns': 76,
#   'Tropico 5': 75,
#   'Road Not Taken': 75,
#   'Roundabout': 75,
#   'Ziggurat': 75,
#   'Borderlands: The Pre-Sequel': 75,
#   'Fenix Rage': 75,
#   'The Samaritan Paradox': 75,
#   'FRACT OSC': 75,
#   'Infested Planet': 75,
#   "Jazzpunk: Director's Cut": 75,
#   'Particulars': 74,
#   'Insurgency': 74,
#   'Our Darker Purpose': 74,
#   'Where is my Heart?': 74,
#   'Shadows: Heretic Kingdoms': 74,
#   'Gabriel Knight: Sins of the Fathers 20th Anniversary Edition': 74,
#   'TRI: Of Friendship and Madness': 74,
#   'The Room': 73,
#   'Pier Solar and the Great Architects': 73,
#   "Letter Quest: Grimm's Journey": 73,
#   'LARA CROFT AND THE TEMPLE OF OSIRIS™': 73,
#   'Lords Of The Fallen™': 73,
#   "Hack 'n' Slash": 73,
#   "King's Bounty: Dark Side": 73,
#   'Space Run': 73,
#   'A Story About My Uncle': 73,
#   'Always Sometimes Monsters': 73,
#   'Warlock 2: The Exiled': 73,
#   'Strike Vector': 73,
#   'Broken Age': 73,
#   'Cloudbuilt': 72,
#   'Full Bore': 72,
#   'Blade Symphony': 72,
#   'The Last Tinker™: City of Colors': 72,
#   'Qbeh-1: The Atlas Cube': 72,
#   'MouseCraft': 72,
#   'Heavy Bullets': 72,
#   'Space Hulk Ascension': 72,
#   'Qvadriga': 72,
#   'The Last Federation': 72,
#   'Gray Matter': 72,
#   '10 Second Ninja': 72,
#   'Loadout': 72,
#   'Styx: Master of Shadows': 71,
#   'Screencheat': 71,
#   'The Crew™': 71,
#   'Lords of Xulima': 71,
#   'FOTONICA': 71,
#   'J.U.L.I.A.: Among the Stars': 71,
#   'To End All Wars': 71,
#   'DYNASTY WARRIORS 8: Xtreme Legends Complete Edition / 真・三國無双７ with 猛将伝': 71,
#   'Halo: Spartan Assault': 70,
#   'Nostradamus: The Last Prophecy': 70,
#   'Anomaly Defenders': 70,
#   'Richard & Alice': 70,
#   'Vertical Drop Heroes HD': 70,
#   'Crowntakers': 70,
#   'Vertical Drop Heroes HD Demo': 70,
#   'Dead State: Reanimated': 70,
#   'Lumino City': 70,
#   'Poltergeist: A Pixelated Horror': 70,
#   'Starpoint Gemini 2': 70,
#   'Bravada': 70,
#   'Ionball 2: Ionstorm': 70,
#   'Thief': 70,
#   'Might & Magic X - Legacy': 70,
#   'Octodad: Dadliest Catch': 69,
#   'Lichdom: Battlemage': 69,
#   'Minimum': 69,
#   'Toybox Turbos': 69,
#   'Basketball Pro Management 2015': 69,
#   'The Marvellous Miss Take': 69,
#   'Abyss Odyssey': 69,
#   'Panzer Tactics HD': 69,
#   'Men of War: Assault Squad 2': 68,
#   'Munin': 68,
#   'Shadowgate (2014)': 68,
#   'Costume Quest 2': 68,
#   'The Evil Within': 68,
#   'The Witcher Adventure Game': 68,
#   'Metrocide': 68,
#   'Warhammer 40,000: Armageddon': 68,
#   'Rollers of the Realm': 68,
#   'Kromaia': 68,
#   'A Golden Wake': 68,
#   'Neverending Nightmares': 68,
#   'SPACECOM': 68,
#   'Runers': 68,
#   'Hatoful Boyfriend': 68,
#   'Pure Pool': 68,
#   'UnEpic': 68,
#   'Crimsonland': 68,
#   'FINAL FANTASY III': 68,
#   'Tesla Effect: A Tex Murphy Adventure': 68,
#   'Call of Duty®: Ghosts': 68,
#   'Blackguards': 68,
#   'Eschalon: Book III': 67,
#   'Dracula: The Resurrection': 67,
#   'Train Fever': 67,
#   'SPINTIRES™': 67,
#   'Platformines': 67,
#   'CONSORTIUM': 66,
#   'NaissanceE': 66,
#   'Silence of the Sleep': 66,
#   'BlazeRush': 66,
#   'A Bird Story': 66,
#   'Battleplan: American Civil War': 66,
#   'Concursion': 66,
#   'Flockers™': 66,
#   '99 Levels To Hell': 66,
#   'Drunken Robot Pornography': 66,
#   'Blood of the Werewolf': 65,
#   'Stronghold Crusader 2': 65,
#   'JUJU': 65,
#   'Depth': 65,
#   'Risen 3 - Titan Lords': 65,
#   'Unrest': 65,
#   'Memento Mori 2': 65,
#   'Farming Simulator 15': 64,
#   'Eidolon': 64,
#   'Gods Will Be Watching': 64,
#   'Whispering Willows': 64,
#   'Defiance': 64,
#   'The Impossible Game': 64,
#   'Rulers of Nations': 63,
#   'Qora': 63,
#   'Sneaky Sneaky': 63,
#   'Vertiginous Golf': 63,
#   'Quest for Infamy': 63,
#   'Dominique Pamplemousse': 62,
#   'Warface': 62,
#   'The Old City: Leviathan': 62,
#   "Five Nights at Freddy's 2": 62,
#   "Buzz Aldrin's Space Program Manager": 62,
# ...
#   'Hyper Light Drifter': 84,
#   'Salt and Sanctuary': 84,
#   'ICEY': 84,
#   'Planet Coaster': 84,
#   'FINAL FANTASY IX': 84,
#   'Enter the Gungeon': 84,
#   'Darkest Dungeon®': 84,
#   'Duskers': 83,
#   'Deus Ex: Mankind Divided': 83,
#   'Slayaway Camp': 83,
#   'Quern - Undying Thoughts': 83,
#   'ABZU': 83,
#   'Hearts of Iron IV': 83,
#   "Don't Starve Together": 83,
#   'Danganronpa 2: Goodbye Despair': 83,
#   'Grim Dawn': 83,
#   'Devil Daggers': 83,
#   'DarkMaus': 83,
#   'Danganronpa: Trigger Happy Havoc': 82,
#   'SUPERHOT': 82,
#   'Momodora: Reverie Under The Moonlight': 82,
#   'BLACKHOLE: Challenge Vault': 82,
#   "WildStar: Captain's Pack": 82,
#   'WildStar: Cute & Cuddly Pack': 82,
#   'VIDEOBALL': 82,
#   'Creepy Castle': 82,
#   'Endless Legend™ - Tempest': 82,
#   'Burly Men at Sea': 82,
#   'RunGunJumpGun': 82,
#   'Duelyst': 82,
#   'WildStar: Adventure Pack': 82,
#   'WildStar: Hero Pack': 82,
#   'WildStar: Legend Pack (NA)': 82,
#   'The Banner Saga 2': 82,
#   "Dragon's Dogma: Dark Arisen": 81,
#   'Nelly Cootalot: The Fowl Fleet': 81,
#   'Starbound': 81,
#   'GoNNER': 81,
#   'Torment: Tides of Numenera': 81,
#   'OneShot': 81,
#   'Ashes of the Singularity: Escalation': 81,
#   'Motorsport Manager': 81,
#   'Atlas Reactor': 81,
#   'Overcooked': 81,
#   'Quadrilateral Cowboy': 81,
#   'SteamWorld Heist': 81,
#   'Firewatch': 81,
#   'The Bug Butcher': 81,
#   'Oxenfree': 80,
#   'Samorost 3': 80,
#   'DARIUSBURST Chronicle Saviours - Space Harrier': 80,
#   'DARIUSBURST Chronicle Saviours - Fantasy Zone': 80,
#   'DARIUSBURST Chronicle Saviours - Galaxy Force II': 80,
#   'Seraph': 80,
#   'Football Manager 2017': 80,
#   'Candle': 80,
#   'Cities: Skylines - Natural Disasters': 80,
#   'Mekazoo': 80,
#   'Tricky Towers': 80,
#   'Sengoku Jidai: Shadow of the Shogun': 80,
#   'Mushroom Wars': 80,
#   '1979 Revolution: Black Friday': 80,
#   'Leap of Fate': 80,
#   'Move or Die': 80,
#   'Homeworld: Deserts of Kharak': 79,
#   'Dying Light: The Following': 79,
#   'EARTH DEFENSE FORCE 4.1 The Shadow of New Despair': 79,
#   'Kelvin and the Infamous Machine': 79,
#   'Worms W.M.D': 79,
#   'Hue': 79,
#   'Fractured Space': 79,
#   'The Metronomicon: Slay The Dance Floor': 79,
#   'Anarcute': 79,
#   'Goetia': 79,
#   'That Dragon, Cancer': 78,
#   'Dungelot: Shattered Lands': 78,
#   'The Count Lucanor': 78,
#   'Offworld Trading Company': 78,
#   "The Lion's Song: Episode 1 - Silence": 78,
#   'Lovely Planet Arcade': 78,
#   'Sunless Sea - Zubmariner': 78,
#   'Xanadu Next': 78,
#   'Shadow Warrior 2': 78,
#   'Wuppo': 78,
#   'Stellaris': 78,
#   'Deathsmiles': 78,
#   'Obliteracers': 78,
#   'Crashlands': 78,
#   'Kathy Rain': 77,
#   'Reigns': 77,
#   'Orwell: Keeping an Eye On You': 77,
#   'VA-11 Hall-A: Cyberpunk Bartender Action': 77,
#   'On Rusty Trails': 77,
#   'Lumo': 77,
#   'Battlefleet Gothic: Armada': 77,
#   "Baldur's Gate: Siege of Dragonspear": 77,
#   'Magical Eyes - Red is for Anguish': 77,
#   'Echoes of Aetheria': 77,
#   'Furi': 76,
#   'Muv-Luv': 76,
#   'The Final Station': 76,
#   'Clustertruck': 76,
#   'Dark Train': 76,
#   'Shantae: Half-Genie Hero': 76,
#   'Chronicle: RuneScape Legends': 76,
#   "Everybody's Gone to the Rapture": 76,
#   'Polaris Sector': 76,
#   'Deponia Doomsday': 76,
#   'American Truck Simulator': 76,
#   'The Aquatic Adventure of the Last Human': 76,
#   'Drawn™: Dark Flight': 75,
#   'Downfall': 75,
#   'Road to Ballhalla': 75,
#   'Beholder': 75,
#   'Silence': 75,
#   'Killing Floor 2': 75,
#   'Rusty Lake: Roots': 75,
#   'Event[0]': 75,
#   'Seasons after Fall': 75,
#   'Space Run Galaxy': 75,
#   'Battlezone 98 Redux': 75,
#   'Gremlins, Inc.': 75,
#   'Shardlight': 75,
#   'Street Fighter V': 74,
#   'Disgaea PC / 魔界戦記ディスガイア PC': 74,
#   'Headlander': 74,
#   'The Turing Test': 74,
#   'The Elder Scrolls V: Skyrim Special Edition': 74,
#   'Yesterday Origins': 74,
#   'The Curious Expedition': 74,
#   'Master of Orion': 74,
#   'Virginia': 74,
#   'The Real Texas': 74,
#   'Arma 3 Apex': 74,
#   'Blacksea Odyssey': 74,
#   'Neon Chrome': 74,
#   'Stories: The Path of Destinies': 74,
#   'Epistory - Typing Chronicles': 74,
#   'Slain: Back from Hell': 74,
#   'WWE 2K16': 74,
#   'Far Cry® Primal': 74,
#   "Heaven's Hope - Special Edition": 74,
#   'Sora': 74,
#   'Punch Club': 73,
#   'The Flame in the Flood': 73,
#   'The Minims': 73,
#   'Turmoil': 73,
#   'Talent Not Included': 73,
#   'Ladykiller in a Bind': 73,
#   'Call of Duty®: Infinite Warfare': 73,
#   'Project Highrise': 73,
#   'Livelock': 73,
#   'Poly Bridge': 73,
#   'Hard Reset Redux': 73,
#   'Cars': 73,
#   'The Deadly Tower of Monsters': 73,
#   'Layers of Fear': 72,
#   'Hitman GO: Definitive Edition': 72,
#   'LOUD on Planet X': 72,
#   'Lichtspeer': 72,
#   'Steep™': 72,
#   'Dofus': 72,
#   'Duke Nukem 3D: 20th Anniversary World Tour': 72,
#   'Valentino Rossi The Game': 72,
#   'Demetrios - The BIG Cynical Adventure': 72,
#   'Ninja Senki DX': 72,
#   'Cities: Skylines - Snowfall': 72,
#   'Corpse Party': 71,
#   'Overfall': 71,
#   'Grow Up': 71,
#   'Halcyon 6: Starbase Commander': 71,
#   'Klang': 71,
#   'Mantis Burn Racing®': 71,
#   'Crazy Machines 3': 71,
#   'Hearts of Iron IV: Together for Victory': 71,
#   'Aragami': 71,
#   'Song of the Deep': 71,
#   "The Order of the Thorne - The King's Challenge": 71,
#   'Wailing Heights': 70,
#   'Human: Fall Flat': 70,
#   'The Warlock of Firetop Mountain': 70,
#   'Marooners': 70,
#   'Ember': 70,
#   'Mother Russia Bleeds': 70,
#   'Near Death': 70,
#   'Brigador: Up-Armored Edition': 70,
#   'SENRAN KAGURA SHINOVI VERSUS': 70,
#   'Fragments of Him': 69,
#   'Battleborn': 69,
#   'TransOcean 2: Rivals': 69,
#   'Farming Simulator 17': 69,
#   '99Vidas': 69,
#   'Diaries of a Spaceport Janitor': 69,
#   'How to Survive 2': 69,
#   'Okhlos: Omega': 69,
#   'Excubitor': 69,
#   'Aurion: Legacy of the Kori-Odan': 69,
#   'Cobalt': 69,
#   'Defragmented': 68,
#   'The Guest': 68,
#   "Don't open the doors!": 68,
#   'Hide and Shriek': 68,
#   'WRC 6 FIA World Rally Championship': 68,
#   "Unbox: Newbie's Adventure": 68,
#   'WASTED': 68,
#   'Koihime Enbu': 68,
#   'Rogue Stormers': 68,
#   'Good Robot': 67,
#   'The Silver Case': 67,
#   'Dungeon Souls': 67,
#   'Small Radios Big Televisions': 67,
#   'Ride 2': 67,
#   'Rogue Wizards': 67,
#   'Champions of Anteria™': 67,
#   'TurnOn': 67,
#   'Megamagic: Wizards of the Neon Age': 67,
#   'CALENDULA': 67,
#   'Zombasite': 66,
#   'Toy Odyssey: The Lost and Found': 66,
#   'Tahira: Echoes of the Astral Empire': 66,
#   'Metrico+': 66,
#   'Last Days of Old Earth': 66,
#   "Sherlock Holmes: The Devil's Daughter": 65,
#   'Maize': 65,
#   'Pirate Pop Plus': 65,
#   'Rusty Lake Hotel': 65,
#   'Slybots: Frantic Zone': 65,
#   'Californium': 64,
#   '8DAYS - PEACE IS OUR BUSINESS': 64,
#   'Oh...Sir!! The Insult Simulator': 64,
#   'Super Rad Raygun': 64,
#   'Franchise Hockey Manager 3': 64,
#   'Masquerada: Songs and Shadows': 64,
#   'Pro Cycling Manager 2016': 64,
#   'Ryzom': 64,
#   'Spellweaver': 63,
#   'Obscuritas': 63,
#   'Wheels of Aurelia': 63,
#   'Youtubers Life': 63,
#   'Nitroplus Blasterz: Heroines Infinite Duel': 63,
#   'Crush Your Enemies': 63,
#   'March of the Living': 63,
#   'The Westport Independent': 63,
#   "Little King's Story": 62,
#   'The Little Acre': 62,
#   "Five Nights at Freddy's: Sister Location": 62,
#   'Mafia III': 62,
#   'Moon Hunters': 62,
#   'Between Me and The Night': 62,
#   'Tharsis': 61,
#   'Fossil Echo': 61,
#   'The Dwarves': 61,
#   "No Man's Sky": 61,
#   'Into the Stars': 61,
#   "Her Majesty's SPIFFING": 60,
#   'No Pineapple Left Behind': 59,
#   'N.E.R.O.: Nothing Ever Remains Obscure': 59,
#   'The Descendant': 59,
#   'Shooting Stars!': 59,
#   'ZHEROS': 58,
#   'Cornerstone: The Song of Tyrim': 58,
#   'Stereo Aereo': 58,
#   "Hunter's Legacy": 58,
#   'Scrap Garden': 58,
#   'Goliath': 57,
#   'The Bunker': 57,
#   'Zenith': 57,
#   'Kill to Collect': 57,
#   'The Descendant: Rest of Season': 57,
#   'Soul Axiom': 57,
#   'ARSLAN: THE WARRIORS OF LEGEND': 57,
#   'ENIGMA:': 56,
#   'OmniBus': 55,
#   'Ray Gigant': 55,
#   'The Great Escape': 54,
#   'The Preposterous Awesomeness of Everything': 54,
#   'Homefront®: The Revolution': 54,
#   'Trials of the Blood Dragon': 54,
#   'Hybrid Wars': 54,
#   'Dangerous Golf': 54,
#   'POSTAL Redux': 54,
#   'E.T. Armies': 54,
#   'Gemini: Heroes Reborn': 54,
#   'Shadwen': 53,
#   'Code of Princess': 53,
#   'Planar Conquest': 53,
#   'Dead Effect 2': 53,
#   'Back in 1995': 52,
#   'Mighty No. 9': 52,
#   'Shiny': 51,
#   'Dinocide': 51,
#   'Krai Mira: Extended Cut': 50,
#   'IS Defense': 50,
#   'Guards': 49,
#   'Ares Omega': 49,
#   'Blood Alloy: Reborn': 48,
#   'DreamBreak': 46,
#   'Prospekt': 43,
#   'RollerCoaster Tycoon World™': 43,
#   'MilitAnt': 41,
#   'Monumental': 41,
#   'Doors': 40,
#   "Alekhine's Gun": 40,
#   'Super Duper Party Pooper': 40,
#   "Ian's Eyes": 36},
#  2017: {'OKAMI HD / 大神 絶景版': 93,
#   'Divinity: Original Sin 2': 93,
#   'Bayonetta': 90,
#   'Linelight': 90,
#   'F1™ 2017': 89,
#   'What Remains of Edith Finch': 89,
#   'Night in the Woods': 88,
#   'XCOM 2: War of the Chosen - Propaganda Center': 88,
#   'XCOM 2: War of the Chosen': 88,
#   'Cuphead': 88,
#   'NBA 2K18': 87,
#   'FINAL FANTASY XIV: Stormblood': 87,
#   'Orcs Must Die! Unchained': 87,
#   'Hollow Knight': 86,
#   'Monster Slayers': 86,
#   'West of Loathing': 86,
#   'Wolfenstein II: The New Colossus': 86,
#   'Microsoft Allegiance': 86,
#   'Total War: WARHAMMER II': 86,
#   'Out of the Park Baseball 18': 86,
#   'Battlerite': 85,
#   'SteamWorld Dig 2': 85,
#   'Aliens Go Home Run': 84,
#   'Thimbleweed Park™': 84,
#   'Rakuen': 84,
#   'Nex Machina': 84,
#   'Field of Glory II': 84,
#   'Sonic Mania': 84,
#   'The End Is Nigh': 84,
#   'NieR:Automata™': 84,
#   'RESIDENT EVIL 7 biohazard / BIOHAZARD 7 resident evil': 83,
#   'Quern - Undying Thoughts (Original Soundtrack)': 83,
#   'The Sexy Brutale': 83,
#   'Monolith': 83,
#   'Gorogoa': 83,
#   'Stellaris: Synthetic Dawn Story Pack': 83,
#   'Subsurface Circular': 83,
#   "Hellblade: Senua's Sacrifice": 83,
#   'Steel Division: Normandy 44': 83,
#   'The Legend of Heroes: Trails in the Sky the 3rd': 83,
#   'Bleed 2': 83,
#   'TEKKEN 7': 82,
#   'Darkest Dungeon®: The Crimson Court': 82,
#   'Pyre': 82,
#   'Finding Paradise': 82,
#   'Football Manager 2018': 82,
#   'Super Hydorah': 82,
#   'HoPiKo': 82,
#   'She Remembered Caterpillars': 82,
#   'Little Nightmares': 81,
#   'Rising Storm 2: Vietnam': 81,
#   'Antihero': 81,
#   'Aztez': 81,
#   'Slime Rancher': 81,
#   'PRO EVOLUTION SOCCER 2018': 81,
#   'JYDGE': 81,
#   'Reigns: Her Majesty': 81,
#   'World of Warships': 81,
#   'The Evil Within 2': 81,
#   'Emily is Away Too': 81,
#   'Stories Untold': 81,
#   'Disgaea 2 PC / 魔界戦記ディスガイア2 PC': 81,
#   'LEGO City Undercover': 80,
#   'The Legend of Heroes: Trails of Cold Steel': 80,
#   'Nidhogg 2': 80,
#   'Ys SEVEN': 80,
#   'Dishonored®: Death of the Outsider™': 80,
#   'Battle Chef Brigade': 80,
#   'Hand of Fate 2': 80,
#   'Zwei: The Ilvard Insurrection': 80,
#   'Tooth and Tail': 80,
#   'Kingsway': 80,
#   'CRYPTARK': 80,
#   'Flinthook': 80,
#   'Battle Brothers': 80,
#   'Faeria': 80,
#   'Tales of Berseria™': 80,
#   'Heat Signature': 79,
#   'A Hat in Time': 79,
#   'Battle Chasers: Nightwar': 79,
#   'Life is Strange: Before the Storm': 79,
#   'Altitude': 79,
#   'Splasher': 79,
#   'Hidden Folks': 78,
#   'Slime-san': 78,
#   "Marvel's Guardians of the Galaxy: The Telltale Series": 78,
#   'Cities: Skylines - Mass Transit': 78,
#   'The Infectious Madness of Doctor Dekker': 78,
#   'Cat Quest': 78,
#   '>observer_': 78,
#   'Vaporum': 78,
#   'Bridge Constructor Portal': 78,
#   'The Journey Down: Chapter Three': 78,
#   'DiRT 4': 78,
#   'Lydia': 78,
#   'RiME': 78,
#   'Vanquish': 78,
#   'Everything': 78,
#   'Blossom Tales: The Sleeping King': 78,
#   'Shadows of Adam': 78,
#   'Downward': 77,
#   'Cosmic Star Heroine': 77,
#   'Full Throttle Remastered': 77,
#   'Figment': 77,
#   'Hob': 77,
#   'Battlestar Galactica Deadlock': 77,
#   "Old Man's Journey": 77,
#   "Block'hood": 77,
#   'Herald: An Interactive Period Drama - Book I & II': 77,
#   'FOR HONOR™': 76,
#   'BULLET SOUL / バレットソウル - 弾魂 - Original Soundtrack': 76,
#   'Lode Runner Legacy': 76,
#   'Super Cloudbuilt': 76,
#   'BULLET SOUL INFINITE BURST - Original Soundtrack': 76,
#   'Secret World Legends': 76,
#   'Mushroom Wars 2': 76,
#   'Purrfect Date - Visual Novel/Dating Simulator': 76,
#   'Breakneck': 76,
#   'LawBreakers': 76,
#   'Tacoma': 76,
#   'Gigantic': 76,
#   'Bulletstorm: Full Clip Edition': 76,
#   'BULLET SOUL / バレットソウル - 弾魂 -': 76,
#   '🔴 Circles': 76,
#   'Stars in Shadow': 75,
#   'World to the West': 75,
#   'Bokida - Heartfelt Reunion': 75,
#   'GET EVEN': 75,
#   'RUINER': 75,
#   'Bomber Crew': 75,
#   'Attentat 1942': 75,
#   'Dungeons 3': 75,
#   'Mutant Football League': 75,
#   'Last Day of June': 75,
#   'Absolver': 75,
#   'Future Unfolding': 75,
#   'Alone With You': 75,
#   'The Darkside Detective': 75,
#   'Milkmaid of the Milky Way': 74,
#   'Dead Rising 4': 74,
#   'Forts': 74,
#   'Mages of Mystralia': 74,
#   'Starpoint Gemini Warlords': 74,
#   'Oriental Empires': 74,
#   'SpellForce 3': 74,
#   'The Escapists 2': 74,
#   'Sundered': 74,
#   'Expeditions: Viking': 74,
#   'Leaving Lyndow': 74,
#   'Atelier Sophie: The Alchemist of the Mysterious Book': 73,
#   'Toukiden 2': 73,
#   'Yooka-Laylee': 73,
#   'Black Desert Online': 73,
#   "Another Lost Phone: Laura's Story": 73,
#   'Halcyon 6: Starbase Commander (LIGHTSPEED EDITION)': 73,
#   'Children of Zodiarcs': 73,
#   'Conarium': 73,
#   'Regalia: Of Men and Monarchs': 73,
#   'Kona': 73,
#   'Mainlining': 73,
#   'Portal Knights': 72,
#   'Dream Daddy: A Dad Dating Simulator': 72,
#   'ECHO': 72,
#   'Black The Fall': 72,
#   'The Surge': 72,
#   'DYSTORIA': 72,
#   'The Wardrobe': 72,
#   'Drifting Lands': 71,
#   'BOOR': 71,
#   'Loot Rascals': 71,
#   'Mantis Burn Racing® - Elite Class': 71,
#   'Mantis Burn Racing® - Snowbound Pack': 71,
#   'Pro Cycling Manager 2017': 71,
#   'Mantis Burn Racing® - Battle Cars': 71,
#   'Dreamfall Chapters': 71,
#   'Aporia: Beyond The Valley': 71,
#   'OVIVO': 71,
#   'Snake Pass': 71,
#   "Alwa's Awakening": 71,
#   'A Normal Lost Phone': 71,
#   'Dawn of Andromeda': 70,
#   'Yonder: The Cloud Catcher Chronicles': 70,
#   'Sudden Strike 4': 70,
#   'ARK: Survival Evolved': 70,
#   'Tokyo Dark': 70,
#   'Rezrog': 70,
#   'Tokyo 42': 70,
#   'Immortal Redneck': 70,
#   'Blackwood Crossing': 70,
#   'DESYNC': 69,
#   'The Shrouded Isle': 69,
#   'Fall of Light': 69,
#   'Marvel vs. Capcom: Infinite': 69,
#   '.hack//G.U. Last Recode': 69,
#   'Baobabs Mausoleum Ep.1: Ovnifagos Don´t Eat Flamingos': 69,
#   'Hover': 69,
#   'The Fidelio Incident': 69,
#   'Plasma Puncher': 69,
#   'Dynasty Feud': 68,
#   'The Long Journey Home': 68,
#   'Blitzkrieg 3': 68,
#   'Solstice Chronicles: MIA': 68,
#   'Darkestville Castle': 68,
#   'Shiness: The Lightning Kingdom': 68,
#   '2Dark': 68,
#   'Warhammer 40,000: Sanctus Reach': 68,
#   'Songbringer': 67,
#   'NBA Playgrounds': 67,
#   'Angels with Scaly Wings': 67,
#   'Nefarious': 67,
#   'Project Earth': 67,
#   'Bounty Train': 66,
#   'Deadbeat Heroes': 66,
#   'WWE 2K18': 66,
#   'Ogre': 66,
#   'CHASER': 66,
#   'Miniature Garden': 66,
#   'Rain World': 66,
#   'Brut@l': 66,
#   'Diluvion': 66,
#   'Among the Sleep - Enhanced Edition': 66,
#   'ATOMEGA': 65,
#   'HYAKKI CASTLE': 65,
#   'Immortal Planet': 65,
#   'Aven Colony': 65,
#   'The Franz Kafka Videogame': 65,
#   "The Crow's Eye": 65,
#   'SpiritSphere': 64,
#   'Danger Zone': 64,
#   'Serial Cleaner': 64,
#   'Fictorum': 64,
#   'Moero Chronicle | 限界凸記 モエロクロニクル | 極限凸記\u3000萌萌編年史': 64,
#   'Nights of Azure': 64,
#   'Voodoo Vince: Remastered': 63,
#   'No Escape': 63,
#   'Fallout Shelter': 63,
#   'Has-Been Heroes': 63,
#   'Take On Mars': 62,
#   'Impact Winter': 62,
#   'Mafia III: Faster, Baby!': 62,
#   'Urban Empire': 62,
#   'BLUE REFLECTION / BLUE REFLECTION\u3000幻に舞う少女の剣': 61,
#   'Friday the 13th: The Game': 61,
#   'The Great Whale Road': 61,
#   'The Keep': 61,
#   'WWE 2K17': 61,
#   'Phoning Home': 61,
#   'Auto Age: Standoff': 59,
#   'Arelite Core': 59,
#   'Memoranda': 58,
#   'Formula Fusion': 58,
#   'Sonic Forces': 58,
#   'Behold the Kickmen': 58,
#   'Empathy: Path of Whispers': 57,
#   'EMPYRE: Lords of the Sea Gates': 56,
#   'Beat The Game': 55,
#   'Raiders of the Broken Planet - Ultimate Edition': 54,
#   'Freaky Awesome': 54,
#   'Raiders of the Broken Planet - Eternal Soldier Campaign': 54,
#   'RAID: World War II': 53,
#   'AereA': 53,
#   'No70: Eye of Basir': 52,
#   'FlatOut 4: Total Insanity': 52,
#   'Syberia 3': 51,
#   'Snow Moto Racing Freedom': 50,
#   'Pylon: Rogue': 50,
#   'Double Dragon IV': 50,
#   'We Are Chicago': 49,
#   'Randall': 48,
#   'Bush Hockey League': 48,
#   'Inmates': 46,
#   'NeverEnd': 44,
#   'Hello Neighbor': 40}}

# %%
with open("datasets/steam_games_endpoint_6_metascore.json", "w") as outfile:
    json.dump(metascoreEndpointDict_sorted, outfile)

# %% [markdown]
# **TEST**

# %%
def metascore( Year: str ):
    """
    Top 5 juegos según año con mayor metascore.
    """
    # Read data
    with open("datasets/steam_games_endpoint_6_metascore.json") as json_file:
        metascore_dict = json.load(json_file)

    # TODO Add validation, ademas de cantidad menor 5.

    # Since data is already sorted, get the first 5 as top 5.
    top5 = dict(list(metascore_dict[Year].items())[0:5])
    return top5

metascore('2015')
# Out:
# {'Grand Theft Auto V': 96,
#  'Divinity: Original Sin - Enhanced Edition': 94,
#  'Undertale': 92,
#  'METAL GEAR SOLID V: THE PHANTOM PAIN': 91,
#  'Pillars of Eternity': 89}
